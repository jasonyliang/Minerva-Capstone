# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import torch
# from fake_claims_generator import generate, grab_random_prompts

# %%
# !pip3 install git+https://github.com/huggingface/transformers@v3.1.0 # there are errors in the later versions
# !pip3 install transformers==3.3.1
# Out:
# Collecting transformers==3.3.1
#   Downloading https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 17.4MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (20.8)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 49.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (4.41.1)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 54.4MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (3.0.12)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 48.4MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.3.1) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.0.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=93c2688af1cc8bb03b418d1d9513b3ba9e4423ba43c91f34a2e6fd4263735e46
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, sentencepiece, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc2 transformers-3.3.1

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts
# *** Modify the directory to the right model ***
OUTPUT_DIR = "./Models/Experiments/Claims/3epochs"
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ## Load Real Data and Label Them

# %%
data = pd.read_csv("./Models/Data/H01L.csv")
real_data = pd.DataFrame({"Claims": data["claims"]})
real_data["Label"] = 0
real_data = real_data[real_data['Claims'].notnull()]
# real_data = pd.DataFrame({"Abstracts": data["abstracts"]})
# real_data["Label"] = 0
# real_data = real_data[real_data['Abstracts'].notnull()]

# %%
real_data
# Out:
#                                                  Claims  Label
# 0     1.  An organic light emitting diode display co...      0
# 1     1.  An electric element cooling module compris...      0
# 2     2.  The organic light emitting diode display o...      0
# 3     2.  The electric element cooling module of cla...      0
# 4     3.  The organic light emitting diode display o...      0
# ...                                                 ...    ...
# 8941  2.  The method of claim 1, further comprising:...      0
# 8942  3.  The method of claim 1, wherein the first g...      0
# 8943  4.  The method of claim 1, wherein a width of ...      0
# 8944  5.  The method of claim 1, wherein a length of...      0
# 8945  6.  The method of claim 1, further comprising:...      0
#
# [8420 rows x 2 columns]

# %% [markdown]
# ## Generate Fake Data and Label Them

# %%
# How many fake claims do you want to generate
# num_fake_claims = len(real_data)
# prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
# fake_claims = []
# for i, prompt in enumerate(prompts):
#     print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
#     generated_text = generate(prompt, n=8)
#     fake_claims.append(generated_text)

# %%
# write in chunks, and write to csv
'''
This code block is responsible for generating fake patent Claims
I first deine the file paths where we will save the fake patent data
Then, I generate the fake patent prompts by sampling from the real abstracts
I save the prompts into a csv file.
Since I am running the generation on Colab and I'm generating thousands of fake patent Claims,
there is a high frequency of interuption, I therefore need to save the prompts (to be accessed later),
and save the patent claims for every 100 that are generated.
The last_interupted variable stores where the generation was last interupted.
'''
import os.path
fake_data_file = "Models/Experiments/Claims/fake_patent_claims_3epochs.csv"
prompt_file = "Models/Experiments/Claims/prompts_3epochs.csv"
# fake_data_file = "Models/Experiments/Abstracts/fake_patent_abstracts_3epochs.csv"
# prompt_file = "Models/Experiments/Abstracts/prompts_3epochs.csv"
num_fake_claims = len(real_data)
if os.path.exists(prompt_file):
  prompts = pd.read_csv(prompt_file)
  prompts = prompts['Prompts'].tolist()
else:
  prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
  # save prompts
  prompt_df = pd.DataFrame({"Prompts": prompts})
  prompt_df.to_csv(prompt_file)
fake_claims = []
# modify last interrupted 
last_interrupted = 8200
for i, prompt in enumerate(prompts[last_interrupted:]): # modify last_interrupted if we got disconnected
    if i % 100 == 0 and i != 0: # for every 100 claims
      df = pd.DataFrame({"Claims": fake_claims, "Label": 1})
      if os.path.exists(fake_data_file): # this means this csv is already created
        df.to_csv(fake_data_file, mode='a', header=False)
      else:
        df.to_csv(fake_data_file)
      fake_claims = []
    print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
    generated_text = generate(prompt, n=8)
    fake_claims.append(generated_text)
# last batch
df = pd.DataFrame({"Claims": fake_claims, "Label": 1})
df.to_csv(fake_data_file, mode='a', header=False)
# Out:
# Generating Prompt 1 ... Prompt: 1. A method for forming
# Generating Prompt 2 ... Prompt: 6. The memory of claim
# Generating Prompt 3 ... Prompt: 20. The organic light emitting
# Generating Prompt 4 ... Prompt: 9. The method of claim
# Generating Prompt 5 ... Prompt: 7. A piezoelectrically actuated valve
# Generating Prompt 6 ... Prompt: 40. The method of claim
# Generating Prompt 7 ... Prompt: 1. An article comprising: a
# Generating Prompt 8 ... Prompt: 4. The method according to
# Generating Prompt 9 ... Prompt: 16. The apparatus of claim
# Generating Prompt 10 ... Prompt: 16. A vibration-type actuator comprising:
# Generating Prompt 11 ... Prompt: 21. The method of manufacturing
# Generating Prompt 12 ... Prompt: 13. The semiconductor device according
# Generating Prompt 13 ... Prompt: 12. The method of claim
# Generating Prompt 14 ... Prompt: 13. The system of claim
# Generating Prompt 15 ... Prompt: 14. A sensor package comprising:
# Generating Prompt 16 ... Prompt: 11. An encapsulant formed by
# Generating Prompt 17 ... Prompt: 10. The phase-change memory of
# Generating Prompt 18 ... Prompt: 1. An organic light emitting
# Generating Prompt 19 ... Prompt: 5. The method of claim
# Generating Prompt 20 ... Prompt: 14. A solid body prepared
# Generating Prompt 21 ... Prompt: 2. The electronic device using
# Generating Prompt 22 ... Prompt: 15. The manufacturing method of
# Generating Prompt 23 ... Prompt: 6. An array of power
# Generating Prompt 24 ... Prompt: 19. A three-dimensional memory device
# Generating Prompt 25 ... Prompt: 20. The method of claim
# Generating Prompt 26 ... Prompt: 8. The method of claim
# Generating Prompt 27 ... Prompt: 4. The device of claim
# Generating Prompt 28 ... Prompt: 10. The analog-to-digital converter according
# Generating Prompt 29 ... Prompt: 34. The method of claim
# Generating Prompt 30 ... Prompt: 4. The method of claim
# Generating Prompt 31 ... Prompt: 7. The method of claim
# Generating Prompt 32 ... Prompt: 3. The assembly of claim
# Generating Prompt 33 ... Prompt: 1. An image sensor comprising
# Generating Prompt 34 ... Prompt: 11. The fabrication method according
# Generating Prompt 35 ... Prompt: 13. The capacitor unit of
# Generating Prompt 36 ... Prompt: 13. An organic light-emitting display
# Generating Prompt 37 ... Prompt: 12. The IC die of
# Generating Prompt 38 ... Prompt: 2. The composition according to
# Generating Prompt 39 ... Prompt: 3. The method of fabricating
# Generating Prompt 40 ... Prompt: 6. The electronic apparatus according
# Generating Prompt 41 ... Prompt: 1. A supplemental cooling system,
# Generating Prompt 42 ... Prompt: 5. The display device according
# Generating Prompt 43 ... Prompt: 2. The photoelectric conversion device
# Generating Prompt 44 ... Prompt: 4. The preparation method according
# Generating Prompt 45 ... Prompt: 20. The method of claim
# Generating Prompt 46 ... Prompt: 20. The light-emitting element according
# Generating Prompt 47 ... Prompt: 3. The uncharged transition metal
# Generating Prompt 48 ... Prompt: 11. The semiconductor device according
# Generating Prompt 49 ... Prompt: 1. A semiconductor device comprising;
# Generating Prompt 50 ... Prompt: 9. The LED package according
# Generating Prompt 51 ... Prompt: 2. The method of claim
# Generating Prompt 52 ... Prompt: 15. The method of claim
# Generating Prompt 53 ... Prompt: 7. The infrared light emitting
# Generating Prompt 54 ... Prompt: 22. The organic light-emitting display
# Generating Prompt 55 ... Prompt: 18. A system comprising: a
# Generating Prompt 56 ... Prompt: 20. The display device of
# Generating Prompt 57 ... Prompt: 17. The analog-to-digital conversion method
# Generating Prompt 58 ... Prompt: 23. The computing device of
# Generating Prompt 59 ... Prompt: 6. The method for producing
# Generating Prompt 60 ... Prompt: 1. An apparatus comprising: a
# Generating Prompt 61 ... Prompt: 5. The stacked-die oscillator package
# Generating Prompt 62 ... Prompt: 15. An electronic device that
# Generating Prompt 63 ... Prompt: 15. A display apparatus, comprising:
# Generating Prompt 64 ... Prompt: 3. The method of claim
# Generating Prompt 65 ... Prompt: 7. The semiconductor device of
# Generating Prompt 66 ... Prompt: 8. The method for manufacturing
# Generating Prompt 67 ... Prompt: 1. A device comprising: a
# Generating Prompt 68 ... Prompt: 2. The solar cell of
# Generating Prompt 69 ... Prompt: 13. A light-emitting element comprising:
# Generating Prompt 70 ... Prompt: 4. The semiconductor device of
# Generating Prompt 71 ... Prompt: 5. The solar cell of
# Generating Prompt 72 ... Prompt: 22. The stacked-die oscillator package
# Generating Prompt 73 ... Prompt: 10. The method of claim
# Generating Prompt 74 ... Prompt: 8. An apparatus for manufacturing
# Generating Prompt 75 ... Prompt: 11. The organic light-emitting device
# Generating Prompt 76 ... Prompt: 5. The perovskite-based photovoltaic device
# Generating Prompt 77 ... Prompt: 13. An electronic camera having
# Generating Prompt 78 ... Prompt: 19. The semiconductor die assembly
# Generating Prompt 79 ... Prompt: 20. The non-transitory computer-readable medium
# Generating Prompt 80 ... Prompt: 7. The method of claim
# Generating Prompt 81 ... Prompt: 5. The organic electroluminescent device
# Generating Prompt 82 ... Prompt: 5. The device of claim
# Generating Prompt 83 ... Prompt: 16. The method of claim
# Generating Prompt 84 ... Prompt: 14. The apparatus of claim
# Generating Prompt 85 ... Prompt: 8. The integrated circuit device
# Generating Prompt 86 ... Prompt: 12. The method for producing
# Generating Prompt 87 ... Prompt: 1. A vapor deposition mask
# Generating Prompt 88 ... Prompt: 5. The perovskite-based photovoltaic device
# Generating Prompt 89 ... Prompt: 36. The process as claimed
# Generating Prompt 90 ... Prompt: 16. The organic light-emitting display
# Generating Prompt 91 ... Prompt: 10. A pixel assembly according
# Generating Prompt 92 ... Prompt: 17. The method of claim
# Generating Prompt 93 ... Prompt: 19. A UV light emitting
# Generating Prompt 94 ... Prompt: 7. The perovskite-based photovoltaic device
# Generating Prompt 95 ... Prompt: 2. The device according to
# Generating Prompt 96 ... Prompt: 2. The light-emitting semiconductor chip
# Generating Prompt 97 ... Prompt: 4. The circuit carrier structure
# Generating Prompt 98 ... Prompt: 3. The display device of
# Generating Prompt 99 ... Prompt: 18. A chip package, comprising:
# Generating Prompt 100 ... Prompt: 19. The composition according to
# Generating Prompt 101 ... Prompt: 3. The magnetoresistance effect element
# Generating Prompt 102 ... Prompt: 22. A memory comprising: a
# Generating Prompt 103 ... Prompt: 5. The method according to
# Generating Prompt 104 ... Prompt: 11. The method of claim
# Generating Prompt 105 ... Prompt: 25. The electronic system of
# Generating Prompt 106 ... Prompt: 7. The display apparatus of
# Generating Prompt 107 ... Prompt: 10. The display panel according
# Generating Prompt 108 ... Prompt: 35. The method of claim
# Generating Prompt 109 ... Prompt: 3. The package according to
# Generating Prompt 110 ... Prompt: 10. The method of claim
# Generating Prompt 111 ... Prompt: 3. The module of claim
# Generating Prompt 112 ... Prompt: 16. The method of claim
# Generating Prompt 113 ... Prompt: 11. A composition comprising: at
# Generating Prompt 114 ... Prompt: 12. The method of claim
# Generating Prompt 115 ... Prompt: 9. The composition of claim
# Generating Prompt 116 ... Prompt: 10. The display device according
# Generating Prompt 117 ... Prompt: 18. A method for operating
# Generating Prompt 118 ... Prompt: 10. The manufacturing method of
# Generating Prompt 119 ... Prompt: 5. The method of claim
# Generating Prompt 120 ... Prompt: 1. A display panel, comprising:
# Generating Prompt 121 ... Prompt: 13. The piezoelectrically actuated valve
# Generating Prompt 122 ... Prompt: 3. The piezoelectric linear actuator
# Generating Prompt 123 ... Prompt: 4. The method of claim
# Generating Prompt 124 ... Prompt: 1. A dual-interface integrated circuit
# Generating Prompt 125 ... Prompt: 7. The electronic apparatus of
# Generating Prompt 126 ... Prompt: 3. The multi-junction solar cell
# Generating Prompt 127 ... Prompt: 11. The method of claim
# Generating Prompt 128 ... Prompt: 18. An infrared light emitting
# Generating Prompt 129 ... Prompt: 1. A method for manufacturing
# Generating Prompt 130 ... Prompt: 2. The pixel of claim
# Generating Prompt 131 ... Prompt: 7. The integrated assembly of
# Generating Prompt 132 ... Prompt: 13. The method of claim
# Generating Prompt 133 ... Prompt: 14. The method of claim
# Generating Prompt 134 ... Prompt: 7. The method of claim
# Generating Prompt 135 ... Prompt: 7. The module of claim
# Generating Prompt 136 ... Prompt: 11. The photoelectric conversion element
# Generating Prompt 137 ... Prompt: 2. The method of the
# Generating Prompt 138 ... Prompt: 4. The apparatus of claim
# Generating Prompt 139 ... Prompt: 3. The image display device
# Generating Prompt 140 ... Prompt: 4. The system of claim
# Generating Prompt 141 ... Prompt: 3. The semiconductor device according
# Generating Prompt 142 ... Prompt: 9. A display apparatus, comprising
# Generating Prompt 143 ... Prompt: 12. The display apparatus of
# Generating Prompt 144 ... Prompt: 21. The organic light-emitting display
# Generating Prompt 145 ... Prompt: 4. The method for producing
# Generating Prompt 146 ... Prompt: 13. The system of claim
# Generating Prompt 147 ... Prompt: 5. The method of claim
# Generating Prompt 148 ... Prompt: 5. The display device according
# Generating Prompt 149 ... Prompt: 7. The manufacturing method as
# Generating Prompt 150 ... Prompt: 18. The method of claim
# Generating Prompt 151 ... Prompt: 17. An organic electronic device
# Generating Prompt 152 ... Prompt: 11. The method as claimed
# Generating Prompt 153 ... Prompt: 7. The method of claim
# Generating Prompt 154 ... Prompt: 19. The display device according
# Generating Prompt 155 ... Prompt: 20. The method of claim
# Generating Prompt 156 ... Prompt: 19. The display apparatus of
# Generating Prompt 157 ... Prompt: 36. The process as claimed
# Generating Prompt 158 ... Prompt: 17. The device according to
# Generating Prompt 159 ... Prompt: 10. A method for producing
# Generating Prompt 160 ... Prompt: 7. The device according to
# Generating Prompt 161 ... Prompt: 19. The method of claim
# Generating Prompt 162 ... Prompt: 11. The magnetoresistance effect element
# Generating Prompt 163 ... Prompt: 11. The photo detector of
# Generating Prompt 164 ... Prompt: 7. The display device of
# Generating Prompt 165 ... Prompt: 2. An image display device
# Generating Prompt 166 ... Prompt: 19. The phase-change memory of
# Generating Prompt 167 ... Prompt: 13. A display device, comprising:
# Generating Prompt 168 ... Prompt: 16. The device according to
# Generating Prompt 169 ... Prompt: 13. The semiconductor device of
# Generating Prompt 170 ... Prompt: 18. The method according to
# Generating Prompt 171 ... Prompt: 13. The method of claim
# Generating Prompt 172 ... Prompt: 3. The DCO of claim
# Generating Prompt 173 ... Prompt: 15. The infrared light emitting
# Generating Prompt 174 ... Prompt: 9. A semiconductor device comprising
# Generating Prompt 175 ... Prompt: 2. The LED package according
# Generating Prompt 176 ... Prompt: 9. The display device according

# %%
fake_data = pd.read_csv("./Models/Experiments/Claims/fake_patent_claims_3epochs.csv")
# fake_data = pd.read_csv("./Models/Experiments/Abstracts/fake_patent_abstracts_3epochs.csv")
fake_data = fake_data.loc[:, ~fake_data.columns.str.contains('^Unnamed')]
fake_data.head()
# Out:
#                                               Claims  Label
# 0  19. An emitter comprising: a first emitter com...      1
# 1  14. The method of claim 6, wherein the second ...      1
# 2  5. The package according to claim 2, wherein t...      1
# 3  7. The organic light emitting display componen...      1
# 4  10. The method for manufacturing a plurality o...      1

# %%
len(fake_data)
# Out:
# 8420

# %%
frames = [real_data, fake_data]
full_data = pd.concat(frames)


full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data
# Out:
#                                                   Claims  Label
# 0      10. The method of claim 11, wherein the first ...      1
# 1      18.  The flow controller according to claim 17...      0
# 2      17.  The method according to claim 10, wherein...      0
# 3      13. The solar cell of claim 12, further compri...      1
# 4      5. The display device of claim 1, wherein the ...      1
# ...                                                  ...    ...
# 16835  2.  The method of claim 1, further comprising ...      0
# 16836  3.  The device according to claim 2, further c...      0
# 16837  10. The apparatus of claim 10 wherein the seco...      1
# 16838  15. A pixel assembly according to claim 19, wh...      1
# 16839  16.  The device of claim 8, further comprising...      0
#
# [16840 rows x 2 columns]

# %%
full_data['Claims'][0][:250]
# Out:
# '10. The method of claim 11, wherein the first electrode comprises a metal layer and the second electrode comprises a metal material. <EOS>\n<BOS> nan <EOS>\n<BOS> 9.  The organic light emitting diode as claimed in claim 4, further comprising: a first e'

# %%
# path: "Models/Experiments/Claims"
full_data.to_csv("./Models/Experiments/Claims/3epochs/real_fake_claims.csv")

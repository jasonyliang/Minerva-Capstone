# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def trim_string(x):

    x = x.split(maxsplit=first_n_words)
    x = ' '.join(x[:first_n_words])

    return x

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
train_test_ratio = 0.90
train_valid_ratio = 0.80
first_n_words=250

data_path = "./Models/Experiments/Abstracts/3epochs"

# %%
# Read raw data
df_raw = pd.read_csv(data_path+"/real_fake_claims.csv")

# Trim text and titletext to first_n_words
#df_raw['Abstract'] = df_raw['Abstract'].apply(trim_string)

# Split according to label
df_real = df_raw[df_raw['Label'] == 0]
df_fake = df_raw[df_raw['Label'] == 1]

# %%
np.array(df_fake['Abstract'])[0]
# Out:
# 'A semiconductor device includes a first      contact pad region, a second contact pad region, a third      contact pad region, a gate insulating region, a gate electrode region, a      drain insulating region, a light emitting region, and a source region.      The first and second contact pads are respectively electrically connected to an      insulating conductor, and the gate insulating region is electrically      connected to the source region. The source region includes a first region      electrically connected with the first contact pad, a second region      electrically connected with the second contact pad, and a gate electrode region.      The gate electrode region includes a second region electrically connected with the      source region, and the source region includes a third region electrically      connected with the third contact pad. <EOS>\n<BOS> A display device includes a flexible base layer including a first region      and a second region separated from each other along a first direction, a      plurality of bumps positioned in the first'

# %%
def trim_abstract(row): 
  # just needs to take out the <EOS> <BOS> tags
  row = row.replace('<EOS>', '')
  row = row.replace('<BOS>', '')
  return row
df_fake['Abstract'] = df_fake['Abstract'].apply(trim_abstract)
# then trim the string
df_real['Abstract'] = df_real['Abstract'].apply(trim_string)
df_fake['Abstract'] = df_fake['Abstract'].apply(trim_string)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# Train-test split
df_real_full_train, df_real_test = train_test_split(df_real, train_size = train_test_ratio, random_state = 1)
df_fake_full_train, df_fake_test = train_test_split(df_fake, train_size = train_test_ratio, random_state = 1)

# Train-valid split
df_real_train, df_real_valid = train_test_split(df_real_full_train, train_size = train_valid_ratio, random_state = 1)
df_fake_train, df_fake_valid = train_test_split(df_fake_full_train, train_size = train_valid_ratio, random_state = 1)

# Concatenate splits of different labels
df_train = pd.concat([df_real_train, df_fake_train], ignore_index=True, sort=False)
df_valid = pd.concat([df_real_valid, df_fake_valid], ignore_index=True, sort=False)
df_test = pd.concat([df_real_test, df_fake_test], ignore_index=True, sort=False)

# Write preprocessed data
df_train.loc[:, ~df_train.columns.str.contains('^Unnamed')].sample(frac= 1).to_csv(data_path + '/train.csv', index=False)
df_valid.loc[:, ~df_valid.columns.str.contains('^Unnamed')].sample(frac= 1).to_csv(data_path + '/valid.csv', index=False)
df_test.loc[:, ~df_test.columns.str.contains('^Unnamed')].sample(frac= 1).to_csv(data_path + '/test.csv', index=False)

# %%
train = pd.read_csv(data_path + '/train.csv')
train
# Out:
#                                                 Abstract  Label
# 0      A structure containing a vertical stack of int...      1
# 1      Structures and formation methods of a chip pac...      0
# 2      Provided are a compound of formula (I) or (IIa...      1
# 3      The present specification relates to a compoun...      0
# 4      A photoelectric conversion element and an opti...      0
# ...                                                  ...    ...
# 12877  A stacked-die oscillator package includes an o...      0
# 12878  Disclosed herein is an organic light-emitting ...      0
# 12879  A piezoelectric linear actuator comprising a l...      1
# 12880  An organic electroluminescent device, a method...      0
# 12881  A light emitting diode (LED) may include a fir...      1
#
# [12882 rows x 2 columns]

# %%
len(train['Abstract'][5])
# Out:
# 807

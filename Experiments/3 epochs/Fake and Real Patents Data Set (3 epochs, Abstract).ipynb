# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# import from library
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import torch
# from fake_claims_generator import generate, grab_random_prompts

# %%
#!pip3 install git+https://github.com/huggingface/transformers@v3.1.0 # there were errors in the later versions, this version allows us to do our job for now
# !pip3 install transformers==3.3.1
# Out:
# Collecting transformers==3.3.1
#   Downloading https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 5.9MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (4.41.1)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 29.7MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (1.19.5)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (20.8)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 41.6MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 42.4MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (3.0.12)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.3.1) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.0.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=7092917a8ad48098af73d25a04723fd2b8bddfb650083f00d1c558b6de5cdcfc
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc2 transformers-3.3.1

# %%
# import necessary GPT-2 model architecture and tokenizer
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts

OUTPUT_DIR = "./Models/Experiments/Abstracts/3epochs" # the model for abstract is stored here
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    '''
    This is the main generation code using our model
    '''
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ## Load Real Data and Label Them

# %%
data = pd.read_csv("./Models/Data/H04L.csv")
real_data = pd.DataFrame({"Abstract": data["abstract"]})
real_data["Label"] = 0
real_data = real_data[real_data['Abstract'].notnull()]

# %%
real_data # shows some of the real patent claims
# Out:
#                                                Abstract  Label
# 0     An organic light emitting diode display includ...      0
# 1     Provided is an electric element cooling module...      0
# 2     An organic light emitting diode display includ...      0
# 3     Provided is an electric element cooling module...      0
# 4     An organic light emitting diode display includ...      0
# ...                                                 ...    ...
# 8942  A method including patterning a continuous fin...      0
# 8943  A method including patterning a continuous fin...      0
# 8944  A method including patterning a continuous fin...      0
# 8945  A method including patterning a continuous fin...      0
# 8946  A method including patterning a continuous fin...      0
#
# [8947 rows x 2 columns]

# %% [markdown]
# ## Generate Fake Data and Label Them

# %%
# How many fake claims do you want to generate
# num_fake_claims = len(real_data)
# prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
# fake_claims = []
# for i, prompt in enumerate(prompts):
#     print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
#     generated_text = generate(prompt, n=8)
#     fake_claims.append(generated_text)

# %%
# write in chunks, and write to csv
'''
This code block is responsible for generating fake patent abstracts
I first deine the file paths where we will save the fake patent data
Then, I generate the fake patent prompts by sampling from the real abstracts
I save the prompts into a csv file.
Since I am running the generation on Colab and I'm generating thousands of fake patent abstracts,
there is a high frequency of interuption, I therefore need to save the prompts (to be accessed later),
and save the patent abstracts for every 100 that are generated.
The last_interupted variable stores where the generation was last interupted.
'''
import os.path
fake_data_file = "./Models/Experiments/Abstracts/3epochs/fake_patent_abstracts.csv"
prompt_file = "./Models/Experiments/Abstracts/3epochs/prompts.csv"
num_fake_claims = len(real_data)
if os.path.exists(prompt_file):
  prompts = pd.read_csv(prompt_file)
  prompts = prompts['Prompts'].tolist()
else:
  prompts = grab_random_prompts(data, num_fake_claims, first_words=5, column='abstract')
  # save prompts
  prompt_df = pd.DataFrame({"Prompts": prompts})
  prompt_df.to_csv(prompt_file)
fake_abstracts = []
last_interupted = 7500
for i, prompt in enumerate(prompts[last_interupted:]): # modify last_interupted if we got disconnected
    if i % 100 == 0 and i != 0: # for every 100 abstracts
      df = pd.DataFrame({"Abstract": fake_abstracts, "Label": 1})
      if os.path.exists(fake_data_file): # this means this csv is already created
        df.to_csv(fake_data_file, mode='a', header=False)
      else:
        df.to_csv(fake_data_file)
      fake_abstracts = []
    print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
    generated_text = generate(prompt, n=8)
    fake_abstracts.append(generated_text)
# last batch (that doesn't go over 100)
df = pd.DataFrame({"Claims": fake_abstracts, "Label": 1})
df.to_csv(fake_data_file, mode='a', header=False)
# Out:
# Generating Prompt 1 ... Prompt: A method of manufacturing a
# Generating Prompt 2 ... Prompt: Systems and methods for detecting
# Generating Prompt 3 ... Prompt: A light emitting diode is
# Generating Prompt 4 ... Prompt: An integrated circuit device includes
# Generating Prompt 5 ... Prompt: A data reading error is
# Generating Prompt 6 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 7 ... Prompt: A light emitting diode package
# Generating Prompt 8 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 9 ... Prompt: A substrate carrier stack includes
# Generating Prompt 10 ... Prompt: The disclosed apparatus may include
# Generating Prompt 11 ... Prompt: A semiconductor structure includes a
# Generating Prompt 12 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 13 ... Prompt: A method for manufacturing a
# Generating Prompt 14 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 15 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 16 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 17 ... Prompt: The present disclosure describes additives
# Generating Prompt 18 ... Prompt: A display apparatus includes: a
# Generating Prompt 19 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 20 ... Prompt: A composition comprising a first
# Generating Prompt 21 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 22 ... Prompt: A solid-state image pickup device
# Generating Prompt 23 ... Prompt: An organic light emitting diode
# Generating Prompt 24 ... Prompt: Methods and devices for forming
# Generating Prompt 25 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 26 ... Prompt: We describe a method for
# Generating Prompt 27 ... Prompt: A display apparatus includes a
# Generating Prompt 28 ... Prompt: [Object] To provide a method
# Generating Prompt 29 ... Prompt: A three-dimensional memory device including
# Generating Prompt 30 ... Prompt: A solid-state image pickup device
# Generating Prompt 31 ... Prompt: The disclosed apparatus may include
# Generating Prompt 32 ... Prompt: A semiconductor device includes a
# Generating Prompt 33 ... Prompt: A flexible display substrate includes
# Generating Prompt 34 ... Prompt: A reheating collection device for
# Generating Prompt 35 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 36 ... Prompt: The present disclosure describes additives
# Generating Prompt 37 ... Prompt: An organic light emitting diode
# Generating Prompt 38 ... Prompt: An organic light-emitting display including
# Generating Prompt 39 ... Prompt: A light emitting diode (LED)
# Generating Prompt 40 ... Prompt: The invention relates to an
# Generating Prompt 41 ... Prompt: An imaging system may include
# Generating Prompt 42 ... Prompt: According to one embodiment, a
# Generating Prompt 43 ... Prompt: Transistors might include first and
# Generating Prompt 44 ... Prompt: An assembly useable with a
# Generating Prompt 45 ... Prompt: Disclosed are a method for
# Generating Prompt 46 ... Prompt: An integrated circuit device includes
# Generating Prompt 47 ... Prompt: A manufacturing method of an
# Generating Prompt 48 ... Prompt: An electronic apparatus includes a
# Generating Prompt 49 ... Prompt: Methods/structures of joining package structures
# Generating Prompt 50 ... Prompt: A semiconductor memory device includes
# Generating Prompt 51 ... Prompt: The present invention relates to
# Generating Prompt 52 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 53 ... Prompt: The present invention relates to
# Generating Prompt 54 ... Prompt: An apparatus and method for
# Generating Prompt 55 ... Prompt: Disclosed are a display substrate,
# Generating Prompt 56 ... Prompt: Some embodiments include an integrated
# Generating Prompt 57 ... Prompt: A light-emitting element having high
# Generating Prompt 58 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 59 ... Prompt: A flexible substrate including a
# Generating Prompt 60 ... Prompt: A display device is described.
# Generating Prompt 61 ... Prompt: An organic light-emitting diode may
# Generating Prompt 62 ... Prompt: An emitter for an LED-based
# Generating Prompt 63 ... Prompt: A driving control method is
# Generating Prompt 64 ... Prompt: A method is provided for
# Generating Prompt 65 ... Prompt: The embodiments of the present
# Generating Prompt 66 ... Prompt: Solar cells having a plurality
# Generating Prompt 67 ... Prompt: Various embodiments of the present
# Generating Prompt 68 ... Prompt: The present disclosure discloses a
# Generating Prompt 69 ... Prompt: The disclosure relates to a
# Generating Prompt 70 ... Prompt: A structure containing a vertical
# Generating Prompt 71 ... Prompt: A method for manufacturing a
# Generating Prompt 72 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 73 ... Prompt: A display apparatus includes a
# Generating Prompt 74 ... Prompt: According to one embodiment, a
# Generating Prompt 75 ... Prompt: To provide a light-emitting element
# Generating Prompt 76 ... Prompt: The present invention discloses a
# Generating Prompt 77 ... Prompt: A light-emitting element having high
# Generating Prompt 78 ... Prompt: A semiconductor device has a
# Generating Prompt 79 ... Prompt: A light emitting diode package
# Generating Prompt 80 ... Prompt: The present invention discloses a
# Generating Prompt 81 ... Prompt: Solar cells having a plurality
# Generating Prompt 82 ... Prompt: Systems and methods for detecting
# Generating Prompt 83 ... Prompt: A method of manufacturing a
# Generating Prompt 84 ... Prompt: A display device includes a
# Generating Prompt 85 ... Prompt: A display device according to
# Generating Prompt 86 ... Prompt: A light-emitting element having high
# Generating Prompt 87 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 88 ... Prompt: An image sensor may include
# Generating Prompt 89 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 90 ... Prompt: Structures and formation methods of
# Generating Prompt 91 ... Prompt: A substrate carrier stack includes
# Generating Prompt 92 ... Prompt: The bluff body attaches to
# Generating Prompt 93 ... Prompt: The present invention provides an
# Generating Prompt 94 ... Prompt: Embodiments of this invention relate
# Generating Prompt 95 ... Prompt: A solid-state image pickup device
# Generating Prompt 96 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 97 ... Prompt: An integrated circuit device includes:
# Generating Prompt 98 ... Prompt: To provide a light-emitting element
# Generating Prompt 99 ... Prompt: An imaging element includes a
# Generating Prompt 100 ... Prompt: Methods, systems, and apparatus for
# Generating Prompt 101 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 102 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 103 ... Prompt: A display device includes a
# Generating Prompt 104 ... Prompt: An integrated circuit device includes
# Generating Prompt 105 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 106 ... Prompt: The present invention(s) is directed
# Generating Prompt 107 ... Prompt: A photoelectric conversion element and
# Generating Prompt 108 ... Prompt: A light-emitting element having high
# Generating Prompt 109 ... Prompt: An integrated circuit device includes
# Generating Prompt 110 ... Prompt: An OLED device and a
# Generating Prompt 111 ... Prompt: According to example embodiments, a
# Generating Prompt 112 ... Prompt: Disclosed herein is an organic
# Generating Prompt 113 ... Prompt: Various embodiments of the present
# Generating Prompt 114 ... Prompt: Disclosed is a pattern forming
# Generating Prompt 115 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 116 ... Prompt: A memory device includes first
# Generating Prompt 117 ... Prompt: The present specification relates to
# Generating Prompt 118 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 119 ... Prompt: A flexible display substrate includes
# Generating Prompt 120 ... Prompt: A semiconductor light emitting device
# Generating Prompt 121 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 122 ... Prompt: A display apparatus includes a
# Generating Prompt 123 ... Prompt: Apparatus and method associated with
# Generating Prompt 124 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 125 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 126 ... Prompt: Solar cells having a plurality
# Generating Prompt 127 ... Prompt: A display device includes: a
# Generating Prompt 128 ... Prompt: A composition comprising a first
# Generating Prompt 129 ... Prompt: The present disclosure relates to
# Generating Prompt 130 ... Prompt: In one embodiment, a solar
# Generating Prompt 131 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 132 ... Prompt: A display panel and a
# Generating Prompt 133 ... Prompt: According to an embodiment of
# Generating Prompt 134 ... Prompt: A flexible substrate including a
# Generating Prompt 135 ... Prompt: A change in electrical characteristics
# Generating Prompt 136 ... Prompt: The embodiments of the present
# Generating Prompt 137 ... Prompt: In a method of manufacturing
# Generating Prompt 138 ... Prompt: An OLED device and a
# Generating Prompt 139 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 140 ... Prompt: An assembly used in a
# Generating Prompt 141 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 142 ... Prompt: A light emitting diode package
# Generating Prompt 143 ... Prompt: A semiconductor device includes a
# Generating Prompt 144 ... Prompt: CMOS circuits may formed using
# Generating Prompt 145 ... Prompt: A method for manufacturing a
# Generating Prompt 146 ... Prompt: Provided are a display apparatus,
# Generating Prompt 147 ... Prompt: The present disclosure provides a
# Generating Prompt 148 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 149 ... Prompt: Disclosed is a light emitting
# Generating Prompt 150 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 151 ... Prompt: A flexible display device includes:
# Generating Prompt 152 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 153 ... Prompt: Provided are a display panel,
# Generating Prompt 154 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 155 ... Prompt: The disclosed apparatus may include
# Generating Prompt 156 ... Prompt: The present invention discloses a
# Generating Prompt 157 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 158 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 159 ... Prompt: A method of packaging CSP
# Generating Prompt 160 ... Prompt: Various embodiments of the present
# Generating Prompt 161 ... Prompt: A semiconductor device includes an
# Generating Prompt 162 ... Prompt: The disclosure relates to a
# Generating Prompt 163 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 164 ... Prompt: A heat sink assembly for
# Generating Prompt 165 ... Prompt: An imaging system may include
# Generating Prompt 166 ... Prompt: Systems and methods for detecting
# Generating Prompt 167 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 168 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 169 ... Prompt: An image sensor may include
# Generating Prompt 170 ... Prompt: A microelectronic structure includes a
# Generating Prompt 171 ... Prompt: A manufacturing method includes forming
# Generating Prompt 172 ... Prompt: Provided is an adhesive composition
# Generating Prompt 173 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 174 ... Prompt: The present disclosure provides a
# Generating Prompt 175 ... Prompt: An image detector comprises a
# Generating Prompt 176 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 177 ... Prompt: A vapor deposition mask capable
# Generating Prompt 178 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 179 ... Prompt: A memory device includes a
# Generating Prompt 180 ... Prompt: The object of the present
# Generating Prompt 181 ... Prompt: A reheating collection device for
# Generating Prompt 182 ... Prompt: A thermoelectric conversion module in
# Generating Prompt 183 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 184 ... Prompt: A solar cell includes a
# Generating Prompt 185 ... Prompt: A light-emitting element having high
# Generating Prompt 186 ... Prompt: An OLED device and a
# Generating Prompt 187 ... Prompt: An emitter for an LED-based
# Generating Prompt 188 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 189 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 190 ... Prompt: An apparatus and method for
# Generating Prompt 191 ... Prompt: A microfluidic system includes a
# Generating Prompt 192 ... Prompt: A semiconductor device includes a
# Generating Prompt 193 ... Prompt: A method is presented for
# Generating Prompt 194 ... Prompt: An organic light emitting diode
# Generating Prompt 195 ... Prompt: An organic light-emitting diode may
# Generating Prompt 196 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 197 ... Prompt: A semiconductor device includes a
# Generating Prompt 198 ... Prompt: A method of fabricating a
# Generating Prompt 199 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 200 ... Prompt: A method of manufacturing a
# Generating Prompt 201 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 202 ... Prompt: A group III-N nanowire is
# Generating Prompt 203 ... Prompt: Systems and methods for growing
# Generating Prompt 204 ... Prompt: Some embodiments include an integrated
# Generating Prompt 205 ... Prompt: Disclosed is an infrared light
# Generating Prompt 206 ... Prompt: The object of the present
# Generating Prompt 207 ... Prompt: A light-emitting element having high
# Generating Prompt 208 ... Prompt: A semiconductor package includes a
# Generating Prompt 209 ... Prompt: A change in electrical characteristics
# Generating Prompt 210 ... Prompt: A light-emitting element having high
# Generating Prompt 211 ... Prompt: Methods and devices for forming
# Generating Prompt 212 ... Prompt: The present specification relates to
# Generating Prompt 213 ... Prompt: To provide a light-emitting element
# Generating Prompt 214 ... Prompt: Disclosed herein is an organic
# Generating Prompt 215 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 216 ... Prompt: A method of manufacturing a
# Generating Prompt 217 ... Prompt: A method of manufacturing a
# Generating Prompt 218 ... Prompt: An application specific integrated circuit
# Generating Prompt 219 ... Prompt: A method for transporting a
# Generating Prompt 220 ... Prompt: An unmanned autonomous vehicle is
# Generating Prompt 221 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 222 ... Prompt: A package structure includes a
# Generating Prompt 223 ... Prompt: Provided are a display panel,
# Generating Prompt 224 ... Prompt: A vapor deposition mask capable
# Generating Prompt 225 ... Prompt: Methods, systems, and apparatus for
# Generating Prompt 226 ... Prompt: The present invention relates to
# Generating Prompt 227 ... Prompt: A display device includes a
# Generating Prompt 228 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 229 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 230 ... Prompt: A method of manufacturing a
# Generating Prompt 231 ... Prompt: Discussed is a method of
# Generating Prompt 232 ... Prompt: The present disclosure relates to
# Generating Prompt 233 ... Prompt: An image sensor includes a
# Generating Prompt 234 ... Prompt: We describe a method for
# Generating Prompt 235 ... Prompt: An assembly useable with a
# Generating Prompt 236 ... Prompt: In one embodiment, a solar
# Generating Prompt 237 ... Prompt: The present invention provides a
# Generating Prompt 238 ... Prompt: A first III-V material based
# Generating Prompt 239 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 240 ... Prompt: Proposed is a layer structure
# Generating Prompt 241 ... Prompt: Provided is a semiconductor device
# Generating Prompt 242 ... Prompt: An organic light emitting diode
# Generating Prompt 243 ... Prompt: A method of forming a
# Generating Prompt 244 ... Prompt: A light emitting diode is
# Generating Prompt 245 ... Prompt: A solar cell includes a
# Generating Prompt 246 ... Prompt: Proposed is a layer structure
# Generating Prompt 247 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 248 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 249 ... Prompt: A circuit carrier structure includes
# Generating Prompt 250 ... Prompt: A method of manufacturing a
# Generating Prompt 251 ... Prompt: A pixel array in an
# Generating Prompt 252 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 253 ... Prompt: A light emitting diode package
# Generating Prompt 254 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 255 ... Prompt: Discussed is a method of
# Generating Prompt 256 ... Prompt: The various embodiments described herein
# Generating Prompt 257 ... Prompt: A semiconductor device has a
# Generating Prompt 258 ... Prompt: An organic EL display device
# Generating Prompt 259 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 260 ... Prompt: According to one example, a
# Generating Prompt 261 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 262 ... Prompt: An object of the present
# Generating Prompt 263 ... Prompt: The present disclosure relates to
# Generating Prompt 264 ... Prompt: The present invention relates to
# Generating Prompt 265 ... Prompt: The present invention(s) is directed
# Generating Prompt 266 ... Prompt: According to one embodiment, a
# Generating Prompt 267 ... Prompt: Provided is a semiconductor device
# Generating Prompt 268 ... Prompt: A method for depositing a
# Generating Prompt 269 ... Prompt: The SCR-based ESD device has
# Generating Prompt 270 ... Prompt: An assembly useable with a
# Generating Prompt 271 ... Prompt: A data reading error is
# Generating Prompt 272 ... Prompt: A semiconductor device includes a
# Generating Prompt 273 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 274 ... Prompt: The present invention relates to
# Generating Prompt 275 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 276 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 277 ... Prompt: An etching method and a
# Generating Prompt 278 ... Prompt: A light emitting diode (LED)
# Generating Prompt 279 ... Prompt: A manufacturing method of an
# Generating Prompt 280 ... Prompt: A random number generator capable
# Generating Prompt 281 ... Prompt: A method of fabricating a
# Generating Prompt 282 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 283 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 284 ... Prompt: According to an embodiment of
# Generating Prompt 285 ... Prompt: A method of manufacturing a
# Generating Prompt 286 ... Prompt: The present invention relates generally
# Generating Prompt 287 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 288 ... Prompt: The present invention discloses a
# Generating Prompt 289 ... Prompt: A semiconductor device is provided.
# Generating Prompt 290 ... Prompt: An imaging element includes: an
# Generating Prompt 291 ... Prompt: A light-emitting element having high
# Generating Prompt 292 ... Prompt: Provided are a display apparatus,
# Generating Prompt 293 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 294 ... Prompt: An imaging element includes a
# Generating Prompt 295 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 296 ... Prompt: A semiconductor device includes a
# Generating Prompt 297 ... Prompt: An anisotropic conductive film includes,
# Generating Prompt 298 ... Prompt: An object of the present
# Generating Prompt 299 ... Prompt: The various embodiments described herein
# Generating Prompt 300 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 301 ... Prompt: A light emitting diode (LED)
# Generating Prompt 302 ... Prompt: A method of manufacturing a
# Generating Prompt 303 ... Prompt: The embodiments of the present
# Generating Prompt 304 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 305 ... Prompt: A display device includes a
# Generating Prompt 306 ... Prompt: A semiconductor structure includes an
# Generating Prompt 307 ... Prompt: An emitter for an LED-based
# Generating Prompt 308 ... Prompt: A light emitting diode package
# Generating Prompt 309 ... Prompt: Disclosed herein is an organic
# Generating Prompt 310 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 311 ... Prompt: Warping of a semiconductor wafer
# Generating Prompt 312 ... Prompt: A light emitting diode package
# Generating Prompt 313 ... Prompt: Various embodiments of the present
# Generating Prompt 314 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 315 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 316 ... Prompt: An object of the present
# Generating Prompt 317 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 318 ... Prompt: A semiconductor package includes a
# Generating Prompt 319 ... Prompt: An organic light emitting diode
# Generating Prompt 320 ... Prompt: An application specific integrated circuit
# Generating Prompt 321 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 322 ... Prompt: A group III-N nanowire is
# Generating Prompt 323 ... Prompt: The disclosed technology generally relates
# Generating Prompt 324 ... Prompt: A light-emitting element having high
# Generating Prompt 325 ... Prompt: A flexible display panel has
# Generating Prompt 326 ... Prompt: The present disclosure relates to
# Generating Prompt 327 ... Prompt: A display device includes a
# Generating Prompt 328 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 329 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 330 ... Prompt: A wafer level package that
# Generating Prompt 331 ... Prompt: A support structure for a
# Generating Prompt 332 ... Prompt: Methods and devices for forming
# Generating Prompt 333 ... Prompt: An organic light-emitting display including
# Generating Prompt 334 ... Prompt: Provided is a light-emitting device
# Generating Prompt 335 ... Prompt: Various embodiments of the present
# Generating Prompt 336 ... Prompt: The present application relates to
# Generating Prompt 337 ... Prompt: A semiconductor device includes a
# Generating Prompt 338 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 339 ... Prompt: In one embodiment, a solar
# Generating Prompt 340 ... Prompt: Systems and methods that may
# Generating Prompt 341 ... Prompt: CMOS circuits may formed using
# Generating Prompt 342 ... Prompt: A circuit carrier structure includes
# Generating Prompt 343 ... Prompt: The present disclosure provides a
# Generating Prompt 344 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 345 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 346 ... Prompt: Systems and methods for growing
# Generating Prompt 347 ... Prompt: A light emitting diode package
# Generating Prompt 348 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 349 ... Prompt: The present invention relates to
# Generating Prompt 350 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 351 ... Prompt: Provided are a display apparatus,
# Generating Prompt 352 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 353 ... Prompt: A display device, which includes
# Generating Prompt 354 ... Prompt: The present disclosure provides an
# Generating Prompt 355 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 356 ... Prompt: Semiconductor devices may include a
# Generating Prompt 357 ... Prompt: A microelectronic structure includes a
# Generating Prompt 358 ... Prompt: An embodiment includes a memory
# Generating Prompt 359 ... Prompt: Disclosed herein is an organic
# Generating Prompt 360 ... Prompt: An application specific integrated circuit
# Generating Prompt 361 ... Prompt: An organic light emitting display
# Generating Prompt 362 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 363 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 364 ... Prompt: A light emitting device and
# Generating Prompt 365 ... Prompt: The various embodiments described herein
# Generating Prompt 366 ... Prompt: A control device includes a
# Generating Prompt 367 ... Prompt: A heat sink assembly for
# Generating Prompt 368 ... Prompt: Methods and devices for forming
# Generating Prompt 369 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 370 ... Prompt: The disclosure relates to a
# Generating Prompt 371 ... Prompt: An emitter for an LED-based
# Generating Prompt 372 ... Prompt: Methods and devices for forming
# Generating Prompt 373 ... Prompt: A pressure sensor includes a
# Generating Prompt 374 ... Prompt: A display device includes a
# Generating Prompt 375 ... Prompt: An enclosure for a radiographic
# Generating Prompt 376 ... Prompt: A method is presented for
# Generating Prompt 377 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 378 ... Prompt: The various embodiments described herein
# Generating Prompt 379 ... Prompt: Various embodiments of the present
# Generating Prompt 380 ... Prompt: A display device includes a
# Generating Prompt 381 ... Prompt: A method is presented for
# Generating Prompt 382 ... Prompt: A display device includes first
# Generating Prompt 383 ... Prompt: A package structure includes a
# Generating Prompt 384 ... Prompt: A display apparatus includes a
# Generating Prompt 385 ... Prompt: To reduce influence occurring between
# Generating Prompt 386 ... Prompt: A light emitting diode is
# Generating Prompt 387 ... Prompt: An unmanned autonomous vehicle is
# Generating Prompt 388 ... Prompt: The object of the present
# Generating Prompt 389 ... Prompt: An imaging element includes a
# Generating Prompt 390 ... Prompt: A random number generator capable
# Generating Prompt 391 ... Prompt: The present disclosure relates to
# Generating Prompt 392 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 393 ... Prompt: Solar cells having a plurality
# Generating Prompt 394 ... Prompt: A display device includes a
# Generating Prompt 395 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 396 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 397 ... Prompt: We describe a method for
# Generating Prompt 398 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 399 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 400 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 401 ... Prompt: Disclosed herein are switching or
# Generating Prompt 402 ... Prompt: The present invention discloses a
# Generating Prompt 403 ... Prompt: The present invention relates to
# Generating Prompt 404 ... Prompt: An emitter for an LED-based
# Generating Prompt 405 ... Prompt: A method for manufacturing a
# Generating Prompt 406 ... Prompt: An organic light-emitting diode may
# Generating Prompt 407 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 408 ... Prompt: Provided is a display device
# Generating Prompt 409 ... Prompt: A semiconductor device includes a
# Generating Prompt 410 ... Prompt: An organic light-emitting display including
# Generating Prompt 411 ... Prompt: A method of manufacturing a
# Generating Prompt 412 ... Prompt: Solar cells having a plurality
# Generating Prompt 413 ... Prompt: The present invention relates to
# Generating Prompt 414 ... Prompt: According to example embodiments, a
# Generating Prompt 415 ... Prompt: Proposed is a layer structure
# Generating Prompt 416 ... Prompt: A three-dimensional memory device including
# Generating Prompt 417 ... Prompt: Provided is a light-emitting device
# Generating Prompt 418 ... Prompt: Proposed is a layer structure
# Generating Prompt 419 ... Prompt: Discussed is a method of
# Generating Prompt 420 ... Prompt: A flexible display panel has
# Generating Prompt 421 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 422 ... Prompt: An OLED device and a
# Generating Prompt 423 ... Prompt: Provided are a compound represented
# Generating Prompt 424 ... Prompt: A support structure for a
# Generating Prompt 425 ... Prompt: A flexible substrate including a
# Generating Prompt 426 ... Prompt: A circuit carrier structure includes
# Generating Prompt 427 ... Prompt: Methods and devices for forming
# Generating Prompt 428 ... Prompt: Provided is a semiconductor device
# Generating Prompt 429 ... Prompt: An imaging element includes: an
# Generating Prompt 430 ... Prompt: A three-dimensional memory device including
# Generating Prompt 431 ... Prompt: Embodiments of this invention relate
# Generating Prompt 432 ... Prompt: Disclosed are a method for
# Generating Prompt 433 ... Prompt: Methods, systems, and apparatus for
# Generating Prompt 434 ... Prompt: A semiconductor light emitting device
# Generating Prompt 435 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 436 ... Prompt: An organic light emitting diode
# Generating Prompt 437 ... Prompt: Disclosed is a pattern forming
# Generating Prompt 438 ... Prompt: A display device includes a
# Generating Prompt 439 ... Prompt: The disclosed apparatus may include
# Generating Prompt 440 ... Prompt: The present disclosure describes additives
# Generating Prompt 441 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 442 ... Prompt: Structures and formation methods of
# Generating Prompt 443 ... Prompt: An application specific integrated circuit
# Generating Prompt 444 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 445 ... Prompt: A method of making a
# Generating Prompt 446 ... Prompt: Discussed is a method of
# Generating Prompt 447 ... Prompt: A light-emitting element having high
# Generating Prompt 448 ... Prompt: A semiconductor device includes a
# Generating Prompt 449 ... Prompt: The present invention discloses a
# Generating Prompt 450 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 451 ... Prompt: The disclosed technology generally relates
# Generating Prompt 452 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 453 ... Prompt: An imaging element includes a
# Generating Prompt 454 ... Prompt: Systems and methods that may
# Generating Prompt 455 ... Prompt: A method of manufacturing a
# Generating Prompt 456 ... Prompt: An image sensor includes a
# Generating Prompt 457 ... Prompt: A semiconductor device and a
# Generating Prompt 458 ... Prompt: A first bent wiring has
# Generating Prompt 459 ... Prompt: An application specific integrated circuit
# Generating Prompt 460 ... Prompt: In accordance with an embodiment,
# Generating Prompt 461 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 462 ... Prompt: A change in electrical characteristics
# Generating Prompt 463 ... Prompt: An imaging element includes: an
# Generating Prompt 464 ... Prompt: The present disclosure relates to
# Generating Prompt 465 ... Prompt: An OLED device and a
# Generating Prompt 466 ... Prompt: A memory device includes first
# Generating Prompt 467 ... Prompt: The present invention relates to
# Generating Prompt 468 ... Prompt: A method is presented for
# Generating Prompt 469 ... Prompt: The disclosure provides a package
# Generating Prompt 470 ... Prompt: A method for manufacturing a
# Generating Prompt 471 ... Prompt: A group III-N nanowire is
# Generating Prompt 472 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 473 ... Prompt: Disclosed are a backplane substrate,
# Generating Prompt 474 ... Prompt: To reduce influence occurring between
# Generating Prompt 475 ... Prompt: In accordance with an embodiment,
# Generating Prompt 476 ... Prompt: A substrate carrier stack includes
# Generating Prompt 477 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 478 ... Prompt: An embodiment includes a memory
# Generating Prompt 479 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 480 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 481 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 482 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 483 ... Prompt: A data reading error is
# Generating Prompt 484 ... Prompt: The disclosure provides a package
# Generating Prompt 485 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 486 ... Prompt: The present disclosure provides an
# Generating Prompt 487 ... Prompt: An organic light-emitting diode may
# Generating Prompt 488 ... Prompt: An assembly useable with a
# Generating Prompt 489 ... Prompt: The embodiments of the present
# Generating Prompt 490 ... Prompt: An emitter for an LED-based
# Generating Prompt 491 ... Prompt: A method of fabricating a
# Generating Prompt 492 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 493 ... Prompt: An embodiment includes a memory
# Generating Prompt 494 ... Prompt: Solar cells having a plurality
# Generating Prompt 495 ... Prompt: An assembly useable with a
# Generating Prompt 496 ... Prompt: The invention relates to an
# Generating Prompt 497 ... Prompt: According to an embodiment of
# Generating Prompt 498 ... Prompt: Provided are a display panel,
# Generating Prompt 499 ... Prompt: A substrate support assembly for
# Generating Prompt 500 ... Prompt: A display apparatus includes a
# Generating Prompt 501 ... Prompt: To provide a coating fluid
# Generating Prompt 502 ... Prompt: An application specific integrated circuit
# Generating Prompt 503 ... Prompt: A high output and high
# Generating Prompt 504 ... Prompt: An enclosure for a radiographic
# Generating Prompt 505 ... Prompt: An etching method and a
# Generating Prompt 506 ... Prompt: We describe a method for
# Generating Prompt 507 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 508 ... Prompt: A display device includes a
# Generating Prompt 509 ... Prompt: A structure containing a vertical
# Generating Prompt 510 ... Prompt: According to example embodiments, a
# Generating Prompt 511 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 512 ... Prompt: A phase-change memory element is
# Generating Prompt 513 ... Prompt: The present disclosure provides a
# Generating Prompt 514 ... Prompt: Provided are a pickup sensor
# Generating Prompt 515 ... Prompt: Provided are a pickup sensor
# Generating Prompt 516 ... Prompt: The present specification relates to
# Generating Prompt 517 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 518 ... Prompt: An imaging element includes: an
# Generating Prompt 519 ... Prompt: The embodiments of the present
# Generating Prompt 520 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 521 ... Prompt: A flexible display substrate includes
# Generating Prompt 522 ... Prompt: Semiconductor devices may include a
# Generating Prompt 523 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 524 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 525 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 526 ... Prompt: A method of manufacturing a
# Generating Prompt 527 ... Prompt: The present disclosure relates to
# Generating Prompt 528 ... Prompt: A light emitting diode is
# Generating Prompt 529 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 530 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 531 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 532 ... Prompt: In accordance with an embodiment,
# Generating Prompt 533 ... Prompt: An assembly used in a
# Generating Prompt 534 ... Prompt: One aspect of the present
# Generating Prompt 535 ... Prompt: A semiconductor light emitting device
# Generating Prompt 536 ... Prompt: Disclosed herein are switching or
# Generating Prompt 537 ... Prompt: The various embodiments described herein
# Generating Prompt 538 ... Prompt: An assembly used in a
# Generating Prompt 539 ... Prompt: A method of packaging CSP
# Generating Prompt 540 ... Prompt: A semiconductor device and a
# Generating Prompt 541 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 542 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 543 ... Prompt: A group III-N nanowire is
# Generating Prompt 544 ... Prompt: Systems and methods for detecting
# Generating Prompt 545 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 546 ... Prompt: A flexible display panel, a
# Generating Prompt 547 ... Prompt: The present invention relates to
# Generating Prompt 548 ... Prompt: An assembly useable with a
# Generating Prompt 549 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 550 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 551 ... Prompt: A method of making a
# Generating Prompt 552 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 553 ... Prompt: Systems and methods for growing
# Generating Prompt 554 ... Prompt: In case of forming electrodes
# Generating Prompt 555 ... Prompt: A light emitting diode is
# Generating Prompt 556 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 557 ... Prompt: An OLED device and a
# Generating Prompt 558 ... Prompt: A flexible display substrate includes
# Generating Prompt 559 ... Prompt: A vehicle skin, such as
# Generating Prompt 560 ... Prompt: The present invention(s) is directed
# Generating Prompt 561 ... Prompt: A light emitting diode is
# Generating Prompt 562 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 563 ... Prompt: A semiconductor structure includes an
# Generating Prompt 564 ... Prompt: The present specification relates to
# Generating Prompt 565 ... Prompt: A novel and useful controlled
# Generating Prompt 566 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 567 ... Prompt: A novel and useful controlled
# Generating Prompt 568 ... Prompt: A display apparatus includes a
# Generating Prompt 569 ... Prompt: Use of transition metal complexes
# Generating Prompt 570 ... Prompt: According to one embodiment, a
# Generating Prompt 571 ... Prompt: Structures and formation methods of
# Generating Prompt 572 ... Prompt: A semiconductor device includes an
# Generating Prompt 573 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 574 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 575 ... Prompt: Structures and formation methods of
# Generating Prompt 576 ... Prompt: A light emitting diode is
# Generating Prompt 577 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 578 ... Prompt: An organic light-emitting diode may
# Generating Prompt 579 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 580 ... Prompt: An organic light emitting diode
# Generating Prompt 581 ... Prompt: A novel and useful controlled
# Generating Prompt 582 ... Prompt: A data reading error is
# Generating Prompt 583 ... Prompt: The present invention relates generally
# Generating Prompt 584 ... Prompt: A phase-change memory element is
# Generating Prompt 585 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 586 ... Prompt: A silicon carbide semiconductor device,
# Generating Prompt 587 ... Prompt: According to one example, a
# Generating Prompt 588 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 589 ... Prompt: A method for transporting a
# Generating Prompt 590 ... Prompt: A vehicle skin, such as
# Generating Prompt 591 ... Prompt: A display apparatus includes: a
# Generating Prompt 592 ... Prompt: A heat sink assembly for
# Generating Prompt 593 ... Prompt: An organic metal complex as
# Generating Prompt 594 ... Prompt: The present disclosure relates to
# Generating Prompt 595 ... Prompt: An image sensor includes a
# Generating Prompt 596 ... Prompt: An electronic device and manufacturing
# Generating Prompt 597 ... Prompt: The present invention relates to
# Generating Prompt 598 ... Prompt: An organic light-emitting device including
# Generating Prompt 599 ... Prompt: Disclosed is an infrared light
# Generating Prompt 600 ... Prompt: Disclosed is a light emitting
# Generating Prompt 601 ... Prompt: Provided are a pickup sensor
# Generating Prompt 602 ... Prompt: A semiconductor device includes a
# Generating Prompt 603 ... Prompt: A control device includes a
# Generating Prompt 604 ... Prompt: Backsheet for photovoltaic panels with
# Generating Prompt 605 ... Prompt: An imaging system may include
# Generating Prompt 606 ... Prompt: A semiconductor device includes a
# Generating Prompt 607 ... Prompt: A substrate support assembly for
# Generating Prompt 608 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 609 ... Prompt: An enclosure for a radiographic
# Generating Prompt 610 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 611 ... Prompt: The present disclosure provides a
# Generating Prompt 612 ... Prompt: A display device includes a
# Generating Prompt 613 ... Prompt: An OLED device and a
# Generating Prompt 614 ... Prompt: Provided are a pickup sensor
# Generating Prompt 615 ... Prompt: A method of manufacturing a
# Generating Prompt 616 ... Prompt: The present disclosure relates to
# Generating Prompt 617 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 618 ... Prompt: The present invention provides an
# Generating Prompt 619 ... Prompt: The present specification relates to
# Generating Prompt 620 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 621 ... Prompt: A substrate support assembly for
# Generating Prompt 622 ... Prompt: An organic metal complex as
# Generating Prompt 623 ... Prompt: A semiconductor device according to
# Generating Prompt 624 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 625 ... Prompt: A driving control method is
# Generating Prompt 626 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 627 ... Prompt: A semiconductor device includes a
# Generating Prompt 628 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 629 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 630 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 631 ... Prompt: A method of packaging CSP
# Generating Prompt 632 ... Prompt: Provided are a display apparatus,
# Generating Prompt 633 ... Prompt: Methods and devices for forming
# Generating Prompt 634 ... Prompt: An embodiment includes a memory
# Generating Prompt 635 ... Prompt: A display panel comprises a
# Generating Prompt 636 ... Prompt: Systems and methods that may
# Generating Prompt 637 ... Prompt: An integrated circuit device includes:
# Generating Prompt 638 ... Prompt: A deposition system and method
# Generating Prompt 639 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 640 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 641 ... Prompt: Provided is a semiconductor device
# Generating Prompt 642 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 643 ... Prompt: A flexible display device includes:
# Generating Prompt 644 ... Prompt: A method is provided for
# Generating Prompt 645 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 646 ... Prompt: A light-emitting element that includes
# Generating Prompt 647 ... Prompt: Disclosed herein is an organic
# Generating Prompt 648 ... Prompt: A method including patterning a
# Generating Prompt 649 ... Prompt: An OLED device and a
# Generating Prompt 650 ... Prompt: One aspect of the present
# Generating Prompt 651 ... Prompt: An imaging element includes a
# Generating Prompt 652 ... Prompt: An organic light-emitting display including
# Generating Prompt 653 ... Prompt: According to example embodiments, a
# Generating Prompt 654 ... Prompt: A semiconductor device has a
# Generating Prompt 655 ... Prompt: A novel and useful controlled
# Generating Prompt 656 ... Prompt: A TFT substrate includes a
# Generating Prompt 657 ... Prompt: The present specification relates to
# Generating Prompt 658 ... Prompt: The present invention relates to
# Generating Prompt 659 ... Prompt: Proposed is a layer structure
# Generating Prompt 660 ... Prompt: An image processing apparatus includes
# Generating Prompt 661 ... Prompt: Provided is a light-emitting device
# Generating Prompt 662 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 663 ... Prompt: An object of the invention
# Generating Prompt 664 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 665 ... Prompt: A semiconductor device has a
# Generating Prompt 666 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 667 ... Prompt: A light emitting device and
# Generating Prompt 668 ... Prompt: A heat sink assembly for
# Generating Prompt 669 ... Prompt: Disclosed are a backplane substrate,
# Generating Prompt 670 ... Prompt: An organic light emitting diode
# Generating Prompt 671 ... Prompt: According to one embodiment, a
# Generating Prompt 672 ... Prompt: A first III-V material based
# Generating Prompt 673 ... Prompt: A method of fabricating a
# Generating Prompt 674 ... Prompt: The present specification relates to
# Generating Prompt 675 ... Prompt: A semiconductor device includes a
# Generating Prompt 676 ... Prompt: The bluff body attaches to
# Generating Prompt 677 ... Prompt: An imaging element includes: an
# Generating Prompt 678 ... Prompt: An imaging system may include
# Generating Prompt 679 ... Prompt: The disclosure relates to a
# Generating Prompt 680 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 681 ... Prompt: The various embodiments described herein
# Generating Prompt 682 ... Prompt: A semiconductor device and a
# Generating Prompt 683 ... Prompt: A flexible display substrate includes
# Generating Prompt 684 ... Prompt: A method for depositing a
# Generating Prompt 685 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 686 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 687 ... Prompt: The present disclosure describes additives
# Generating Prompt 688 ... Prompt: A pixel array in an
# Generating Prompt 689 ... Prompt: A light emitting diode package
# Generating Prompt 690 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 691 ... Prompt: A supporting device includes a
# Generating Prompt 692 ... Prompt: A micro light emitting diode
# Generating Prompt 693 ... Prompt: The present specification relates to
# Generating Prompt 694 ... Prompt: An organic metal complex as
# Generating Prompt 695 ... Prompt: Methods of forming germanium channel
# Generating Prompt 696 ... Prompt: A display apparatus includes a
# Generating Prompt 697 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 698 ... Prompt: A display apparatus includes a
# Generating Prompt 699 ... Prompt: A semiconductor device includes a
# Generating Prompt 700 ... Prompt: The present disclosure relates to
# Generating Prompt 701 ... Prompt: A pressure sensor includes a
# Generating Prompt 702 ... Prompt: A supporting device includes a
# Generating Prompt 703 ... Prompt: An etching method and a
# Generating Prompt 704 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 705 ... Prompt: A deposition system and method
# Generating Prompt 706 ... Prompt: The disclosed technology generally relates
# Generating Prompt 707 ... Prompt: A display apparatus includes: a
# Generating Prompt 708 ... Prompt: The present disclosure describes additives
# Generating Prompt 709 ... Prompt: An imaging system may include
# Generating Prompt 710 ... Prompt: Systems and methods for growing
# Generating Prompt 711 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 712 ... Prompt: The present disclosure provides an
# Generating Prompt 713 ... Prompt: Various embodiments of the present
# ...
# Generating Prompt 1216 ... Prompt: An electronic device and manufacturing
# Generating Prompt 1217 ... Prompt: A pixel array in an
# Generating Prompt 1218 ... Prompt: An imaging element includes a
# Generating Prompt 1219 ... Prompt: A method is presented for
# Generating Prompt 1220 ... Prompt: Methods and devices for forming
# Generating Prompt 1221 ... Prompt: A deposition system and method
# Generating Prompt 1222 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 1223 ... Prompt: An imaging system may include
# Generating Prompt 1224 ... Prompt: A method is presented for
# Generating Prompt 1225 ... Prompt: Various embodiments of the present
# Generating Prompt 1226 ... Prompt: Systems and methods for detecting
# Generating Prompt 1227 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 1228 ... Prompt: An integrated circuit device includes
# Generating Prompt 1229 ... Prompt: The present invention relates to
# Generating Prompt 1230 ... Prompt: A pixel array in an
# Generating Prompt 1231 ... Prompt: An organic light emitting diode
# Generating Prompt 1232 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 1233 ... Prompt: A light-emitting element that includes
# Generating Prompt 1234 ... Prompt: The present disclosure discloses a
# Generating Prompt 1235 ... Prompt: An organic light emitting diode
# Generating Prompt 1236 ... Prompt: The present disclosure provides an
# Generating Prompt 1237 ... Prompt: Discussed is a method of
# Generating Prompt 1238 ... Prompt: A semiconductor device includes a
# Generating Prompt 1239 ... Prompt: An organic light emitting diode
# Generating Prompt 1240 ... Prompt: An imaging system may include
# Generating Prompt 1241 ... Prompt: Provided are a display panel,
# Generating Prompt 1242 ... Prompt: The present disclosure provides a
# Generating Prompt 1243 ... Prompt: A display apparatus includes a
# Generating Prompt 1244 ... Prompt: An organic light emitting diode
# Generating Prompt 1245 ... Prompt: In case of forming electrodes
# Generating Prompt 1246 ... Prompt: The present application relates to
# Generating Prompt 1247 ... Prompt: Methods and devices for forming
# Generating Prompt 1248 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 1249 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 1250 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 1251 ... Prompt: A photoelectric conversion element and
# Generating Prompt 1252 ... Prompt: The present invention relates to
# Generating Prompt 1253 ... Prompt: Methods and devices for forming
# Generating Prompt 1254 ... Prompt: A change in electrical characteristics
# Generating Prompt 1255 ... Prompt: A light-emitting element that includes
# Generating Prompt 1256 ... Prompt: A display device is described.
# Generating Prompt 1257 ... Prompt: To provide a light-emitting element
# Generating Prompt 1258 ... Prompt: In accordance with an embodiment,
# Generating Prompt 1259 ... Prompt: The present disclosure discloses a
# Generating Prompt 1260 ... Prompt: A novel and useful controlled
# Generating Prompt 1261 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 1262 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 1263 ... Prompt: Provided are a compound represented
# Generating Prompt 1264 ... Prompt: An application specific integrated circuit
# Generating Prompt 1265 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 1266 ... Prompt: Systems and methods for detecting
# Generating Prompt 1267 ... Prompt: A random number generator capable
# Generating Prompt 1268 ... Prompt: A composition comprising a first
# Generating Prompt 1269 ... Prompt: A backplate of a display
# Generating Prompt 1270 ... Prompt: A semiconductor device includes a
# Generating Prompt 1271 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 1272 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 1273 ... Prompt: A silicon carbide semiconductor device,
# Generating Prompt 1274 ... Prompt: Some embodiments include an integrated
# Generating Prompt 1275 ... Prompt: A change in electrical characteristics
# Generating Prompt 1276 ... Prompt: Some embodiments include an integrated
# Generating Prompt 1277 ... Prompt: A novel and useful controlled
# Generating Prompt 1278 ... Prompt: An imaging element includes a
# Generating Prompt 1279 ... Prompt: A flexible display panel has
# Generating Prompt 1280 ... Prompt: An electronic apparatus includes a
# Generating Prompt 1281 ... Prompt: The present invention discloses a
# Generating Prompt 1282 ... Prompt: A light emitting diode is
# Generating Prompt 1283 ... Prompt: The present disclosure discloses a
# Generating Prompt 1284 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 1285 ... Prompt: The present application discloses a
# Generating Prompt 1286 ... Prompt: A method of packaging CSP
# Generating Prompt 1287 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 1288 ... Prompt: A phase-change memory element is
# Generating Prompt 1289 ... Prompt: A flexible display substrate includes
# Generating Prompt 1290 ... Prompt: An organic light-emitting diode may
# Generating Prompt 1291 ... Prompt: A dynamic vision sensor (DVS)
# Generating Prompt 1292 ... Prompt: An imaging element includes a
# Generating Prompt 1293 ... Prompt: A display device includes first
# Generating Prompt 1294 ... Prompt: A light emitting diode (LED)
# Generating Prompt 1295 ... Prompt: A method of manufacturing a
# Generating Prompt 1296 ... Prompt: Proposed is a layer structure
# Generating Prompt 1297 ... Prompt: An organic light emitting device
# Generating Prompt 1298 ... Prompt: Structures and formation methods of
# Generating Prompt 1299 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 1300 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 1301 ... Prompt: We describe a method for
# Generating Prompt 1302 ... Prompt: The disclosure provides a package
# Generating Prompt 1303 ... Prompt: The present invention(s) is directed
# Generating Prompt 1304 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 1305 ... Prompt: Structures and formation methods of
# Generating Prompt 1306 ... Prompt: An imaging element includes a
# Generating Prompt 1307 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 1308 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 1309 ... Prompt: The present invention relates to
# Generating Prompt 1310 ... Prompt: An organic light-emitting device having
# Generating Prompt 1311 ... Prompt: A method of fabricating a
# Generating Prompt 1312 ... Prompt: The present invention discloses a
# Generating Prompt 1313 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 1314 ... Prompt: Provided is an adhesive composition
# Generating Prompt 1315 ... Prompt: A light-emitting element that includes
# Generating Prompt 1316 ... Prompt: An assembly used in a
# Generating Prompt 1317 ... Prompt: An imaging system may include
# Generating Prompt 1318 ... Prompt: According to one embodiment, a
# Generating Prompt 1319 ... Prompt: A semiconductor package includes a
# Generating Prompt 1320 ... Prompt: A composition comprising a first
# Generating Prompt 1321 ... Prompt: According to one embodiment, a
# Generating Prompt 1322 ... Prompt: A change in electrical characteristics
# Generating Prompt 1323 ... Prompt: An assembly used in a
# Generating Prompt 1324 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 1325 ... Prompt: A display device is described.
# Generating Prompt 1326 ... Prompt: Provided is a light-emitting device
# Generating Prompt 1327 ... Prompt: A pixel array in an
# Generating Prompt 1328 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 1329 ... Prompt: The object of the present
# Generating Prompt 1330 ... Prompt: The present disclosure provides a
# Generating Prompt 1331 ... Prompt: A novel and useful controlled
# Generating Prompt 1332 ... Prompt: A thermally conductive article including
# Generating Prompt 1333 ... Prompt: Embodiments of this invention relate
# Generating Prompt 1334 ... Prompt: A three-dimensional memory device including
# Generating Prompt 1335 ... Prompt: Semiconductor devices may include a
# Generating Prompt 1336 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 1337 ... Prompt: A photoelectric conversion element and
# Generating Prompt 1338 ... Prompt: A flexible display panel, a
# Generating Prompt 1339 ... Prompt: A microfluidic system includes a
# Generating Prompt 1340 ... Prompt: An imaging element includes: an
# Generating Prompt 1341 ... Prompt: An object of the present
# Generating Prompt 1342 ... Prompt: A first III-V material based
# Generating Prompt 1343 ... Prompt: Provided is an electric element
# Generating Prompt 1344 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 1345 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 1346 ... Prompt: A flexible display panel has
# Generating Prompt 1347 ... Prompt: A microfluidic system includes a
# Generating Prompt 1348 ... Prompt: A display device includes a
# Generating Prompt 1349 ... Prompt: A semiconductor device includes an
# Generating Prompt 1350 ... Prompt: Discussed is a method of
# Generating Prompt 1351 ... Prompt: A display apparatus includes a
# Generating Prompt 1352 ... Prompt: Provided is a semiconductor device
# Generating Prompt 1353 ... Prompt: A data reading error is
# Generating Prompt 1354 ... Prompt: An emitter for an LED-based
# Generating Prompt 1355 ... Prompt: A first III-V material based
# Generating Prompt 1356 ... Prompt: An organic light emitting device
# Generating Prompt 1357 ... Prompt: A semiconductor package includes a
# Generating Prompt 1358 ... Prompt: An assembly used in a
# Generating Prompt 1359 ... Prompt: A microfluidic system includes a
# Generating Prompt 1360 ... Prompt: An organic light emitting diode
# Generating Prompt 1361 ... Prompt: An object of the invention
# Generating Prompt 1362 ... Prompt: A semiconductor device includes a
# Generating Prompt 1363 ... Prompt: An object of the present
# Generating Prompt 1364 ... Prompt: A light emitting device and
# Generating Prompt 1365 ... Prompt: Semiconductor devices may include a
# Generating Prompt 1366 ... Prompt: A display apparatus includes: a
# Generating Prompt 1367 ... Prompt: The present invention relates to
# Generating Prompt 1368 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 1369 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 1370 ... Prompt: An imaging unit includes: an
# Generating Prompt 1371 ... Prompt: CMOS circuits may formed using
# Generating Prompt 1372 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 1373 ... Prompt: A flexible display substrate includes
# Generating Prompt 1374 ... Prompt: A display apparatus includes a
# Generating Prompt 1375 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 1376 ... Prompt: An image sensor includes a
# Generating Prompt 1377 ... Prompt: An organic light emitting display
# Generating Prompt 1378 ... Prompt: A bipolar complementary metal oxide
# Generating Prompt 1379 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 1380 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 1381 ... Prompt: Disclosed is an infrared light
# Generating Prompt 1382 ... Prompt: Semiconductor devices may include a
# Generating Prompt 1383 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 1384 ... Prompt: Disclosed herein is an organic
# Generating Prompt 1385 ... Prompt: An integrated circuit device includes
# Generating Prompt 1386 ... Prompt: A method of fabricating a
# Generating Prompt 1387 ... Prompt: Provided is an electric element
# Generating Prompt 1388 ... Prompt: A semiconductor device includes a
# Generating Prompt 1389 ... Prompt: An image sensor includes a
# Generating Prompt 1390 ... Prompt: The present disclosure describes additives
# Generating Prompt 1391 ... Prompt: An organic EL display device
# Generating Prompt 1392 ... Prompt: The disclosure provides a package
# Generating Prompt 1393 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 1394 ... Prompt: The present invention relates generally
# Generating Prompt 1395 ... Prompt: A supporting device includes a
# Generating Prompt 1396 ... Prompt: An organic EL display device
# Generating Prompt 1397 ... Prompt: An electronic component mounting board
# Generating Prompt 1398 ... Prompt: A group III-N nanowire is
# Generating Prompt 1399 ... Prompt: A semiconductor device includes an
# Generating Prompt 1400 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 1401 ... Prompt: The present invention discloses a
# Generating Prompt 1402 ... Prompt: A photoelectric conversion element and
# Generating Prompt 1403 ... Prompt: Disclosed are a display substrate,
# Generating Prompt 1404 ... Prompt: Proposed is a layer structure
# Generating Prompt 1405 ... Prompt: A pixel array in an
# Generating Prompt 1406 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 1407 ... Prompt: An organic light-emitting diode may
# Generating Prompt 1408 ... Prompt: An electronic apparatus includes a
# Generating Prompt 1409 ... Prompt: A memory device includes first
# Generating Prompt 1410 ... Prompt: A vehicle skin, such as
# Generating Prompt 1411 ... Prompt: The present invention relates to
# Generating Prompt 1412 ... Prompt: Provided are a compound represented
# Generating Prompt 1413 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 1414 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 1415 ... Prompt: A first bent wiring has
# Generating Prompt 1416 ... Prompt: Warping of a semiconductor wafer
# Generating Prompt 1417 ... Prompt: A method of manufacturing a
# Generating Prompt 1418 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 1419 ... Prompt: The present invention relates to
# Generating Prompt 1420 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 1421 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 1422 ... Prompt: A semiconductor device includes a
# Generating Prompt 1423 ... Prompt: It is an object of
# Generating Prompt 1424 ... Prompt: An object of the invention
# Generating Prompt 1425 ... Prompt: To provide a coating fluid
# Generating Prompt 1426 ... Prompt: An organic light emitting diode
# Generating Prompt 1427 ... Prompt: The present invention(s) is directed
# Generating Prompt 1428 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 1429 ... Prompt: Described herein are polishing compositions
# Generating Prompt 1430 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 1431 ... Prompt: A display device is described.
# Generating Prompt 1432 ... Prompt: Provided are a display panel,
# Generating Prompt 1433 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 1434 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 1435 ... Prompt: Disclosed herein is an organic
# Generating Prompt 1436 ... Prompt: In one embodiment, a surface
# Generating Prompt 1437 ... Prompt: Provided are a compound represented
# Generating Prompt 1438 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 1439 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 1440 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 1441 ... Prompt: The various embodiments described herein
# Generating Prompt 1442 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 1443 ... Prompt: An application specific integrated circuit
# Generating Prompt 1444 ... Prompt: An OLED device and a
# Generating Prompt 1445 ... Prompt: Disclosed herein is an organic
# Generating Prompt 1446 ... Prompt: A data reading error is
# Generating Prompt 1447 ... Prompt: In a described example, a

# %%
fake_data = pd.read_csv("./Models/Experiments/Abstracts/3epochs/fake_patent_abstracts.csv")
fake_data = fake_data.loc[:, ~fake_data.columns.str.contains('^Unnamed')]
fake_data
# Out:
#                                                Abstract  Label
# 0     Protective dielectrics are discussed generally...      1
# 1     The disclosed technology generally relates to ...      1
# 2     An ultraviolet light-emitting device including...      1
# 3     A HDR CTIA pixel which provides automatic gain...      1
# 4     Quantum dot polymer composites for      inter-...      1
# ...                                                 ...    ...
# 8942  An application specific integrated circuit (AS...      1
# 8943  An OLED device and a method of manufacturing t...      1
# 8944  Disclosed herein is an organic      semiconduc...      1
# 8945  A data reading error is reduced. The data read...      1
# 8946  In a described example, a      manufacturing m...      1
#
# [8947 rows x 2 columns]

# %%
len(fake_data)
# Out:
# 8947

# %%
fake_prompts = pd.read_csv("./Models/Experiments/Abstracts/3epochs/prompts.csv")

# %%
fake_data['Abstract'][0]
# Out:
# 'Protective dielectrics are discussed generally herein. In one or more exemplary embodiments, one or more epitaxial or      semiconductor-on-insulator-die (OEL) capacitive modules (150),     particularly suitable for RF filters, are formed on the order of nanometers or.     nm. In one or more exemplary embodiments, a III-V or V-N material may      be formed on the order of 1 nm. <EOS>\n<BOS> An organic light emitting diode and an organic light emitting display      panel, the organic light emitting diode including an anode disposed on a      base layer; a first organic light emitting layer disposed on the anode; a      cathode disposed on the first organic light emitting layer; and an      electron control layer disposed between the first organic light emitting      layer and the cathode, the electron control layer including ytterbium,      wherein the cathode includes a first inorganic compound layer contacting      the electron control layer to form a P-N junction with the electron'

# %%
fake_prompts['Prompts'][0]
# Out:
# 'Protective dielectrics are discussed generally'

# %%
frames = [real_data, fake_data]
full_data = pd.concat(frames)


full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data
# Out:
#                                                 Abstract  Label
# 0      An analog-to-digital converter is provided. Th...      0
# 1      An apparatus comprising: a module; a substrate...      0
# 2      Disclosed herein is an organic light-emitting ...      0
# 3      A piezoelectric linear actuator comprising a l...      0
# 4      A semiconductor device includes a first      c...      1
# ...                                                  ...    ...
# 17889  An organic light emitting diode display includ...      0
# 17890  A semiconductor device of an     embodiment in...      1
# 17891  A MEMS IR sensor, with a cavity in a substrate...      0
# 17892  A process for producing a light emitting unit ...      1
# 17893  The invention relates to an organic molecule, ...      0
#
# [17894 rows x 2 columns]

# %%
# Out:
# 'Embodiments of the present disclosure include methods and      configurations for an image sensor capable of simultaneous integration of      electrons and holes. According to one example, the image sensor can process      signals emitted from holes split into mutually different sub-lenses that are      indistinguishable at multiple wavelengths. <EOS>\n<BOS> A semiconductor device is provided. The semiconductor device includes a      carrier. The carrier includes a first region. The first region includes      holes. The carrier further includes an oxygen exchange layer (OEL) between      the first region and the OEL. The oxygen exchange layer includes a first portion      of a trench that extends in a first direction crossing the horizontal      direction, and a second portion that is in a second direction crossing the      horizontal direction and extending in a third direction crossing the      horizontal direction. A distance between an edge of the first region and an edge      of the second region in a first direction direction that is not      overlapping the first direction is equal to or greater than'

# %%
full_data.to_csv("./Models/Experiments/Abstracts/3epochs/real_fake_claims.csv")

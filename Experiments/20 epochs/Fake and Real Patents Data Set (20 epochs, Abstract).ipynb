# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# import from library
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import torch
# from fake_claims_generator import generate, grab_random_prompts

# %%
#!pip3 install git+https://github.com/huggingface/transformers@v3.1.0 # there were errors in the later versions, this version allows us to do our job for now
# !pip3 install transformers==3.3.1
# Out:
# Collecting transformers==3.3.1
#   Downloading https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 16.5MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (0.8)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 56.4MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (20.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2.23.0)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 54.1MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (1.19.5)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 56.6MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2019.12.20)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.3.1) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (3.0.4)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=f3ef31f1722504c7364f12c063dc667f31f51bc1ac0bfc78e557552c218190f3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, sentencepiece, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc2 transformers-3.3.1

# %%
# import necessary GPT-2 model architecture and tokenizer
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts

OUTPUT_DIR = "./Models/Experiments/Abstracts/20epochs" # the model for abstract is stored here
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    '''
    This is the main generation code using our model
    '''
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ## Load Real Data and Label Them

# %%
data = pd.read_csv("./Models/Data/H01L.csv")
real_data = pd.DataFrame({"Abstract": data["abstract"]})
real_data["Label"] = 0
real_data = real_data[real_data['Abstract'].notnull()]

# %%
real_data
# Out:
#                                                Abstract  Label
# 0     An organic light emitting diode display includ...      0
# 1     Provided is an electric element cooling module...      0
# 2     An organic light emitting diode display includ...      0
# 3     Provided is an electric element cooling module...      0
# 4     An organic light emitting diode display includ...      0
# ...                                                 ...    ...
# 8942  A method including patterning a continuous fin...      0
# 8943  A method including patterning a continuous fin...      0
# 8944  A method including patterning a continuous fin...      0
# 8945  A method including patterning a continuous fin...      0
# 8946  A method including patterning a continuous fin...      0
#
# [8947 rows x 2 columns]

# %% [markdown]
# ## Generate Fake Data and Label Them

# %%
# How many fake claims do you want to generate
# num_fake_claims = len(real_data)
# prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
# fake_claims = []
# for i, prompt in enumerate(prompts):
#     print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
#     generated_text = generate(prompt, n=8)
#     fake_claims.append(generated_text)

# %%
# write in chunks, and write to csv
'''
This code block is responsible for generating fake patent abstracts
I first deine the file paths where we will save the fake patent data
Then, I generate the fake patent prompts by sampling from the real abstracts
I save the prompts into a csv file.
Since I am running the generation on Colab and I'm generating thousands of fake patent abstracts,
there is a high frequency of interuption, I therefore need to save the prompts (to be accessed later),
and save the patent abstracts for every 100 that are generated.
The last_interupted variable stores where the generation was last interupted.
'''
import os.path
fake_data_file = "./Models/Experiments/Abstracts/20epochs/fake_patent_abstracts.csv"
prompt_file = "./Models/Experiments/Abstracts/20epochs/prompts.csv"
num_fake_claims = len(real_data)
if os.path.exists(prompt_file):
  prompts = pd.read_csv(prompt_file)
  prompts = prompts['Prompts'].tolist()
else:
  prompts = grab_random_prompts(data, num_fake_claims, first_words=5, column='abstract')
  # save prompts
  prompt_df = pd.DataFrame({"Prompts": prompts})
  prompt_df.to_csv(prompt_file)
fake_abstracts = []
last_interupted = 5100
for i, prompt in enumerate(prompts[last_interupted:]): # modify last_interupted if we got disconnected
    if i % 100 == 0 and i != 0: # for every 100 abstracts
      df = pd.DataFrame({"Abstract": fake_abstracts, "Label": 1})
      if os.path.exists(fake_data_file): # this means this csv is already created
        df.to_csv(fake_data_file, mode='a', header=False)
      else:
        df.to_csv(fake_data_file)
      fake_abstracts = []
    print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
    generated_text = generate(prompt, n=8)
    fake_abstracts.append(generated_text)
# last batch (that doesn't go over 100)
df = pd.DataFrame({"Claims": fake_abstracts, "Label": 1})
df.to_csv(fake_data_file, mode='a', header=False)
# Out:
# Generating Prompt 1 ... Prompt: A method of fabricating a
# Generating Prompt 2 ... Prompt: To provide a light-emitting element
# Generating Prompt 3 ... Prompt: A light emitting diode (LED)
# Generating Prompt 4 ... Prompt: A device includes a substrate
# Generating Prompt 5 ... Prompt: The present invention relates to
# Generating Prompt 6 ... Prompt: A silicon carbide semiconductor device,
# Generating Prompt 7 ... Prompt: The present invention discloses a
# Generating Prompt 8 ... Prompt: An assembly useable with a
# Generating Prompt 9 ... Prompt: Disclosed are a backplane substrate,
# Generating Prompt 10 ... Prompt: One aspect of the present
# Generating Prompt 11 ... Prompt: The present application discloses a
# Generating Prompt 12 ... Prompt: An organic light emitting device
# Generating Prompt 13 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 14 ... Prompt: An electronic apparatus that is
# Generating Prompt 15 ... Prompt: According to example embodiments, a
# Generating Prompt 16 ... Prompt: The present invention relates to
# Generating Prompt 17 ... Prompt: Various embodiments of the present
# Generating Prompt 18 ... Prompt: Provided are a display panel,
# Generating Prompt 19 ... Prompt: A method for depositing a
# Generating Prompt 20 ... Prompt: A flexible display panel has
# Generating Prompt 21 ... Prompt: An organic light emitting diode
# Generating Prompt 22 ... Prompt: An integrated circuit device includes
# Generating Prompt 23 ... Prompt: An organic light emitting device
# Generating Prompt 24 ... Prompt: A semiconductor package includes a
# Generating Prompt 25 ... Prompt: An integrated circuit device includes
# Generating Prompt 26 ... Prompt: The present disclosure relates to
# Generating Prompt 27 ... Prompt: The present disclosure relates to
# Generating Prompt 28 ... Prompt: A composition comprising a first
# Generating Prompt 29 ... Prompt: A solid-state image pickup device
# Generating Prompt 30 ... Prompt: According to one embodiment, a
# Generating Prompt 31 ... Prompt: An unmanned autonomous vehicle is
# Generating Prompt 32 ... Prompt: A microelectronic structure includes a
# Generating Prompt 33 ... Prompt: The present disclosure provides an
# Generating Prompt 34 ... Prompt: We describe a method for
# Generating Prompt 35 ... Prompt: Provided are a pickup sensor
# Generating Prompt 36 ... Prompt: Systems and methods for detecting
# Generating Prompt 37 ... Prompt: A pixel array in an
# Generating Prompt 38 ... Prompt: The disclosure provides a package
# Generating Prompt 39 ... Prompt: A light emitting diode (LED)
# Generating Prompt 40 ... Prompt: An organic light emitting diode
# Generating Prompt 41 ... Prompt: According to one embodiment, a
# Generating Prompt 42 ... Prompt: A display apparatus includes: a
# Generating Prompt 43 ... Prompt: An organic light emitting diode
# Generating Prompt 44 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 45 ... Prompt: [Object] To provide a method
# Generating Prompt 46 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 47 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 48 ... Prompt: Some embodiments include an integrated
# Generating Prompt 49 ... Prompt: An electronic apparatus includes a
# Generating Prompt 50 ... Prompt: A display device includes a
# Generating Prompt 51 ... Prompt: An unmanned autonomous vehicle is
# Generating Prompt 52 ... Prompt: A light emitting diode package
# Generating Prompt 53 ... Prompt: A thermoelectric conversion module in
# Generating Prompt 54 ... Prompt: An organic light emitting device
# Generating Prompt 55 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 56 ... Prompt: The present disclosure provides an
# Generating Prompt 57 ... Prompt: A change in electrical characteristics
# Generating Prompt 58 ... Prompt: A structure containing a vertical
# Generating Prompt 59 ... Prompt: A substrate support assembly for
# Generating Prompt 60 ... Prompt: A method of manufacturing a
# Generating Prompt 61 ... Prompt: A display device includes a
# Generating Prompt 62 ... Prompt: A solar cell includes a
# Generating Prompt 63 ... Prompt: A flexible display panel has
# Generating Prompt 64 ... Prompt: The various embodiments described herein
# Generating Prompt 65 ... Prompt: Provided are a display panel,
# Generating Prompt 66 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 67 ... Prompt: A flexible display substrate includes
# Generating Prompt 68 ... Prompt: A method of manufacturing a
# Generating Prompt 69 ... Prompt: The present disclosure relates to
# Generating Prompt 70 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 71 ... Prompt: A display panel and a
# Generating Prompt 72 ... Prompt: Systems and methods that may
# Generating Prompt 73 ... Prompt: A system for surface patterning
# Generating Prompt 74 ... Prompt: There is provided a barrier
# Generating Prompt 75 ... Prompt: An application specific integrated circuit
# Generating Prompt 76 ... Prompt: A semiconductor device and a
# Generating Prompt 77 ... Prompt: An object of the invention
# Generating Prompt 78 ... Prompt: It is an object of
# Generating Prompt 79 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 80 ... Prompt: A method of forming a
# Generating Prompt 81 ... Prompt: The disclosure provides a package
# Generating Prompt 82 ... Prompt: An organic light emitting diode
# Generating Prompt 83 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 84 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 85 ... Prompt: A three-dimensional memory device including
# Generating Prompt 86 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 87 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 88 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 89 ... Prompt: The various embodiments described herein
# Generating Prompt 90 ... Prompt: A method is provided for
# Generating Prompt 91 ... Prompt: A semiconductor device and a
# Generating Prompt 92 ... Prompt: A display device includes first
# Generating Prompt 93 ... Prompt: A semiconductor device and a
# Generating Prompt 94 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 95 ... Prompt: The present invention discloses a
# Generating Prompt 96 ... Prompt: An organic light-emitting device having
# Generating Prompt 97 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 98 ... Prompt: An organic light-emitting display including
# Generating Prompt 99 ... Prompt: Methods, systems, and apparatus for
# Generating Prompt 100 ... Prompt: A method of manufacturing a
# Generating Prompt 101 ... Prompt: To reduce influence occurring between
# Generating Prompt 102 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 103 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 104 ... Prompt: A semiconductor package includes a
# Generating Prompt 105 ... Prompt: A data reading error is
# Generating Prompt 106 ... Prompt: An assembly useable with a
# Generating Prompt 107 ... Prompt: A semiconductor device includes a
# Generating Prompt 108 ... Prompt: A random number generator capable
# Generating Prompt 109 ... Prompt: Various embodiments of the present
# Generating Prompt 110 ... Prompt: The present specification relates to
# Generating Prompt 111 ... Prompt: A display apparatus includes a
# Generating Prompt 112 ... Prompt: An imaging element includes: an
# Generating Prompt 113 ... Prompt: Disclosed are a method for
# Generating Prompt 114 ... Prompt: A flexible display panel, a
# Generating Prompt 115 ... Prompt: A semiconductor structure includes a
# Generating Prompt 116 ... Prompt: A high output and high
# Generating Prompt 117 ... Prompt: Structures and formation methods of
# Generating Prompt 118 ... Prompt: An organic light-emitting device including
# Generating Prompt 119 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 120 ... Prompt: To provide a coating fluid
# Generating Prompt 121 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 122 ... Prompt: Provided are a display panel,
# Generating Prompt 123 ... Prompt: The present disclosure provides a
# Generating Prompt 124 ... Prompt: A TFT substrate includes a
# Generating Prompt 125 ... Prompt: Embodiments of this invention relate
# Generating Prompt 126 ... Prompt: In one embodiment, a solar
# Generating Prompt 127 ... Prompt: A method of manufacturing a
# Generating Prompt 128 ... Prompt: An organic light-emitting diode may
# Generating Prompt 129 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 130 ... Prompt: In case of forming electrodes
# Generating Prompt 131 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 132 ... Prompt: A light emitting diode (LED)
# Generating Prompt 133 ... Prompt: A semiconductor package includes a
# Generating Prompt 134 ... Prompt: A flexible display panel has
# Generating Prompt 135 ... Prompt: A pressure sensor includes a
# Generating Prompt 136 ... Prompt: A method of manufacturing a
# Generating Prompt 137 ... Prompt: A substrate support assembly for
# Generating Prompt 138 ... Prompt: An image sensor includes a
# Generating Prompt 139 ... Prompt: The present disclosure relates to
# Generating Prompt 140 ... Prompt: The disclosed apparatus may include
# Generating Prompt 141 ... Prompt: A light-emitting element having high
# Generating Prompt 142 ... Prompt: A change in electrical characteristics
# Generating Prompt 143 ... Prompt: A hermetic capsule including a
# Generating Prompt 144 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 145 ... Prompt: A flexible display panel has
# Generating Prompt 146 ... Prompt: Provided is a display device
# Generating Prompt 147 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 148 ... Prompt: A display apparatus includes: a
# Generating Prompt 149 ... Prompt: In accordance with an embodiment,
# Generating Prompt 150 ... Prompt: An image processing apparatus includes
# Generating Prompt 151 ... Prompt: A light emitting diode package
# Generating Prompt 152 ... Prompt: According to one example, a
# Generating Prompt 153 ... Prompt: A thermoelectric conversion module in
# Generating Prompt 154 ... Prompt: A composition comprising a first
# Generating Prompt 155 ... Prompt: To reduce influence occurring between
# Generating Prompt 156 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 157 ... Prompt: Provided are a compound of
# Generating Prompt 158 ... Prompt: The present disclosure provides a
# Generating Prompt 159 ... Prompt: An application specific integrated circuit
# Generating Prompt 160 ... Prompt: A flexible display substrate includes
# Generating Prompt 161 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 162 ... Prompt: A circuit carrier structure includes
# Generating Prompt 163 ... Prompt: The present invention relates to
# Generating Prompt 164 ... Prompt: An electronic apparatus includes a
# Generating Prompt 165 ... Prompt: A light emitting diode package
# Generating Prompt 166 ... Prompt: A semiconductor device includes a
# Generating Prompt 167 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 168 ... Prompt: Various embodiments of the present
# Generating Prompt 169 ... Prompt: A microelectronic structure includes a
# Generating Prompt 170 ... Prompt: A flexible display substrate includes
# Generating Prompt 171 ... Prompt: A light emitting diode package
# Generating Prompt 172 ... Prompt: A microfluidic system includes a
# Generating Prompt 173 ... Prompt: An apparatus and method for
# Generating Prompt 174 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 175 ... Prompt: A display device includes a
# Generating Prompt 176 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 177 ... Prompt: The present specification relates to
# Generating Prompt 178 ... Prompt: According to an embodiment of
# Generating Prompt 179 ... Prompt: Various embodiments of the present
# Generating Prompt 180 ... Prompt: A first III-V material based
# Generating Prompt 181 ... Prompt: A semiconductor device includes a
# Generating Prompt 182 ... Prompt: The present disclosure relates to
# Generating Prompt 183 ... Prompt: A random number generator capable
# Generating Prompt 184 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 185 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 186 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 187 ... Prompt: To provide a light-emitting element
# Generating Prompt 188 ... Prompt: A semiconductor device of an
# Generating Prompt 189 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 190 ... Prompt: A package structure includes a
# Generating Prompt 191 ... Prompt: Provided are a display apparatus,
# Generating Prompt 192 ... Prompt: A light-emitting element having high
# Generating Prompt 193 ... Prompt: A flexible display panel has
# Generating Prompt 194 ... Prompt: The disclosure provides a package
# Generating Prompt 195 ... Prompt: Structures and formation methods of
# Generating Prompt 196 ... Prompt: A semiconductor structure includes a
# Generating Prompt 197 ... Prompt: Solar cells having a plurality
# Generating Prompt 198 ... Prompt: According to one embodiment, a
# Generating Prompt 199 ... Prompt: An organic light emitting diode
# Generating Prompt 200 ... Prompt: An organic EL display device
# Generating Prompt 201 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 202 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 203 ... Prompt: An application specific integrated circuit
# Generating Prompt 204 ... Prompt: The present disclosure relates to
# Generating Prompt 205 ... Prompt: A method of packaging CSP
# Generating Prompt 206 ... Prompt: An integrated circuit device includes
# Generating Prompt 207 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 208 ... Prompt: According to one embodiment, a
# Generating Prompt 209 ... Prompt: We describe a method for
# Generating Prompt 210 ... Prompt: The present disclosure provides a
# Generating Prompt 211 ... Prompt: A system for surface patterning
# Generating Prompt 212 ... Prompt: To provide a coating fluid
# Generating Prompt 213 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 214 ... Prompt: The disclosed technology generally relates
# Generating Prompt 215 ... Prompt: The present application discloses a
# Generating Prompt 216 ... Prompt: A data reading error is
# Generating Prompt 217 ... Prompt: A semiconductor device and a
# Generating Prompt 218 ... Prompt: An application specific integrated circuit
# Generating Prompt 219 ... Prompt: A vehicle skin, such as
# Generating Prompt 220 ... Prompt: A high output and high
# Generating Prompt 221 ... Prompt: A display device includes: a
# Generating Prompt 222 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 223 ... Prompt: Disclosed are a method for
# Generating Prompt 224 ... Prompt: According to one embodiment, a
# Generating Prompt 225 ... Prompt: Use of transition metal complexes
# Generating Prompt 226 ... Prompt: A support structure for a
# Generating Prompt 227 ... Prompt: A method of manufacturing a
# Generating Prompt 228 ... Prompt: A flexible display panel has
# Generating Prompt 229 ... Prompt: A method of fabricating a
# Generating Prompt 230 ... Prompt: A display device includes a
# Generating Prompt 231 ... Prompt: Semiconductor devices may include a
# Generating Prompt 232 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 233 ... Prompt: A light emitting diode is
# Generating Prompt 234 ... Prompt: [Object] To provide a method
# Generating Prompt 235 ... Prompt: An application specific integrated circuit
# Generating Prompt 236 ... Prompt: The embodiments of the present
# Generating Prompt 237 ... Prompt: A display apparatus includes a
# Generating Prompt 238 ... Prompt: A method of manufacturing a
# Generating Prompt 239 ... Prompt: A microfluidic system includes a
# Generating Prompt 240 ... Prompt: An assembly used in a
# Generating Prompt 241 ... Prompt: A group III-N nanowire is
# Generating Prompt 242 ... Prompt: We describe a method for
# Generating Prompt 243 ... Prompt: Discussed is a method of
# Generating Prompt 244 ... Prompt: A display apparatus includes: a
# Generating Prompt 245 ... Prompt: A driving control method is
# Generating Prompt 246 ... Prompt: An embodiment includes a memory
# Generating Prompt 247 ... Prompt: A semiconductor package includes a
# Generating Prompt 248 ... Prompt: Provided is a light-emitting device
# Generating Prompt 249 ... Prompt: The present disclosure provides an
# Generating Prompt 250 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 251 ... Prompt: Systems and methods for detecting
# Generating Prompt 252 ... Prompt: A structure containing a vertical
# Generating Prompt 253 ... Prompt: An electronic device and manufacturing
# Generating Prompt 254 ... Prompt: A light-emitting semiconductor chip and
# Generating Prompt 255 ... Prompt: Some embodiments include an integrated
# Generating Prompt 256 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 257 ... Prompt: Provided is a semiconductor device
# Generating Prompt 258 ... Prompt: The present invention relates to
# Generating Prompt 259 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 260 ... Prompt: Disclosed is an infrared light
# Generating Prompt 261 ... Prompt: A method of fabricating a
# Generating Prompt 262 ... Prompt: In accordance with an embodiment,
# Generating Prompt 263 ... Prompt: A display device includes first
# Generating Prompt 264 ... Prompt: A phase-change memory element is
# Generating Prompt 265 ... Prompt: A semiconductor memory device includes
# Generating Prompt 266 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 267 ... Prompt: Disclosed are a method for
# Generating Prompt 268 ... Prompt: In a method of manufacturing
# Generating Prompt 269 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 270 ... Prompt: Methods of forming germanium channel
# Generating Prompt 271 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 272 ... Prompt: An application specific integrated circuit
# Generating Prompt 273 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 274 ... Prompt: A method for transporting a
# Generating Prompt 275 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 276 ... Prompt: Provided is an electric element
# Generating Prompt 277 ... Prompt: A light-emitting element having high
# Generating Prompt 278 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 279 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 280 ... Prompt: Docking platforms formed in one
# Generating Prompt 281 ... Prompt: Embodiments are directed to a
# Generating Prompt 282 ... Prompt: An electronic apparatus includes a
# Generating Prompt 283 ... Prompt: Docking platforms formed in one
# Generating Prompt 284 ... Prompt: An assembly useable with a
# Generating Prompt 285 ... Prompt: An object of the present
# Generating Prompt 286 ... Prompt: A vehicle skin, such as
# Generating Prompt 287 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 288 ... Prompt: An organic light emitting display
# Generating Prompt 289 ... Prompt: The present invention provides a
# Generating Prompt 290 ... Prompt: A vehicle skin, such as
# Generating Prompt 291 ... Prompt: An electronic component mounting board
# Generating Prompt 292 ... Prompt: An array substrate, a method
# Generating Prompt 293 ... Prompt: A method for manufacturing a
# Generating Prompt 294 ... Prompt: A semiconductor light emitting device
# Generating Prompt 295 ... Prompt: A display apparatus includes: a
# Generating Prompt 296 ... Prompt: An organic light-emitting device including
# Generating Prompt 297 ... Prompt: An application specific integrated circuit
# Generating Prompt 298 ... Prompt: A semiconductor package includes a
# Generating Prompt 299 ... Prompt: The present invention discloses a
# Generating Prompt 300 ... Prompt: To provide a coating fluid
# Generating Prompt 301 ... Prompt: The present specification relates to
# Generating Prompt 302 ... Prompt: An organic metal complex as
# Generating Prompt 303 ... Prompt: In one embodiment, a solar
# Generating Prompt 304 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 305 ... Prompt: An emitter for an LED-based
# Generating Prompt 306 ... Prompt: A microfluidic system includes a
# Generating Prompt 307 ... Prompt: The disclosed apparatus may include
# Generating Prompt 308 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 309 ... Prompt: To provide a coating fluid
# Generating Prompt 310 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 311 ... Prompt: Provided are a compound represented
# Generating Prompt 312 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 313 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 314 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 315 ... Prompt: An application specific integrated circuit
# Generating Prompt 316 ... Prompt: The present invention(s) is directed
# Generating Prompt 317 ... Prompt: A method is presented for
# Generating Prompt 318 ... Prompt: The present invention relates to
# Generating Prompt 319 ... Prompt: It is an object of
# Generating Prompt 320 ... Prompt: According to one embodiment, a
# Generating Prompt 321 ... Prompt: A method of fabricating a
# Generating Prompt 322 ... Prompt: Systems and methods for growing
# Generating Prompt 323 ... Prompt: A display device includes a
# Generating Prompt 324 ... Prompt: Provided are a display panel,
# Generating Prompt 325 ... Prompt: Disclosed is a light emitting
# Generating Prompt 326 ... Prompt: Disclosed herein is an organic
# Generating Prompt 327 ... Prompt: The present disclosure provides a
# Generating Prompt 328 ... Prompt: Various embodiments of the present
# Generating Prompt 329 ... Prompt: An application specific integrated circuit
# Generating Prompt 330 ... Prompt: An integrated circuit device includes
# Generating Prompt 331 ... Prompt: An image sensor may include
# Generating Prompt 332 ... Prompt: An organic EL display device
# Generating Prompt 333 ... Prompt: A process for producing a
# Generating Prompt 334 ... Prompt: A semiconductor package includes a
# Generating Prompt 335 ... Prompt: A microelectronic structure includes a
# Generating Prompt 336 ... Prompt: A substrate support assembly for
# Generating Prompt 337 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 338 ... Prompt: A first bent wiring has
# Generating Prompt 339 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 340 ... Prompt: Embodiments of a method and
# Generating Prompt 341 ... Prompt: A method is presented for
# Generating Prompt 342 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 343 ... Prompt: An integrated circuit device includes:
# Generating Prompt 344 ... Prompt: The bluff body attaches to
# Generating Prompt 345 ... Prompt: A high output and high
# Generating Prompt 346 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 347 ... Prompt: A package for housing an
# Generating Prompt 348 ... Prompt: A method is provided for
# Generating Prompt 349 ... Prompt: A control device includes a
# Generating Prompt 350 ... Prompt: An embodiment includes a memory
# Generating Prompt 351 ... Prompt: An imaging element includes a
# Generating Prompt 352 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 353 ... Prompt: A manufacturing method of an
# Generating Prompt 354 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 355 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 356 ... Prompt: A heat sink assembly for
# Generating Prompt 357 ... Prompt: A heat-pipe membrane module belongs
# Generating Prompt 358 ... Prompt: A method of packaging CSP
# Generating Prompt 359 ... Prompt: Disclosed is a light emitting
# Generating Prompt 360 ... Prompt: A microelectronic structure includes a
# Generating Prompt 361 ... Prompt: The present disclosure discloses a
# Generating Prompt 362 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 363 ... Prompt: A display apparatus includes a
# Generating Prompt 364 ... Prompt: A method is provided for
# Generating Prompt 365 ... Prompt: A semiconductor device includes a
# Generating Prompt 366 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 367 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 368 ... Prompt: A light emitting diode package
# Generating Prompt 369 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 370 ... Prompt: A semiconductor device is provided.
# Generating Prompt 371 ... Prompt: Embodiments of this invention relate
# Generating Prompt 372 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 373 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 374 ... Prompt: An organic light emitting diode
# Generating Prompt 375 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 376 ... Prompt: [Object] To provide a method
# Generating Prompt 377 ... Prompt: The present invention relates to
# Generating Prompt 378 ... Prompt: In one embodiment, a solar
# Generating Prompt 379 ... Prompt: A display apparatus includes a
# Generating Prompt 380 ... Prompt: A change in electrical characteristics
# Generating Prompt 381 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 382 ... Prompt: The present invention(s) is directed
# Generating Prompt 383 ... Prompt: A semiconductor light emitting device
# Generating Prompt 384 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 385 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 386 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 387 ... Prompt: A semiconductor light emitting device
# Generating Prompt 388 ... Prompt: In a described example, a
# Generating Prompt 389 ... Prompt: The present disclosure provides a
# Generating Prompt 390 ... Prompt: A semiconductor device and a
# Generating Prompt 391 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 392 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 393 ... Prompt: Provided is a display device
# Generating Prompt 394 ... Prompt: A light-emitting element having high
# Generating Prompt 395 ... Prompt: A substrate carrier stack includes
# Generating Prompt 396 ... Prompt: A semiconductor device includes a
# Generating Prompt 397 ... Prompt: A semiconductor light emitting device
# Generating Prompt 398 ... Prompt: A device including oxide spacer
# Generating Prompt 399 ... Prompt: A system for surface patterning
# Generating Prompt 400 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 401 ... Prompt: CMOS circuits may formed using
# Generating Prompt 402 ... Prompt: A group III-N nanowire is
# Generating Prompt 403 ... Prompt: The present invention relates to
# Generating Prompt 404 ... Prompt: A dynamic vision sensor (DVS)
# Generating Prompt 405 ... Prompt: Systems and methods for growing
# Generating Prompt 406 ... Prompt: A heat sink assembly for
# Generating Prompt 407 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 408 ... Prompt: A semiconductor light emitting device
# Generating Prompt 409 ... Prompt: An imaging element includes: an
# Generating Prompt 410 ... Prompt: A method of manufacturing a
# Generating Prompt 411 ... Prompt: An object of the present
# Generating Prompt 412 ... Prompt: The present invention discloses a
# Generating Prompt 413 ... Prompt: The various embodiments described herein
# Generating Prompt 414 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 415 ... Prompt: The disclosure relates to a
# Generating Prompt 416 ... Prompt: To provide a coating fluid
# Generating Prompt 417 ... Prompt: There is provided a barrier
# Generating Prompt 418 ... Prompt: An organic EL display device
# Generating Prompt 419 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 420 ... Prompt: The present application discloses a
# Generating Prompt 421 ... Prompt: An organic light emitting device
# Generating Prompt 422 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 423 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 424 ... Prompt: An organic light-emitting display including
# Generating Prompt 425 ... Prompt: A solid-state image pickup device
# Generating Prompt 426 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 427 ... Prompt: A heat sink assembly for
# Generating Prompt 428 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 429 ... Prompt: A device including oxide spacer
# Generating Prompt 430 ... Prompt: A display device includes: a
# Generating Prompt 431 ... Prompt: A light-emitting element having high
# Generating Prompt 432 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 433 ... Prompt: Use of transition metal complexes
# Generating Prompt 434 ... Prompt: A method of manufacturing a
# Generating Prompt 435 ... Prompt: A method of making a
# Generating Prompt 436 ... Prompt: A novel and useful controlled
# Generating Prompt 437 ... Prompt: A method of manufacturing a
# Generating Prompt 438 ... Prompt: A photoelectric conversion element and
# Generating Prompt 439 ... Prompt: Various embodiments of the present
# Generating Prompt 440 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 441 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 442 ... Prompt: A group III-N nanowire is
# Generating Prompt 443 ... Prompt: The present invention discloses a
# Generating Prompt 444 ... Prompt: Provided is an adhesive composition
# Generating Prompt 445 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 446 ... Prompt: Methods/structures of joining package structures
# Generating Prompt 447 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 448 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 449 ... Prompt: One aspect of the present
# Generating Prompt 450 ... Prompt: A device includes a substrate
# Generating Prompt 451 ... Prompt: An image sensor includes a
# Generating Prompt 452 ... Prompt: One aspect of the present
# Generating Prompt 453 ... Prompt: A semiconductor device includes a
# Generating Prompt 454 ... Prompt: A method for transporting a
# Generating Prompt 455 ... Prompt: A method of manufacturing a
# Generating Prompt 456 ... Prompt: An organic metal complex as
# Generating Prompt 457 ... Prompt: An organic metal complex as
# Generating Prompt 458 ... Prompt: Provided are a pickup sensor
# Generating Prompt 459 ... Prompt: A display device includes first
# Generating Prompt 460 ... Prompt: A light emitting diode (LED)
# Generating Prompt 461 ... Prompt: A method for transporting a
# Generating Prompt 462 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 463 ... Prompt: The present disclosure describes additives
# Generating Prompt 464 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 465 ... Prompt: A driving control method is
# Generating Prompt 466 ... Prompt: A TFT substrate includes a
# Generating Prompt 467 ... Prompt: A solar cell includes a
# Generating Prompt 468 ... Prompt: Provided are a compound represented
# Generating Prompt 469 ... Prompt: An object of the present
# Generating Prompt 470 ... Prompt: A display apparatus includes a
# Generating Prompt 471 ... Prompt: Provided are a display panel,
# Generating Prompt 472 ... Prompt: A display device includes: a
# Generating Prompt 473 ... Prompt: An image detector comprises a
# Generating Prompt 474 ... Prompt: A method of manufacturing a
# Generating Prompt 475 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 476 ... Prompt: Provided are a compound represented
# Generating Prompt 477 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 478 ... Prompt: A method of manufacturing a
# Generating Prompt 479 ... Prompt: A supporting device includes a
# Generating Prompt 480 ... Prompt: A display apparatus includes a
# Generating Prompt 481 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 482 ... Prompt: A flexible display panel, a
# Generating Prompt 483 ... Prompt: A display apparatus includes a
# Generating Prompt 484 ... Prompt: Various embodiments of the present
# Generating Prompt 485 ... Prompt: The present invention relates to
# Generating Prompt 486 ... Prompt: An assembly used in a
# Generating Prompt 487 ... Prompt: Verifying a semiconductor product is
# Generating Prompt 488 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 489 ... Prompt: Methods and devices for forming
# Generating Prompt 490 ... Prompt: The present disclosure provides a
# Generating Prompt 491 ... Prompt: The present disclosure relates to
# Generating Prompt 492 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 493 ... Prompt: A manufacturing method of an
# Generating Prompt 494 ... Prompt: The present disclosure relates to
# Generating Prompt 495 ... Prompt: A circuit carrier structure includes
# Generating Prompt 496 ... Prompt: The present invention relates to
# Generating Prompt 497 ... Prompt: A semiconductor structure includes a
# Generating Prompt 498 ... Prompt: A method is provided for
# Generating Prompt 499 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 500 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 501 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 502 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 503 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 504 ... Prompt: A first III-V material based
# Generating Prompt 505 ... Prompt: Disclosed are a method for
# Generating Prompt 506 ... Prompt: The disclosure relates to a
# Generating Prompt 507 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 508 ... Prompt: The present application relates to
# Generating Prompt 509 ... Prompt: A method of manufacturing a
# Generating Prompt 510 ... Prompt: A bipolar complementary metal oxide
# Generating Prompt 511 ... Prompt: To reduce influence occurring between
# Generating Prompt 512 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 513 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 514 ... Prompt: An electronic apparatus that is
# Generating Prompt 515 ... Prompt: A method for manufacturing a
# Generating Prompt 516 ... Prompt: A flexible display device includes:
# Generating Prompt 517 ... Prompt: A change in electrical characteristics
# Generating Prompt 518 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 519 ... Prompt: A display device includes: a
# Generating Prompt 520 ... Prompt: An application specific integrated circuit
# Generating Prompt 521 ... Prompt: An imaging element includes a
# Generating Prompt 522 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 523 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 524 ... Prompt: Disclosed herein is an organic
# Generating Prompt 525 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 526 ... Prompt: In accordance with an embodiment,
# Generating Prompt 527 ... Prompt: Provided are a compound represented
# Generating Prompt 528 ... Prompt: The bluff body attaches to
# Generating Prompt 529 ... Prompt: Provided is a portable, thermoelectrically
# Generating Prompt 530 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 531 ... Prompt: The present disclosure relates to
# Generating Prompt 532 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 533 ... Prompt: A flexible display panel has
# Generating Prompt 534 ... Prompt: A photoelectric conversion element and
# Generating Prompt 535 ... Prompt: CMOS circuits may formed using
# Generating Prompt 536 ... Prompt: A semiconductor structure for a
# Generating Prompt 537 ... Prompt: A microfluidic system includes a
# Generating Prompt 538 ... Prompt: Systems and methods that may
# Generating Prompt 539 ... Prompt: Systems and methods for growing
# Generating Prompt 540 ... Prompt: A method is presented for
# Generating Prompt 541 ... Prompt: A method of manufacturing a
# Generating Prompt 542 ... Prompt: A group III-N nanowire is
# Generating Prompt 543 ... Prompt: In case of forming electrodes
# Generating Prompt 544 ... Prompt: A display apparatus includes a
# Generating Prompt 545 ... Prompt: A driving control method is
# Generating Prompt 546 ... Prompt: According to one embodiment, a
# Generating Prompt 547 ... Prompt: A semiconductor structure is provided
# Generating Prompt 548 ... Prompt: Docking platforms formed in one
# Generating Prompt 549 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 550 ... Prompt: Provided is a semiconductor device
# Generating Prompt 551 ... Prompt: An electronic apparatus includes a
# Generating Prompt 552 ... Prompt: A solar cell includes a
# Generating Prompt 553 ... Prompt: An etching method and a
# Generating Prompt 554 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 555 ... Prompt: We describe a method for
# Generating Prompt 556 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 557 ... Prompt: An organic EL display device
# Generating Prompt 558 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 559 ... Prompt: The present invention(s) is directed
# Generating Prompt 560 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 561 ... Prompt: The present application relates to
# Generating Prompt 562 ... Prompt: Discussed is a method of
# Generating Prompt 563 ... Prompt: Systems and methods for growing
# Generating Prompt 564 ... Prompt: A deposition system and method
# Generating Prompt 565 ... Prompt: A semiconductor light emitting device
# Generating Prompt 566 ... Prompt: A semiconductor device according to
# Generating Prompt 567 ... Prompt: A deposition system and method
# Generating Prompt 568 ... Prompt: A light emitting diode package
# Generating Prompt 569 ... Prompt: An OLED device and a
# Generating Prompt 570 ... Prompt: An object of the invention
# Generating Prompt 571 ... Prompt: The present invention discloses a
# Generating Prompt 572 ... Prompt: A light emitting diode package
# Generating Prompt 573 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 574 ... Prompt: An application specific integrated circuit
# Generating Prompt 575 ... Prompt: An embodiment includes a memory
# Generating Prompt 576 ... Prompt: The present disclosure provides a
# Generating Prompt 577 ... Prompt: The present specification relates to
# Generating Prompt 578 ... Prompt: A system for surface patterning
# Generating Prompt 579 ... Prompt: A manufacturing method of an
# Generating Prompt 580 ... Prompt: A semiconductor device includes a
# Generating Prompt 581 ... Prompt: An application specific integrated circuit
# Generating Prompt 582 ... Prompt: An emitter for an LED-based
# Generating Prompt 583 ... Prompt: Systems and methods for detecting
# Generating Prompt 584 ... Prompt: The present invention relates generally
# Generating Prompt 585 ... Prompt: A driving control method is
# Generating Prompt 586 ... Prompt: A display apparatus includes a
# Generating Prompt 587 ... Prompt: Discussed is a method of
# Generating Prompt 588 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 589 ... Prompt: A high output and high
# Generating Prompt 590 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 591 ... Prompt: The present invention discloses a
# Generating Prompt 592 ... Prompt: A method of manufacturing a
# Generating Prompt 593 ... Prompt: A semiconductor structure for a
# Generating Prompt 594 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 595 ... Prompt: An embodiment includes a memory
# Generating Prompt 596 ... Prompt: According to an embodiment of
# Generating Prompt 597 ... Prompt: An image sensor may include
# Generating Prompt 598 ... Prompt: There is provided a barrier
# Generating Prompt 599 ... Prompt: Provided are a display apparatus,
# Generating Prompt 600 ... Prompt: [Object] To provide a method
# Generating Prompt 601 ... Prompt: A light emitting diode package
# Generating Prompt 602 ... Prompt: An organic metal complex as
# Generating Prompt 603 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 604 ... Prompt: Disclosed is a pattern forming
# Generating Prompt 605 ... Prompt: Proposed is a layer structure
# Generating Prompt 606 ... Prompt: A light emitting diode package
# Generating Prompt 607 ... Prompt: A flexible display panel, a
# Generating Prompt 608 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 609 ... Prompt: Some embodiments include an integrated
# Generating Prompt 610 ... Prompt: The present specification relates to
# Generating Prompt 611 ... Prompt: An upper surface of a
# Generating Prompt 612 ... Prompt: An image processing apparatus includes
# Generating Prompt 613 ... Prompt: An electronic apparatus that is
# Generating Prompt 614 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 615 ... Prompt: Proposed is a layer structure
# Generating Prompt 616 ... Prompt: The present disclosure discloses a
# Generating Prompt 617 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 618 ... Prompt: An organic light-emitting diode may
# Generating Prompt 619 ... Prompt: A microelectronic structure includes a
# Generating Prompt 620 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 621 ... Prompt: A light emitting diode package
# Generating Prompt 622 ... Prompt: A display apparatus includes a
# Generating Prompt 623 ... Prompt: An organic metal complex as
# Generating Prompt 624 ... Prompt: The present invention relates to
# Generating Prompt 625 ... Prompt: Various embodiments of the present
# Generating Prompt 626 ... Prompt: A display apparatus includes a
# Generating Prompt 627 ... Prompt: An image detector comprises a
# Generating Prompt 628 ... Prompt: The present invention relates generally
# Generating Prompt 629 ... Prompt: A semiconductor package includes a
# Generating Prompt 630 ... Prompt: A heat sink assembly for
# Generating Prompt 631 ... Prompt: A method is provided for
# Generating Prompt 632 ... Prompt: A driving control method is
# Generating Prompt 633 ... Prompt: A vehicle skin, such as
# Generating Prompt 634 ... Prompt: A system for surface patterning
# Generating Prompt 635 ... Prompt: A light-emitting element having high
# Generating Prompt 636 ... Prompt: One aspect of the present
# Generating Prompt 637 ... Prompt: An imaging element includes a
# Generating Prompt 638 ... Prompt: An OLED device and a
# Generating Prompt 639 ... Prompt: A change in electrical characteristics
# Generating Prompt 640 ... Prompt: A semiconductor device includes a
# Generating Prompt 641 ... Prompt: A group III-N nanowire is
# Generating Prompt 642 ... Prompt: An array substrate, a method
# Generating Prompt 643 ... Prompt: Disclosed herein are switching or
# Generating Prompt 644 ... Prompt: An organic light emitting diode
# Generating Prompt 645 ... Prompt: An organic light-emitting display including
# Generating Prompt 646 ... Prompt: In accordance with an embodiment,
# Generating Prompt 647 ... Prompt: A group III-N nanowire is
# Generating Prompt 648 ... Prompt: A data reading error is
# Generating Prompt 649 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 650 ... Prompt: The embodiments of the present
# Generating Prompt 651 ... Prompt: A random number generator capable
# Generating Prompt 652 ... Prompt: A phase-change memory element is
# Generating Prompt 653 ... Prompt: A method of manufacturing a
# Generating Prompt 654 ... Prompt: An organic light emitting device
# Generating Prompt 655 ... Prompt: A flexible display panel, a
# Generating Prompt 656 ... Prompt: A light emitting diode (LED)
# Generating Prompt 657 ... Prompt: A structure containing a vertical
# Generating Prompt 658 ... Prompt: The present disclosure relates to
# Generating Prompt 659 ... Prompt: The disclosed technology generally relates
# Generating Prompt 660 ... Prompt: A light emitting diode (LED)
# Generating Prompt 661 ... Prompt: A display unit includes a
# Generating Prompt 662 ... Prompt: Provided are a compound of
# Generating Prompt 663 ... Prompt: The present specification relates to
# Generating Prompt 664 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 665 ... Prompt: Structures and formation methods of
# Generating Prompt 666 ... Prompt: A semiconductor device includes a
# Generating Prompt 667 ... Prompt: Disclosed herein is an organic
# Generating Prompt 668 ... Prompt: A display panel and a
# Generating Prompt 669 ... Prompt: An organic light-emitting display including
# Generating Prompt 670 ... Prompt: We describe a method for
# Generating Prompt 671 ... Prompt: A display device includes a
# Generating Prompt 672 ... Prompt: Disclosed herein is an organic
# Generating Prompt 673 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 674 ... Prompt: A method of fabricating a
# Generating Prompt 675 ... Prompt: A display device, which includes
# Generating Prompt 676 ... Prompt: A heat sink assembly for
# Generating Prompt 677 ... Prompt: An object of the invention
# Generating Prompt 678 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 679 ... Prompt: An organic light emitting diode
# Generating Prompt 680 ... Prompt: A support structure for a
# Generating Prompt 681 ... Prompt: Systems and methods for growing
# Generating Prompt 682 ... Prompt: Provided is an electric element
# Generating Prompt 683 ... Prompt: The present disclosure relates to
# Generating Prompt 684 ... Prompt: A flexible display substrate includes
# Generating Prompt 685 ... Prompt: A vehicle skin, such as
# Generating Prompt 686 ... Prompt: According to example embodiments, a
# Generating Prompt 687 ... Prompt: Described herein are polishing compositions
# Generating Prompt 688 ... Prompt: A semiconductor device includes a
# Generating Prompt 689 ... Prompt: A method of manufacturing a
# Generating Prompt 690 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 691 ... Prompt: A display device includes a
# Generating Prompt 692 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 693 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 694 ... Prompt: A chip accommodation tray for
# Generating Prompt 695 ... Prompt: A semiconductor structure for a
# Generating Prompt 696 ... Prompt: Backsheet for photovoltaic panels with
# Generating Prompt 697 ... Prompt: The disclosure provides a package
# Generating Prompt 698 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 699 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 700 ... Prompt: A semiconductor device includes a
# Generating Prompt 701 ... Prompt: A method of manufacturing a
# Generating Prompt 702 ... Prompt: According to example embodiments, a
# Generating Prompt 703 ... Prompt: Systems and methods for detecting
# Generating Prompt 704 ... Prompt: An organic metal complex as
# Generating Prompt 705 ... Prompt: An organic metal complex as
# Generating Prompt 706 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 707 ... Prompt: Provided is a light-emitting device
# Generating Prompt 708 ... Prompt: The present disclosure provides a
# Generating Prompt 709 ... Prompt: A method for depositing a
# Generating Prompt 710 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 711 ... Prompt: The present disclosure provides a
# Generating Prompt 712 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 713 ... Prompt: A heat-pipe membrane module belongs
# ...
# Generating Prompt 3616 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 3617 ... Prompt: An application specific integrated circuit
# Generating Prompt 3618 ... Prompt: According to one embodiment, a
# Generating Prompt 3619 ... Prompt: An organic metal complex as
# Generating Prompt 3620 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 3621 ... Prompt: An imaging system may include
# Generating Prompt 3622 ... Prompt: A package structure includes a
# Generating Prompt 3623 ... Prompt: An object of the invention
# Generating Prompt 3624 ... Prompt: A package for housing an
# Generating Prompt 3625 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 3626 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3627 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 3628 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 3629 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 3630 ... Prompt: A semiconductor device includes a
# Generating Prompt 3631 ... Prompt: A microfluidic system includes a
# Generating Prompt 3632 ... Prompt: An application specific integrated circuit
# Generating Prompt 3633 ... Prompt: The various embodiments described herein
# Generating Prompt 3634 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 3635 ... Prompt: The present specification relates to
# Generating Prompt 3636 ... Prompt: A semiconductor structure includes a
# Generating Prompt 3637 ... Prompt: Use of transition metal complexes
# Generating Prompt 3638 ... Prompt: Provided is an electric element
# Generating Prompt 3639 ... Prompt: Provided are a compound represented
# Generating Prompt 3640 ... Prompt: A semiconductor device includes an
# Generating Prompt 3641 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 3642 ... Prompt: A first III-V material based
# Generating Prompt 3643 ... Prompt: An integrated circuit device includes
# Generating Prompt 3644 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 3645 ... Prompt: In accordance with an embodiment,
# Generating Prompt 3646 ... Prompt: A display device including a
# Generating Prompt 3647 ... Prompt: A microelectronic structure includes a
# Generating Prompt 3648 ... Prompt: The present disclosure provides a
# Generating Prompt 3649 ... Prompt: The various embodiments described herein
# Generating Prompt 3650 ... Prompt: According to an embodiment of
# Generating Prompt 3651 ... Prompt: An organic light emitting diode
# Generating Prompt 3652 ... Prompt: A semiconductor device has a
# Generating Prompt 3653 ... Prompt: A substrate carrier stack includes
# Generating Prompt 3654 ... Prompt: A light-emitting element having high
# Generating Prompt 3655 ... Prompt: A substrate carrier stack includes
# Generating Prompt 3656 ... Prompt: An imaging system may include
# Generating Prompt 3657 ... Prompt: An image detector comprises a
# Generating Prompt 3658 ... Prompt: The present specification relates to
# Generating Prompt 3659 ... Prompt: Disclosed is a light emitting
# Generating Prompt 3660 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 3661 ... Prompt: The present specification relates to
# Generating Prompt 3662 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 3663 ... Prompt: An organic light emitting device
# Generating Prompt 3664 ... Prompt: Various embodiments of the present
# Generating Prompt 3665 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 3666 ... Prompt: A method of manufacturing a
# Generating Prompt 3667 ... Prompt: An anisotropic conductive film includes,
# Generating Prompt 3668 ... Prompt: Disclosed are a method for
# Generating Prompt 3669 ... Prompt: A method of fabricating a
# Generating Prompt 3670 ... Prompt: A bipolar complementary metal oxide
# Generating Prompt 3671 ... Prompt: A method for depositing a
# Generating Prompt 3672 ... Prompt: A method of fabricating a
# Generating Prompt 3673 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 3674 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 3675 ... Prompt: A solid-state image pickup device
# Generating Prompt 3676 ... Prompt: A phase-change memory element is
# Generating Prompt 3677 ... Prompt: Provided is a display device
# Generating Prompt 3678 ... Prompt: A light-emitting element that includes
# Generating Prompt 3679 ... Prompt: A display unit includes a
# Generating Prompt 3680 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 3681 ... Prompt: The present disclosure provides a
# Generating Prompt 3682 ... Prompt: A flexible substrate including a
# Generating Prompt 3683 ... Prompt: A method is presented for
# Generating Prompt 3684 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 3685 ... Prompt: Provided is a light-emitting device
# Generating Prompt 3686 ... Prompt: A microelectronic structure includes a
# Generating Prompt 3687 ... Prompt: A circuit carrier structure includes
# Generating Prompt 3688 ... Prompt: A method of forming a
# Generating Prompt 3689 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 3690 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 3691 ... Prompt: A method is provided for
# Generating Prompt 3692 ... Prompt: An image sensor includes a
# Generating Prompt 3693 ... Prompt: An etching method and a
# Generating Prompt 3694 ... Prompt: A light emitting diode package
# Generating Prompt 3695 ... Prompt: Proposed is a layer structure
# Generating Prompt 3696 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 3697 ... Prompt: A semiconductor device includes a
# Generating Prompt 3698 ... Prompt: An organic light emitting diode
# Generating Prompt 3699 ... Prompt: According to one embodiment, a
# Generating Prompt 3700 ... Prompt: The disclosed apparatus may include
# Generating Prompt 3701 ... Prompt: The disclosed apparatus may include
# Generating Prompt 3702 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 3703 ... Prompt: Systems and methods that may
# Generating Prompt 3704 ... Prompt: A device includes a substrate
# Generating Prompt 3705 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 3706 ... Prompt: Disclosed herein are switching or
# Generating Prompt 3707 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 3708 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 3709 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 3710 ... Prompt: Provided is a semiconductor device
# Generating Prompt 3711 ... Prompt: A light emitting diode (LED)
# Generating Prompt 3712 ... Prompt: Embodiments are directed to a
# Generating Prompt 3713 ... Prompt: An electronic apparatus that is
# Generating Prompt 3714 ... Prompt: An application specific integrated circuit
# Generating Prompt 3715 ... Prompt: According to one embodiment, a
# Generating Prompt 3716 ... Prompt: An organic metal complex as
# Generating Prompt 3717 ... Prompt: In case of forming electrodes
# Generating Prompt 3718 ... Prompt: A light-emitting element that includes
# Generating Prompt 3719 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 3720 ... Prompt: A hermetic capsule including a
# Generating Prompt 3721 ... Prompt: Verifying a semiconductor product is
# Generating Prompt 3722 ... Prompt: A method for manufacturing a
# Generating Prompt 3723 ... Prompt: A method for transporting a
# Generating Prompt 3724 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 3725 ... Prompt: An organic metal complex as
# Generating Prompt 3726 ... Prompt: A semiconductor device includes a
# Generating Prompt 3727 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 3728 ... Prompt: A display device includes a
# Generating Prompt 3729 ... Prompt: A light-emitting element that includes
# Generating Prompt 3730 ... Prompt: A display apparatus includes: a
# Generating Prompt 3731 ... Prompt: A light emitting diode package
# Generating Prompt 3732 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 3733 ... Prompt: A solid-state image pickup device
# Generating Prompt 3734 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3735 ... Prompt: An organic light-emitting device having
# Generating Prompt 3736 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 3737 ... Prompt: An assembly useable with a
# Generating Prompt 3738 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 3739 ... Prompt: A display apparatus includes a
# Generating Prompt 3740 ... Prompt: A light-emitting element having high
# Generating Prompt 3741 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 3742 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 3743 ... Prompt: An organic light emitting device
# Generating Prompt 3744 ... Prompt: The present disclosure provides a
# Generating Prompt 3745 ... Prompt: Provided is a semiconductor device
# Generating Prompt 3746 ... Prompt: A method of manufacturing a
# Generating Prompt 3747 ... Prompt: A TFT substrate includes a
# Generating Prompt 3748 ... Prompt: Methods and devices for forming
# Generating Prompt 3749 ... Prompt: According to one example, a
# Generating Prompt 3750 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 3751 ... Prompt: A vehicle skin, such as
# Generating Prompt 3752 ... Prompt: An imaging element includes: an
# Generating Prompt 3753 ... Prompt: Disclosed herein is an organic
# Generating Prompt 3754 ... Prompt: An integrated circuit device includes:
# Generating Prompt 3755 ... Prompt: Provided are a pickup sensor
# Generating Prompt 3756 ... Prompt: A semiconductor device in embodiments,
# Generating Prompt 3757 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 3758 ... Prompt: Various embodiments of the present
# Generating Prompt 3759 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 3760 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 3761 ... Prompt: A light-emitting element having high
# Generating Prompt 3762 ... Prompt: A semiconductor light emitting device
# Generating Prompt 3763 ... Prompt: A substrate support assembly for
# Generating Prompt 3764 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 3765 ... Prompt: A method for pre-aligning a
# Generating Prompt 3766 ... Prompt: A memory device includes a
# Generating Prompt 3767 ... Prompt: An application specific integrated circuit
# Generating Prompt 3768 ... Prompt: A method for transporting a
# Generating Prompt 3769 ... Prompt: An embodiment includes a memory
# Generating Prompt 3770 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 3771 ... Prompt: An organic EL display device
# Generating Prompt 3772 ... Prompt: The present invention provides an
# Generating Prompt 3773 ... Prompt: A display device includes a
# Generating Prompt 3774 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 3775 ... Prompt: An object of the invention
# Generating Prompt 3776 ... Prompt: In case of forming electrodes
# Generating Prompt 3777 ... Prompt: A three-dimensional memory device including
# Generating Prompt 3778 ... Prompt: In case of forming electrodes
# Generating Prompt 3779 ... Prompt: A heat sink assembly for
# Generating Prompt 3780 ... Prompt: The present specification relates to
# Generating Prompt 3781 ... Prompt: Provided are a display apparatus,
# Generating Prompt 3782 ... Prompt: The present disclosure discloses a
# Generating Prompt 3783 ... Prompt: A method is provided for
# Generating Prompt 3784 ... Prompt: According to one example, a
# Generating Prompt 3785 ... Prompt: A package structure includes a
# Generating Prompt 3786 ... Prompt: A method of manufacturing a
# Generating Prompt 3787 ... Prompt: A display device includes a
# Generating Prompt 3788 ... Prompt: Disclosed herein is an organic
# Generating Prompt 3789 ... Prompt: The present disclosure relates to
# Generating Prompt 3790 ... Prompt: A deposition system and method
# Generating Prompt 3791 ... Prompt: Disclosed is a light emitting
# Generating Prompt 3792 ... Prompt: A circuit substrate and a
# Generating Prompt 3793 ... Prompt: A semiconductor device includes a
# Generating Prompt 3794 ... Prompt: A display device includes a
# Generating Prompt 3795 ... Prompt: A control device includes a
# Generating Prompt 3796 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 3797 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 3798 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 3799 ... Prompt: A light emitting diode package
# Generating Prompt 3800 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 3801 ... Prompt: A pixel array in an
# Generating Prompt 3802 ... Prompt: A substrate processing apparatus includes
# Generating Prompt 3803 ... Prompt: A method of manufacturing a
# Generating Prompt 3804 ... Prompt: Disclosed herein is an organic
# Generating Prompt 3805 ... Prompt: An organic light emitting diode
# Generating Prompt 3806 ... Prompt: A system for surface patterning
# Generating Prompt 3807 ... Prompt: An imaging element includes: an
# Generating Prompt 3808 ... Prompt: A method of manufacturing a
# Generating Prompt 3809 ... Prompt: The bluff body attaches to
# Generating Prompt 3810 ... Prompt: A three-dimensional memory device including
# Generating Prompt 3811 ... Prompt: A semiconductor package includes a
# Generating Prompt 3812 ... Prompt: A light-emitting element having high
# Generating Prompt 3813 ... Prompt: The disclosure provides a package
# Generating Prompt 3814 ... Prompt: An organic light emitting diode
# Generating Prompt 3815 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 3816 ... Prompt: A display device includes a
# Generating Prompt 3817 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 3818 ... Prompt: A semiconductor structure includes an
# Generating Prompt 3819 ... Prompt: According to example embodiments, a
# Generating Prompt 3820 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 3821 ... Prompt: A composition comprising a first
# Generating Prompt 3822 ... Prompt: A chip accommodation tray for
# Generating Prompt 3823 ... Prompt: Provided are a display panel,
# Generating Prompt 3824 ... Prompt: A method for manufacturing a
# Generating Prompt 3825 ... Prompt: An application specific integrated circuit
# Generating Prompt 3826 ... Prompt: Provided are a compound represented
# Generating Prompt 3827 ... Prompt: The present disclosure provides a
# Generating Prompt 3828 ... Prompt: Methods and devices for forming
# Generating Prompt 3829 ... Prompt: To provide a coating fluid
# Generating Prompt 3830 ... Prompt: An object of the invention
# Generating Prompt 3831 ... Prompt: A substrate support assembly for
# Generating Prompt 3832 ... Prompt: A solar cell includes a
# Generating Prompt 3833 ... Prompt: In accordance with an embodiment,
# Generating Prompt 3834 ... Prompt: The present invention relates to
# Generating Prompt 3835 ... Prompt: A display apparatus includes: a
# Generating Prompt 3836 ... Prompt: To provide a coating fluid
# Generating Prompt 3837 ... Prompt: The present invention relates to
# Generating Prompt 3838 ... Prompt: Various embodiments of the present
# Generating Prompt 3839 ... Prompt: Provided is an adhesive composition
# Generating Prompt 3840 ... Prompt: The present invention relates to
# Generating Prompt 3841 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3842 ... Prompt: A semiconductor light emitting device
# Generating Prompt 3843 ... Prompt: A semiconductor light emitting device
# Generating Prompt 3844 ... Prompt: An imaging element includes a
# Generating Prompt 3845 ... Prompt: An enclosure for a radiographic
# Generating Prompt 3846 ... Prompt: Provided are a pickup sensor
# Generating Prompt 3847 ... Prompt: Systems and methods that may

# %%
fake_data = pd.read_csv("./Models/Experiments/Abstracts/20epochs/fake_patent_abstracts.csv")
fake_data = fake_data.loc[:, ~fake_data.columns.str.contains('^Unnamed')]
fake_data
# Out:
#                                                Abstract  Label
# 0     Vacuum annealing-based techniques for forming ...      1
# 1     A method for manufacturing a light emitting un...      1
# 2     Stacked semiconductor die assemblies with impr...      1
# 3     The present disclosure provides a biological f...      1
# 4     According to one example, a device includes a ...      1
# ...                                                 ...    ...
# 5095  An organic light-emitting diode may have trans...      1
# 5096  A deposition system and method includes a depo...      1
# 5097  A semiconductor package includes a semiconduct...      1
# 5098  A flexible substrate including a display area ...      1
# 5099  A method of manufacturing a light emitting dev...      1
#
# [5100 rows x 2 columns]

# %%
len(fake_data)
# Out:
# 5100

# %%
fake_prompts = pd.read_csv("./Models/Experiments/Abstracts/20epochs/prompts.csv")

# %%
fake_data['Abstract'][0]
# Out:
# 'A solid-state image pickup device      includes a first semiconductor layer including a first photoelectric      converter, a second semiconductor layer including a second photoelectric      converter, and an intermediate layer between the first photoelectric      converter and the second photoelectric converter, and a pad electrode electrically      connects the first semiconductor layer to the second photoelectric      converter through the intermediate layer. A first resistive layer is over the      first semiconductor layer and a second resistive layer is under the second      semiconductor layer. A gate insulator and/or gate conductor coaxially      wraps completely around the first resistive layer and the second resistive      layer when it is in contact with the pad electrode. <EOS>\n<BOS> A light-emitting element having high external quantum efficiency is      provided. A light-emitting element having a long lifetime is provided. A      light-emitting element is provided which includes a light-emitting layer      containing a phosphorescent compound, a'

# %%
fake_prompts['Prompts'][0]
# Out:
# 'Protective dielectrics are discussed generally'

# %%
frames = [real_data, fake_data]
full_data = pd.concat(frames)


full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data
# Out:
#                                                 Abstract  Label
# 0      An imaging element includes a laminated plural...      0
# 1      A data reading error is reduced. A memory cell...      0
# 2      The present disclosure describes additives tha...      1
# 3      Provided are a pickup sensor and a biological ...      0
# 4      A display apparatus includes a first display a...      0
# ...                                                  ...    ...
# 17889  A semiconductor device includes a substrate, a...      0
# 17890  Low temperature epitaxial silicon deposition f...      0
# 17891  A photoelectric conversion element and an opti...      0
# 17892  The present disclosure discloses a light emitt...      0
# 17893  The present invention(s) is directed to novel ...      1
#
# [17894 rows x 2 columns]

# %%
# Out:
# 'Embodiments of the present disclosure include methods and      configurations for an image sensor capable of simultaneous integration of      electrons and holes. According to one example, the image sensor can process      signals emitted from holes split into mutually different sub-lenses that are      indistinguishable at multiple wavelengths. <EOS>\n<BOS> A semiconductor device is provided. The semiconductor device includes a      carrier. The carrier includes a first region. The first region includes      holes. The carrier further includes an oxygen exchange layer (OEL) between      the first region and the OEL. The oxygen exchange layer includes a first portion      of a trench that extends in a first direction crossing the horizontal      direction, and a second portion that is in a second direction crossing the      horizontal direction and extending in a third direction crossing the      horizontal direction. A distance between an edge of the first region and an edge      of the second region in a first direction direction that is not      overlapping the first direction is equal to or greater than'

# %%
full_data.to_csv("./Models/Experiments/Abstracts/20epochs/real_fake_abstracts.csv")

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import torch
# from fake_claims_generator import generate, grab_random_prompts

# %%
# !pip3 install git+https://github.com/huggingface/transformers@v3.1.0 # there are errors in the later versions
# !pip3 install transformers==3.3.1
# Out:
# Collecting transformers==3.3.1
#   Downloading https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 20.4MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (3.0.12)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 53.0MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 58.6MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (20.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2.23.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (0.8)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 46.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.3.1) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (1.24.3)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=f5291c307ba212ba9b1a2214c3a39e87a1473608ad631f0c9aa46973a8a9daf6
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, sentencepiece, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc2 transformers-3.3.1

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts
# *** Modify the directory to the right model ***
OUTPUT_DIR = "./Models/Experiments/Claims/10epochs"
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ## Load Real Data and Label Them

# %%
data = pd.read_csv("./Models/Data/H01L.csv")
real_data = pd.DataFrame({"Claims": data["claims"]})
real_data["Label"] = 0
real_data = real_data[real_data['Claims'].notnull()]
# real_data = pd.DataFrame({"Abstracts": data["abstracts"]})
# real_data["Label"] = 0
# real_data = real_data[real_data['Abstracts'].notnull()]

# %%
real_data
# Out:
#                                                  Claims  Label
# 0     1.  An organic light emitting diode display co...      0
# 1     1.  An electric element cooling module compris...      0
# 2     2.  The organic light emitting diode display o...      0
# 3     2.  The electric element cooling module of cla...      0
# 4     3.  The organic light emitting diode display o...      0
# ...                                                 ...    ...
# 8941  2.  The method of claim 1, further comprising:...      0
# 8942  3.  The method of claim 1, wherein the first g...      0
# 8943  4.  The method of claim 1, wherein a width of ...      0
# 8944  5.  The method of claim 1, wherein a length of...      0
# 8945  6.  The method of claim 1, further comprising:...      0
#
# [8420 rows x 2 columns]

# %% [markdown]
# ## Generate Fake Data and Label Them

# %%
# How many fake claims do you want to generate
# num_fake_claims = len(real_data)
# prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
# fake_claims = []
# for i, prompt in enumerate(prompts):
#     print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
#     generated_text = generate(prompt, n=8)
#     fake_claims.append(generated_text)

# %%
# write in chunks, and write to csv
'''
This code block is responsible for generating fake patent Claims
I first deine the file paths where we will save the fake patent data
Then, I generate the fake patent prompts by sampling from the real abstracts
I save the prompts into a csv file.
Since I am running the generation on Colab and I'm generating thousands of fake patent Claims,
there is a high frequency of interuption, I therefore need to save the prompts (to be accessed later),
and save the patent claims for every 100 that are generated.
The last_interupted variable stores where the generation was last interupted.
'''
import os.path
fake_data_file = "Models/Experiments/Claims/10epochs/fake_patent_claims.csv"
prompt_file = "Models/Experiments/Claims/10epochs/prompts.csv"
# fake_data_file = "Models/Experiments/Abstracts/fake_patent_abstracts_3epochs.csv"
# prompt_file = "Models/Experiments/Abstracts/prompts_3epochs.csv"
num_fake_claims = len(real_data)
if os.path.exists(prompt_file):
  prompts = pd.read_csv(prompt_file)
  prompts = prompts['Prompts'].tolist()
else:
  prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
  # save prompts
  prompt_df = pd.DataFrame({"Prompts": prompts})
  prompt_df.to_csv(prompt_file)
fake_claims = []
# modify last interrupted 
last_interrupted = 7800
for i, prompt in enumerate(prompts[last_interrupted:]): # modify last_interrupted if we got disconnected
    if i % 100 == 0 and i != 0: # for every 100 claims
      df = pd.DataFrame({"Claims": fake_claims, "Label": 1})
      if os.path.exists(fake_data_file): # this means this csv is already created
        df.to_csv(fake_data_file, mode='a', header=False)
      else:
        df.to_csv(fake_data_file)
      fake_claims = []
    print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
    generated_text = generate(prompt, n=8)
    fake_claims.append(generated_text)
# last batch
df = pd.DataFrame({"Claims": fake_claims, "Label": 1})
df.to_csv(fake_data_file, mode='a', header=False)
# Out:
# Generating Prompt 1 ... Prompt: 4. The compound of claim
# Generating Prompt 2 ... Prompt: 9. The semiconductor device according
# Generating Prompt 3 ... Prompt: 1. A method for manufacturing
# Generating Prompt 4 ... Prompt: 3. The image sensor according
# Generating Prompt 5 ... Prompt: 9. The electronic circuit as
# Generating Prompt 6 ... Prompt: 5. The organic electric element
# Generating Prompt 7 ... Prompt: 19. The light-emitting element according
# Generating Prompt 8 ... Prompt: 14. The article of claim
# Generating Prompt 9 ... Prompt: 16. The circuit of claim
# Generating Prompt 10 ... Prompt: 1. A method of producing
# Generating Prompt 11 ... Prompt: 17. The organic light-emitting device
# Generating Prompt 12 ... Prompt: 5. The photoelectric conversion element
# Generating Prompt 13 ... Prompt: 12. The solid-state image sensor
# Generating Prompt 14 ... Prompt: 4. The LDMOS transistor of
# Generating Prompt 15 ... Prompt: 3. The method for pre-aligning
# Generating Prompt 16 ... Prompt: 5. The solid-state image sensor
# Generating Prompt 17 ... Prompt: 10. A formulation comprising the
# Generating Prompt 18 ... Prompt: 10. The organic light emitting
# Generating Prompt 19 ... Prompt: 4. The semiconductor die assembly
# Generating Prompt 20 ... Prompt: 1. A hermetic capsule comprising:
# Generating Prompt 21 ... Prompt: 9. The optoelectronic arrangement according
# Generating Prompt 22 ... Prompt: 19. The memory package of
# Generating Prompt 23 ... Prompt: 9. The imaging system according
# Generating Prompt 24 ... Prompt: 14. The semiconductor device according
# Generating Prompt 25 ... Prompt: 8. A method, comprising: forming
# Generating Prompt 26 ... Prompt: 7. An organic electroluminescence device
# Generating Prompt 27 ... Prompt: 1. A method comprising: forming
# Generating Prompt 28 ... Prompt: 10. The system of claim
# Generating Prompt 29 ... Prompt: 16. The method as claimed
# Generating Prompt 30 ... Prompt: 14. The display device according
# Generating Prompt 31 ... Prompt: 14. The method of claim
# Generating Prompt 32 ... Prompt: 8. The Light-emitting semiconductor chip
# Generating Prompt 33 ... Prompt: 15. The acoustic resonator structure
# Generating Prompt 34 ... Prompt: 16. The light emitting device
# Generating Prompt 35 ... Prompt: 7. The polishing composition of
# Generating Prompt 36 ... Prompt: 1. A compound of formula
# Generating Prompt 37 ... Prompt: 10. The organic optoelectronic device
# Generating Prompt 38 ... Prompt: 12. The phase-change memory of
# Generating Prompt 39 ... Prompt: 7. The method according to
# Generating Prompt 40 ... Prompt: 10. A method for manufacturing
# Generating Prompt 41 ... Prompt: 16. The method according to
# Generating Prompt 42 ... Prompt: 11. The method as claimed
# Generating Prompt 43 ... Prompt: 7. The article of claim
# Generating Prompt 44 ... Prompt: 6. The composition for display
# Generating Prompt 45 ... Prompt: 5. The flexible display substrate
# Generating Prompt 46 ... Prompt: 5. The process of claim
# Generating Prompt 47 ... Prompt: 2. The device of claim
# Generating Prompt 48 ... Prompt: 9. The stacked-die oscillator package
# Generating Prompt 49 ... Prompt: 9. A light emitting device
# Generating Prompt 50 ... Prompt: 14. The method of claim
# Generating Prompt 51 ... Prompt: 14. An electronic device selected
# Generating Prompt 52 ... Prompt: 9. The display device of
# Generating Prompt 53 ... Prompt: 17. The method as claimed
# Generating Prompt 54 ... Prompt: 7. The semiconductor die of
# Generating Prompt 55 ... Prompt: 7. The method of claim
# Generating Prompt 56 ... Prompt: 9. The method of claim
# Generating Prompt 57 ... Prompt: 11. The magnetoresistance effect element
# Generating Prompt 58 ... Prompt: 16. An organic electronic device
# Generating Prompt 59 ... Prompt: 11. A method forming a
# Generating Prompt 60 ... Prompt: 13. A method for depositing
# Generating Prompt 61 ... Prompt: 5. The composition of matter
# Generating Prompt 62 ... Prompt: 1. An organic light emitting
# Generating Prompt 63 ... Prompt: 10. The image sensor according
# Generating Prompt 64 ... Prompt: 3. The system of claim
# Generating Prompt 65 ... Prompt: 7. A manufacturing method of
# Generating Prompt 66 ... Prompt: 2. The heat-pipe membrane assembly
# Generating Prompt 67 ... Prompt: 19. The method of claim
# Generating Prompt 68 ... Prompt: 10. The organic light-emitting device
# Generating Prompt 69 ... Prompt: 5. The optoelectronic arrangement according
# Generating Prompt 70 ... Prompt: 3. The organic light emitting
# Generating Prompt 71 ... Prompt: 32. The pixel of claim
# Generating Prompt 72 ... Prompt: 21. The method according to
# Generating Prompt 73 ... Prompt: 19. The method according to
# Generating Prompt 74 ... Prompt: 4. An electric element cooling
# Generating Prompt 75 ... Prompt: 17. The flexible display according
# Generating Prompt 76 ... Prompt: 16. The semiconductor light emitting
# Generating Prompt 77 ... Prompt: 10. The semiconductor die assembly
# Generating Prompt 78 ... Prompt: 12. The integrated circuit of
# Generating Prompt 79 ... Prompt: 9. The hermetic capsule claimed
# Generating Prompt 80 ... Prompt: 7. The device according to
# Generating Prompt 81 ... Prompt: 18. The method of claim
# Generating Prompt 82 ... Prompt: 7. The method of the
# Generating Prompt 83 ... Prompt: 14. The method according to
# Generating Prompt 84 ... Prompt: 7. The method according to
# Generating Prompt 85 ... Prompt: 6. The method of claim
# Generating Prompt 86 ... Prompt: 5. The photoelectric conversion device
# Generating Prompt 87 ... Prompt: 6. The backplate according to
# Generating Prompt 88 ... Prompt: 11. The integrated circuit of
# Generating Prompt 89 ... Prompt: 2. The display device according
# Generating Prompt 90 ... Prompt: 5. An organic electric element
# Generating Prompt 91 ... Prompt: 26. The formulation as claimed
# Generating Prompt 92 ... Prompt: 1. An organic electroluminescent device
# Generating Prompt 93 ... Prompt: 18. A method of assembling
# Generating Prompt 94 ... Prompt: 2. The hetero-cyclic compound of
# Generating Prompt 95 ... Prompt: 31. The electrical circuit of
# Generating Prompt 96 ... Prompt: 5. The apparatus of claim
# Generating Prompt 97 ... Prompt: 9. The method of claim
# Generating Prompt 98 ... Prompt: 24. The light emitting device
# Generating Prompt 99 ... Prompt: 9. A method as claimed
# Generating Prompt 100 ... Prompt: 1. A three transistor ultraviolet
# Generating Prompt 101 ... Prompt: 7. The DCO of claim
# Generating Prompt 102 ... Prompt: 15. A device comprising: a
# Generating Prompt 103 ... Prompt: 17. The integrated circuit device
# Generating Prompt 104 ... Prompt: 12. The method of fabricating
# Generating Prompt 105 ... Prompt: 27. The ASIC of claim
# Generating Prompt 106 ... Prompt: 14. The phase-change memory of
# Generating Prompt 107 ... Prompt: 1. An article comprising: a
# Generating Prompt 108 ... Prompt: 27. An anti-tamper system according
# Generating Prompt 109 ... Prompt: 28. A display device comprising
# Generating Prompt 110 ... Prompt: 16. The image sensor according
# Generating Prompt 111 ... Prompt: 14. The Doherty amplifier of
# Generating Prompt 112 ... Prompt: 12. The capacitor array of
# Generating Prompt 113 ... Prompt: 24. The method according to
# Generating Prompt 114 ... Prompt: 4. The display device of
# Generating Prompt 115 ... Prompt: 16. The method of claim
# Generating Prompt 116 ... Prompt: 11. The IC die of
# Generating Prompt 117 ... Prompt: 3. The electronic circuit as
# Generating Prompt 118 ... Prompt: 27. The display apparatus of
# Generating Prompt 119 ... Prompt: 5. The flexible display substrate
# Generating Prompt 120 ... Prompt: 11. The solid-state image sensor
# Generating Prompt 121 ... Prompt: 6. The display device according
# Generating Prompt 122 ... Prompt: 17. The substrate carrier according
# Generating Prompt 123 ... Prompt: 4. The enclosure of claim
# Generating Prompt 124 ... Prompt: 9. The organic light emitting
# Generating Prompt 125 ... Prompt: 22. A method of preparing
# Generating Prompt 126 ... Prompt: 13. The method of claim
# Generating Prompt 127 ... Prompt: 7. The light emitting diode
# Generating Prompt 128 ... Prompt: 13. The system of claim
# Generating Prompt 129 ... Prompt: 6. The method for manufacturing
# Generating Prompt 130 ... Prompt: 7. The semiconductor device according
# Generating Prompt 131 ... Prompt: 13. The method of claim
# Generating Prompt 132 ... Prompt: 1. A method of forming
# Generating Prompt 133 ... Prompt: 2. The light emitting device
# Generating Prompt 134 ... Prompt: 14. A system comprising: a
# Generating Prompt 135 ... Prompt: 15. The semiconductor die assembly
# Generating Prompt 136 ... Prompt: 19. The light emitting device
# Generating Prompt 137 ... Prompt: 13. An optical sensor comprising:
# Generating Prompt 138 ... Prompt: 10. The system according to
# Generating Prompt 139 ... Prompt: 8. The display substrate according
# Generating Prompt 140 ... Prompt: 20. The method according to
# Generating Prompt 141 ... Prompt: 7. The perovskite-based photovoltaic device
# Generating Prompt 142 ... Prompt: 14. The formulation of claim
# Generating Prompt 143 ... Prompt: 9. The method of claim
# Generating Prompt 144 ... Prompt: 36. A method of manufacturing
# Generating Prompt 145 ... Prompt: 20. The device of claim
# Generating Prompt 146 ... Prompt: 8. The method of claim
# Generating Prompt 147 ... Prompt: 13. The method as claimed
# Generating Prompt 148 ... Prompt: 11. The method according to
# Generating Prompt 149 ... Prompt: 4. The process of claim
# Generating Prompt 150 ... Prompt: 2. The method of packaging
# Generating Prompt 151 ... Prompt: 2. The composition of matter
# Generating Prompt 152 ... Prompt: 7. The system of claim
# Generating Prompt 153 ... Prompt: 5. The MEMS IR sensor
# Generating Prompt 154 ... Prompt: 5. The method as claimed
# Generating Prompt 155 ... Prompt: 8. A microelectronic mechanical system
# Generating Prompt 156 ... Prompt: 10. The method of claim
# Generating Prompt 157 ... Prompt: 12. The LED package structure
# Generating Prompt 158 ... Prompt: 2. The integrated circuit device
# Generating Prompt 159 ... Prompt: 2. The process of claim
# Generating Prompt 160 ... Prompt: 4. The method of claim
# Generating Prompt 161 ... Prompt: 19. A random number generation
# Generating Prompt 162 ... Prompt: 2. The solar cell of
# Generating Prompt 163 ... Prompt: 21. The apparatus of claim
# Generating Prompt 164 ... Prompt: 1. A stacked complementary metal
# Generating Prompt 165 ... Prompt: 7. The packaged semiconductor device
# Generating Prompt 166 ... Prompt: 14. The infrared light emitting
# Generating Prompt 167 ... Prompt: 24. The pixel of claim
# Generating Prompt 168 ... Prompt: 3. The OLED device according
# Generating Prompt 169 ... Prompt: 1. A package structure comprising:
# Generating Prompt 170 ... Prompt: 1. A display device comprising;
# Generating Prompt 171 ... Prompt: 3. The solid-state imaging element
# Generating Prompt 172 ... Prompt: 7. The photoelectric conversion element
# Generating Prompt 173 ... Prompt: 7. The method for manufacturing
# Generating Prompt 174 ... Prompt: 11. A method comprising: forming
# Generating Prompt 175 ... Prompt: 11. The microfluidic system of
# Generating Prompt 176 ... Prompt: 4. The magnetoresistance effect element
# Generating Prompt 177 ... Prompt: 2. The assembly of claim
# Generating Prompt 178 ... Prompt: 19. The method of claim
# Generating Prompt 179 ... Prompt: 14. The method of claim
# Generating Prompt 180 ... Prompt: 10. The organic light emitting
# Generating Prompt 181 ... Prompt: 17. The system of claim
# Generating Prompt 182 ... Prompt: 22. A light emitting device
# Generating Prompt 183 ... Prompt: 12. The semiconductor device according
# Generating Prompt 184 ... Prompt: 9. The method of claim
# Generating Prompt 185 ... Prompt: 25. The light-emitting element according
# Generating Prompt 186 ... Prompt: 4. The method as claimed
# Generating Prompt 187 ... Prompt: 14. The method of claim
# Generating Prompt 188 ... Prompt: 13. The method of claim
# Generating Prompt 189 ... Prompt: 11. The method for manufacturing
# Generating Prompt 190 ... Prompt: 17. The organic light emitting
# Generating Prompt 191 ... Prompt: 11. The display device of
# Generating Prompt 192 ... Prompt: 7. The method of claim
# Generating Prompt 193 ... Prompt: 10. The phase-change memory of
# Generating Prompt 194 ... Prompt: 5. The capacitor array of
# Generating Prompt 195 ... Prompt: 4. The method according to
# Generating Prompt 196 ... Prompt: 29. The organic light emitting
# Generating Prompt 197 ... Prompt: 3. The semiconductor die assembly
# Generating Prompt 198 ... Prompt: 17. The method as claimed
# Generating Prompt 199 ... Prompt: 3. The micro light emitting
# Generating Prompt 200 ... Prompt: 16. The method of claim
# Generating Prompt 201 ... Prompt: 5. The integrated circuit according
# Generating Prompt 202 ... Prompt: 9. A method for fabricating
# Generating Prompt 203 ... Prompt: 14. An integrated circuit comprising:
# Generating Prompt 204 ... Prompt: 6. The image sensor defined
# Generating Prompt 205 ... Prompt: 12. The organic light-emitting device
# Generating Prompt 206 ... Prompt: 9. The display apparatus of
# Generating Prompt 207 ... Prompt: 7. The semiconductor device of
# Generating Prompt 208 ... Prompt: 2. The organic molecule according
# Generating Prompt 209 ... Prompt: 29. The display apparatus according
# Generating Prompt 210 ... Prompt: 15. The sensor package of
# Generating Prompt 211 ... Prompt: 5. The display panel of
# Generating Prompt 212 ... Prompt: 10. The substrate support assembly
# Generating Prompt 213 ... Prompt: 3. A method as claimed
# Generating Prompt 214 ... Prompt: 7. The method for manufacturing
# Generating Prompt 215 ... Prompt: 3. The display apparatus of
# Generating Prompt 216 ... Prompt: 9. The method of claim
# Generating Prompt 217 ... Prompt: 8. An organic electric element
# Generating Prompt 218 ... Prompt: 9. The method of claim
# Generating Prompt 219 ... Prompt: 14. A display apparatus comprising:
# Generating Prompt 220 ... Prompt: 13. A display apparatus, comprising
# Generating Prompt 221 ... Prompt: 25. The electrical circuit of
# Generating Prompt 222 ... Prompt: 5. The integrated circuit according
# Generating Prompt 223 ... Prompt: 12. An electronic device comprising
# Generating Prompt 224 ... Prompt: 18. The system of claim
# Generating Prompt 225 ... Prompt: 8. The method for pre-aligning
# Generating Prompt 226 ... Prompt: 10. The method of claim
# Generating Prompt 227 ... Prompt: 10. The image sensor according
# Generating Prompt 228 ... Prompt: 3. A three transistor ultraviolet
# Generating Prompt 229 ... Prompt: 12. The multi-junction solar cell
# Generating Prompt 230 ... Prompt: 19. The semiconductor device of
# Generating Prompt 231 ... Prompt: 13. The LED package structure
# Generating Prompt 232 ... Prompt: 16. The method of claim
# Generating Prompt 233 ... Prompt: 11. The semiconductor device according
# Generating Prompt 234 ... Prompt: 5. The structure of claim
# Generating Prompt 235 ... Prompt: 34. An organic electroluminescent device
# Generating Prompt 236 ... Prompt: 17. The method of claim
# Generating Prompt 237 ... Prompt: 7. The pixel circuit according
# Generating Prompt 238 ... Prompt: 13. The microfluidic system of
# Generating Prompt 239 ... Prompt: 24. The stacked-die oscillator package
# Generating Prompt 240 ... Prompt: 3. The semiconductor device of
# Generating Prompt 241 ... Prompt: 18. The computing device of
# Generating Prompt 242 ... Prompt: 1. A package structure comprising:
# Generating Prompt 243 ... Prompt: 17. The imaging sensor according
# Generating Prompt 244 ... Prompt: 6. The method of claim
# Generating Prompt 245 ... Prompt: 10. The fabricating method of
# Generating Prompt 246 ... Prompt: 19. A method of using
# Generating Prompt 247 ... Prompt: 4. The organic light-emitting device
# Generating Prompt 248 ... Prompt: 2. The solid-state imaging element
# Generating Prompt 249 ... Prompt: 12. The method according to
# Generating Prompt 250 ... Prompt: 6. The organic metal complex
# Generating Prompt 251 ... Prompt: 7. The semiconductor device according
# Generating Prompt 252 ... Prompt: 7. The system of claim
# Generating Prompt 253 ... Prompt: 20. The image sensor according
# Generating Prompt 254 ... Prompt: 9. The method for producing
# Generating Prompt 255 ... Prompt: 6. The compound of claim
# Generating Prompt 256 ... Prompt: 16. The flexible display device
# Generating Prompt 257 ... Prompt: 6. The method for manufacturing
# Generating Prompt 258 ... Prompt: 19. The method of claim
# Generating Prompt 259 ... Prompt: 14. A computer-implemented method for
# Generating Prompt 260 ... Prompt: 1. An image sensor comprising;
# Generating Prompt 261 ... Prompt: 2. The method according to
# Generating Prompt 262 ... Prompt: 5. The drive circuit of
# Generating Prompt 263 ... Prompt: 5. The display device according
# Generating Prompt 264 ... Prompt: 6. The method of claim
# Generating Prompt 265 ... Prompt: 7. The polishing composition of
# Generating Prompt 266 ... Prompt: 6. The display device of
# Generating Prompt 267 ... Prompt: 7. The assembly of claim
# Generating Prompt 268 ... Prompt: 22. The electronic system of
# Generating Prompt 269 ... Prompt: 2. The electronic circuit as
# Generating Prompt 270 ... Prompt: 6. The image sensor defined
# Generating Prompt 271 ... Prompt: 1. A composition comprising a
# Generating Prompt 272 ... Prompt: 16. The organic light-emitting device
# Generating Prompt 273 ... Prompt: 10. The method of claim
# Generating Prompt 274 ... Prompt: 13. The memory of claim
# Generating Prompt 275 ... Prompt: 18. The method of claim
# Generating Prompt 276 ... Prompt: 8. The device according to
# Generating Prompt 277 ... Prompt: 27. The ASIC of claim
# Generating Prompt 278 ... Prompt: 6. The light-emitting device according
# Generating Prompt 279 ... Prompt: 11. The process of claim
# Generating Prompt 280 ... Prompt: 12. The device of claim
# Generating Prompt 281 ... Prompt: 9. The method defined in
# Generating Prompt 282 ... Prompt: 6. The display device of
# Generating Prompt 283 ... Prompt: 6. The device according to
# Generating Prompt 284 ... Prompt: 2. The integrated circuit device
# Generating Prompt 285 ... Prompt: 5. The method of fabricating
# Generating Prompt 286 ... Prompt: 15. The device according to
# Generating Prompt 287 ... Prompt: 1. A semiconductor device comprising:
# Generating Prompt 288 ... Prompt: 21. The organic light-emitting display
# Generating Prompt 289 ... Prompt: 11. The fabrication method according
# Generating Prompt 290 ... Prompt: 17. The method as claimed
# Generating Prompt 291 ... Prompt: 5. The semiconductor device of
# Generating Prompt 292 ... Prompt: 27. The display apparatus of
# Generating Prompt 293 ... Prompt: 9. The light-emitting device according
# Generating Prompt 294 ... Prompt: 16. The image sensor of
# Generating Prompt 295 ... Prompt: 16. The integrated circuit device
# Generating Prompt 296 ... Prompt: 3. The ASIC of claim
# Generating Prompt 297 ... Prompt: 2. The method of claim
# Generating Prompt 298 ... Prompt: 2. The compound of claim
# Generating Prompt 299 ... Prompt: 6. The magnetoresistance effect element
# Generating Prompt 300 ... Prompt: 5. The electronic device using
# Generating Prompt 301 ... Prompt: 9. The integrated circuit device
# Generating Prompt 302 ... Prompt: 11. The integrated circuit structure
# Generating Prompt 303 ... Prompt: 20. The magnetoresistance effect element
# Generating Prompt 304 ... Prompt: 1. A method for verifying
# Generating Prompt 305 ... Prompt: 4. The compound according to
# Generating Prompt 306 ... Prompt: 29. The electrical circuit of
# Generating Prompt 307 ... Prompt: 3. The ASIC of claim
# Generating Prompt 308 ... Prompt: 16. An electronic component comprising
# Generating Prompt 309 ... Prompt: 8. The display device according
# Generating Prompt 310 ... Prompt: 22. The current sensor package
# Generating Prompt 311 ... Prompt: 2. The compound of claim
# Generating Prompt 312 ... Prompt: 19. The method of manufacturing
# Generating Prompt 313 ... Prompt: 10. The organic light emitting
# Generating Prompt 314 ... Prompt: 18. The organic light-emitting display
# Generating Prompt 315 ... Prompt: 2. The display device according
# Generating Prompt 316 ... Prompt: 8. The method according to
# Generating Prompt 317 ... Prompt: 10. The method for manufacturing
# Generating Prompt 318 ... Prompt: 7. The pattern forming method
# Generating Prompt 319 ... Prompt: 1. A digitally controlled oscillator
# Generating Prompt 320 ... Prompt: 7. An electronic device that
# Generating Prompt 321 ... Prompt: 3. The method of claim
# Generating Prompt 322 ... Prompt: 7. An electric element cooling
# Generating Prompt 323 ... Prompt: 9. The method of claim
# Generating Prompt 324 ... Prompt: 23. The apparatus of claim
# Generating Prompt 325 ... Prompt: 5. The solid-state imaging element
# Generating Prompt 326 ... Prompt: 6. The method for producing
# Generating Prompt 327 ... Prompt: 7. The apparatus of claim
# Generating Prompt 328 ... Prompt: 15. The display device of
# Generating Prompt 329 ... Prompt: 10. The microfluidic system of
# Generating Prompt 330 ... Prompt: 2. The chip package as
# Generating Prompt 331 ... Prompt: 9. The method of claim
# Generating Prompt 332 ... Prompt: 6. The method of claim
# Generating Prompt 333 ... Prompt: 10. The display panel of
# Generating Prompt 334 ... Prompt: 2. The integrated circuit device
# Generating Prompt 335 ... Prompt: 1. A method of manufacturing
# Generating Prompt 336 ... Prompt: 7. The assembly of claim
# Generating Prompt 337 ... Prompt: 12. The image sensor of
# Generating Prompt 338 ... Prompt: 4. The device of claim
# Generating Prompt 339 ... Prompt: 4. The method of claim
# Generating Prompt 340 ... Prompt: 8. The system according to
# Generating Prompt 341 ... Prompt: 17. The device according to
# Generating Prompt 342 ... Prompt: 1. A radio-frequency (RF) module
# Generating Prompt 343 ... Prompt: 15. The method according to
# Generating Prompt 344 ... Prompt: 4. The method of claim
# Generating Prompt 345 ... Prompt: 9. The system of claim
# Generating Prompt 346 ... Prompt: 2. The composition of matter
# Generating Prompt 347 ... Prompt: 20. The method of the
# Generating Prompt 348 ... Prompt: 18. The method of the
# Generating Prompt 349 ... Prompt: 25. The method of claim
# Generating Prompt 350 ... Prompt: 9. The organic light-emitting device
# Generating Prompt 351 ... Prompt: 11. The sensor package of
# Generating Prompt 352 ... Prompt: 10. A magnetic memory device
# Generating Prompt 353 ... Prompt: 11. The chip package as
# Generating Prompt 354 ... Prompt: 7. The process of claim
# Generating Prompt 355 ... Prompt: 16. A rollable display apparatus
# Generating Prompt 356 ... Prompt: 2. The module of claim
# Generating Prompt 357 ... Prompt: 14. The shift register according
# Generating Prompt 358 ... Prompt: 12. The optoelectronic arrangement according
# Generating Prompt 359 ... Prompt: 3. The IC assembly of
# Generating Prompt 360 ... Prompt: 21. The circuit of claim
# Generating Prompt 361 ... Prompt: 30. The organic light emitting
# Generating Prompt 362 ... Prompt: 2. The magnetoresistance effect element
# Generating Prompt 363 ... Prompt: 23. The circuit of claim
# Generating Prompt 364 ... Prompt: 16. A computing device, comprising:
# Generating Prompt 365 ... Prompt: 3. The analog-to-digital converter of
# Generating Prompt 366 ... Prompt: 8. The method according to
# Generating Prompt 367 ... Prompt: 2. A multi-layer random access
# Generating Prompt 368 ... Prompt: 7. The electronic apparatus according
# Generating Prompt 369 ... Prompt: 10. The OLED device according
# Generating Prompt 370 ... Prompt: 2. The light-emitting semiconductor chip
# Generating Prompt 371 ... Prompt: 16. The semiconductor device according
# Generating Prompt 372 ... Prompt: 6. The imaging sensor according
# Generating Prompt 373 ... Prompt: 9. The display panel according
# Generating Prompt 374 ... Prompt: 17. The vibration-type actuator according
# Generating Prompt 375 ... Prompt: 6. The method for manufacturing
# Generating Prompt 376 ... Prompt: 2. The memory of claim
# Generating Prompt 377 ... Prompt: 25. The organic light-emitting display
# Generating Prompt 378 ... Prompt: 7. The organic light-emitting display
# Generating Prompt 379 ... Prompt: 15. The manufacturing method according
# Generating Prompt 380 ... Prompt: 8. A mixture comprising at
# Generating Prompt 381 ... Prompt: 2. The organic light emitting
# Generating Prompt 382 ... Prompt: 14. The ASIC of claim
# Generating Prompt 383 ... Prompt: 12. The manufacturing method according
# Generating Prompt 384 ... Prompt: 12. A biological sensor comprising:
# Generating Prompt 385 ... Prompt: 10. The method of claim
# Generating Prompt 386 ... Prompt: 26. The organic light emitting
# Generating Prompt 387 ... Prompt: 19. The method according to
# Generating Prompt 388 ... Prompt: 23. The computing device of
# Generating Prompt 389 ... Prompt: 10. The carbon nanotube nanostructure
# Generating Prompt 390 ... Prompt: 6. The display apparatus of
# Generating Prompt 391 ... Prompt: 16. The fabrication method according
# Generating Prompt 392 ... Prompt: 20. A neuromorphic computer including
# Generating Prompt 393 ... Prompt: 29. The ASIC of claim
# Generating Prompt 394 ... Prompt: 17. The pixel array of
# Generating Prompt 395 ... Prompt: 9. The method of claim
# Generating Prompt 396 ... Prompt: 18. A chaos nanonet-based physical
# Generating Prompt 397 ... Prompt: 3. The Doherty amplifier of
# Generating Prompt 398 ... Prompt: 19. The apparatus as recited
# Generating Prompt 399 ... Prompt: 9. The device according to
# Generating Prompt 400 ... Prompt: 16. The wiring layer laminate
# Generating Prompt 401 ... Prompt: 3. The semiconductor device according
# Generating Prompt 402 ... Prompt: 14. The method of claim
# Generating Prompt 403 ... Prompt: 17. The packaging method of
# Generating Prompt 404 ... Prompt: 2. The method of claim
# Generating Prompt 405 ... Prompt: 4. The organic light emitting
# Generating Prompt 406 ... Prompt: 3. A method of forming
# Generating Prompt 407 ... Prompt: 8. The composition of matter
# Generating Prompt 408 ... Prompt: 10. The device according to
# Generating Prompt 409 ... Prompt: 17. The method of claim
# Generating Prompt 410 ... Prompt: 19. A method of manufacturing
# Generating Prompt 411 ... Prompt: 9. The preparation method according
# Generating Prompt 412 ... Prompt: 2. The composition according to
# Generating Prompt 413 ... Prompt: 1. An organic electric element
# Generating Prompt 414 ... Prompt: 17. The display panel according
# Generating Prompt 415 ... Prompt: 6. The method of claim
# Generating Prompt 416 ... Prompt: 8. An electronic apparatus, including:
# Generating Prompt 417 ... Prompt: 19. The electronic apparatus of
# Generating Prompt 418 ... Prompt: 30. A display apparatus, comprising:
# Generating Prompt 419 ... Prompt: 6. The organic electroluminescent device
# Generating Prompt 420 ... Prompt: 13. The method as claimed
# Generating Prompt 421 ... Prompt: 7. The organic light emitting
# Generating Prompt 422 ... Prompt: 4. The printed circuit board
# Generating Prompt 423 ... Prompt: 3. The solar cell of
# Generating Prompt 424 ... Prompt: 13. The organic electronic device
# Generating Prompt 425 ... Prompt: 15. The method of claim
# Generating Prompt 426 ... Prompt: 9. The method of claim
# Generating Prompt 427 ... Prompt: 8. The apparatus of claim
# Generating Prompt 428 ... Prompt: 12. The heat-pipe membrane assembly
# Generating Prompt 429 ... Prompt: 8. The heat-dissipating substrate as
# Generating Prompt 430 ... Prompt: 12. The device according to
# Generating Prompt 431 ... Prompt: 10. The semiconductor memory device
# Generating Prompt 432 ... Prompt: 19. The method of claim
# Generating Prompt 433 ... Prompt: 13. The integrated circuit device
# Generating Prompt 434 ... Prompt: 22. The display panel according
# Generating Prompt 435 ... Prompt: 15. The method of claim
# Generating Prompt 436 ... Prompt: 7. The carbon nanotube nanostructure
# Generating Prompt 437 ... Prompt: 4. The IC assembly of
# Generating Prompt 438 ... Prompt: 4. The compound according to
# Generating Prompt 439 ... Prompt: 19. The surface treatment method
# Generating Prompt 440 ... Prompt: 16. A memory package comprising:
# Generating Prompt 441 ... Prompt: 5. The flexible display apparatus
# Generating Prompt 442 ... Prompt: 12. The sensor package of
# Generating Prompt 443 ... Prompt: 19. A method of manufacturing
# Generating Prompt 444 ... Prompt: 3. The module of claim
# Generating Prompt 445 ... Prompt: 2. The method according to
# Generating Prompt 446 ... Prompt: 26. The method according to
# Generating Prompt 447 ... Prompt: 13. The method as claimed
# Generating Prompt 448 ... Prompt: 1. A chip accommodation tray
# Generating Prompt 449 ... Prompt: 9. The method of claim
# Generating Prompt 450 ... Prompt: 4. The method of claim
# Generating Prompt 451 ... Prompt: 7. The display device of
# Generating Prompt 452 ... Prompt: 29. The display apparatus according
# Generating Prompt 453 ... Prompt: 5. The process of claim
# Generating Prompt 454 ... Prompt: 3. The organic electroluminescent device
# Generating Prompt 455 ... Prompt: 21. The semiconductor device according
# Generating Prompt 456 ... Prompt: 4. The method of claim
# Generating Prompt 457 ... Prompt: 9. The LDMOS transistor of
# Generating Prompt 458 ... Prompt: 17. The non-transitory computer-readable medium
# Generating Prompt 459 ... Prompt: 16. The method of claim
# Generating Prompt 460 ... Prompt: 17. The method as claimed
# Generating Prompt 461 ... Prompt: 2. The semiconductor device according
# Generating Prompt 462 ... Prompt: 19. An emitter comprising: a
# Generating Prompt 463 ... Prompt: 4. The method of claim
# Generating Prompt 464 ... Prompt: 17. The method of claim
# Generating Prompt 465 ... Prompt: 8. The light emitting device
# Generating Prompt 466 ... Prompt: 8. A semiconductor device, comprising:
# Generating Prompt 467 ... Prompt: 13. The semiconductor device of
# Generating Prompt 468 ... Prompt: 20. The method of claim
# Generating Prompt 469 ... Prompt: 8. The organic light-emitting device
# Generating Prompt 470 ... Prompt: 5. The method of claim
# Generating Prompt 471 ... Prompt: 4. The method as claimed
# Generating Prompt 472 ... Prompt: 3. The system of claim
# Generating Prompt 473 ... Prompt: 9. A display apparatus, comprising
# Generating Prompt 474 ... Prompt: 6. The reheating collection device
# Generating Prompt 475 ... Prompt: 25. A method comprising: providing
# Generating Prompt 476 ... Prompt: 15. The module of claim
# Generating Prompt 477 ... Prompt: 38. The compound according to
# Generating Prompt 478 ... Prompt: 8. The display device according
# Generating Prompt 479 ... Prompt: 8. The display substrate according
# Generating Prompt 480 ... Prompt: 9. The carbon nanotube nanostructure
# Generating Prompt 481 ... Prompt: 24. The electronic system of
# Generating Prompt 482 ... Prompt: 1. A compound represented by
# Generating Prompt 483 ... Prompt: 22. The apparatus of claim
# Generating Prompt 484 ... Prompt: 6. The device of claim
# Generating Prompt 485 ... Prompt: 16. A biological sensor comprising:
# Generating Prompt 486 ... Prompt: 15. The chaos nanonet device
# Generating Prompt 487 ... Prompt: 10. The organic light emitting
# Generating Prompt 488 ... Prompt: 1. A wiring layer laminate
# Generating Prompt 489 ... Prompt: 6. The pixel of claim
# Generating Prompt 490 ... Prompt: 18. The flow controller according
# Generating Prompt 491 ... Prompt: 1. An image sensor comprising;
# Generating Prompt 492 ... Prompt: 18. The method of manufacturing
# Generating Prompt 493 ... Prompt: 11. The wiring layer laminate
# Generating Prompt 494 ... Prompt: 11. The method as claimed
# Generating Prompt 495 ... Prompt: 1. A reheating collection device
# Generating Prompt 496 ... Prompt: 19. The light-emitting element according
# Generating Prompt 497 ... Prompt: 13. The method of claim
# Generating Prompt 498 ... Prompt: 4. The method of claim
# Generating Prompt 499 ... Prompt: 13. The method of claim
# Generating Prompt 500 ... Prompt: 15. A semiconductor structure for
# Generating Prompt 501 ... Prompt: 15. The wiring layer laminate
# Generating Prompt 502 ... Prompt: 15. The method of claim
# Generating Prompt 503 ... Prompt: 32. The organic light emitting
# Generating Prompt 504 ... Prompt: 2. The method of manufacturing
# Generating Prompt 505 ... Prompt: 2. The random number generator
# Generating Prompt 506 ... Prompt: 9. The semiconductor device of
# Generating Prompt 507 ... Prompt: 22. An anti-tamper system according
# Generating Prompt 508 ... Prompt: 16. The flow controller according
# Generating Prompt 509 ... Prompt: 2. The method of manufacturing
# Generating Prompt 510 ... Prompt: 16. An electronic component comprising
# Generating Prompt 511 ... Prompt: 2. The semiconductor structure of
# Generating Prompt 512 ... Prompt: 8. The display substrate according
# Generating Prompt 513 ... Prompt: 10. The organic electronic device
# Generating Prompt 514 ... Prompt: 9. The manufacturing method of
# Generating Prompt 515 ... Prompt: 2. The composition according to
# Generating Prompt 516 ... Prompt: 19. The semiconductor structure of
# Generating Prompt 517 ... Prompt: 6. The hermetic capsule claimed
# Generating Prompt 518 ... Prompt: 9. The apparatus for manufacturing
# Generating Prompt 519 ... Prompt: 32. The organic light emitting
# Generating Prompt 520 ... Prompt: 2. The method of claim
# Generating Prompt 521 ... Prompt: 14. The display apparatus of
# Generating Prompt 522 ... Prompt: 20. The method according to
# Generating Prompt 523 ... Prompt: 6. The display device of
# Generating Prompt 524 ... Prompt: 11. The organic light-emitting device
# Generating Prompt 525 ... Prompt: 12. The solid-state stacked chip
# Generating Prompt 526 ... Prompt: 8. The integrated assembly of
# Generating Prompt 527 ... Prompt: 12. The wiring layer laminate
# Generating Prompt 528 ... Prompt: 13. The image display device
# Generating Prompt 529 ... Prompt: 19. The image sensor according
# Generating Prompt 530 ... Prompt: 20. The method of claim
# Generating Prompt 531 ... Prompt: 1. An organic light-emitting device,
# Generating Prompt 532 ... Prompt: 14. The OLED device according
# Generating Prompt 533 ... Prompt: 13. A display device, comprising:
# Generating Prompt 534 ... Prompt: 4. The hetero-cyclic compound of
# Generating Prompt 535 ... Prompt: 1. A method of manufacturing
# Generating Prompt 536 ... Prompt: 20. The semiconductor light emitting
# Generating Prompt 537 ... Prompt: 3. The composition of matter
# Generating Prompt 538 ... Prompt: 11. A pickup sensor comprising
# Generating Prompt 539 ... Prompt: 13. An electronic device comprising
# Generating Prompt 540 ... Prompt: 10. The electronic apparatus according
# Generating Prompt 541 ... Prompt: 1. A substrate support, comprising:
# Generating Prompt 542 ... Prompt: 6. The manufacturing apparatus according
# Generating Prompt 543 ... Prompt: 9. A capacitor unit, comprising:
# Generating Prompt 544 ... Prompt: 3. The display device according
# Generating Prompt 545 ... Prompt: 21. A quantum computer including
# Generating Prompt 546 ... Prompt: 3. The semiconductor memory device
# Generating Prompt 547 ... Prompt: 16. The non-transitory computer-readable medium
# Generating Prompt 548 ... Prompt: 12. An electronic device comprising
# Generating Prompt 549 ... Prompt: 10. The method of claim
# Generating Prompt 550 ... Prompt: 3. The apparatus of claim
# Generating Prompt 551 ... Prompt: 4. The semiconductor device according
# Generating Prompt 552 ... Prompt: 16. The method of claim
# Generating Prompt 553 ... Prompt: 36. The process as claimed
# Generating Prompt 554 ... Prompt: 11. The display device according
# Generating Prompt 555 ... Prompt: 9. The display substrate according
# Generating Prompt 556 ... Prompt: 18. A method of forming
# Generating Prompt 557 ... Prompt: 8. The organic light-emitting display
# Generating Prompt 558 ... Prompt: 4. The system of claim
# Generating Prompt 559 ... Prompt: 13. The chaos nanonet device
# Generating Prompt 560 ... Prompt: 8. An integrated circuit (IC)
# Generating Prompt 561 ... Prompt: 3. The solar cell of
# Generating Prompt 562 ... Prompt: 2. The organic light emitting
# Generating Prompt 563 ... Prompt: 16. The semiconductor device of
# Generating Prompt 564 ... Prompt: 10. An integrated circuit comprising:
# Generating Prompt 565 ... Prompt: 4. The method of manufacturing
# Generating Prompt 566 ... Prompt: 16. A display apparatus comprising:
# Generating Prompt 567 ... Prompt: 17. The image sensor according
# Generating Prompt 568 ... Prompt: 16. The method according to
# Generating Prompt 569 ... Prompt: 20. The memory package of
# Generating Prompt 570 ... Prompt: 2. The pixel circuit according
# Generating Prompt 571 ... Prompt: 3. The semiconductor device according
# Generating Prompt 572 ... Prompt: 2. The method according to
# Generating Prompt 573 ... Prompt: 21. The integrated circuit device
# Generating Prompt 574 ... Prompt: 12. The method of claim
# Generating Prompt 575 ... Prompt: 2. The method of claim
# Generating Prompt 576 ... Prompt: 20. The method according to
# Generating Prompt 577 ... Prompt: 1. An electrical circuit, comprising:
# Generating Prompt 578 ... Prompt: 15. The integrated circuit according
# Generating Prompt 579 ... Prompt: 19. The method for emitting
# Generating Prompt 580 ... Prompt: 22. The organic light emitting
# Generating Prompt 581 ... Prompt: 17. The display device according
# Generating Prompt 582 ... Prompt: 5. The method for manufacturing
# Generating Prompt 583 ... Prompt: 2. The pixel of claim
# Generating Prompt 584 ... Prompt: 22. The method according to
# Generating Prompt 585 ... Prompt: 3. The display device of
# Generating Prompt 586 ... Prompt: 19. The phase-change memory of
# Generating Prompt 587 ... Prompt: 17. The organic light-emitting device
# Generating Prompt 588 ... Prompt: 17. The computing device of
# Generating Prompt 589 ... Prompt: 8. An organic electronic device
# Generating Prompt 590 ... Prompt: 18. The ASIC of claim
# Generating Prompt 591 ... Prompt: 3. The semiconductor structure of
# Generating Prompt 592 ... Prompt: 10. The light-emitting device according
# Generating Prompt 593 ... Prompt: 7. The composition of claim
# Generating Prompt 594 ... Prompt: 3. The imaging unit according
# Generating Prompt 595 ... Prompt: 20. The device according to
# Generating Prompt 596 ... Prompt: 1. A multi-junction solar cell,
# Generating Prompt 597 ... Prompt: 11. The semiconductor device of
# Generating Prompt 598 ... Prompt: 14. An image sensor comprising:
# Generating Prompt 599 ... Prompt: 12. The heat-pipe membrane assembly
# Generating Prompt 600 ... Prompt: 15. A foldable display device,
# Generating Prompt 601 ... Prompt: 13. The Doherty amplifier of
# Generating Prompt 602 ... Prompt: 10. The light emitting device
# Generating Prompt 603 ... Prompt: 19. The pixel of claim
# Generating Prompt 604 ... Prompt: 14. The device of claim
# Generating Prompt 605 ... Prompt: 5. The semiconductor memory device
# Generating Prompt 606 ... Prompt: 10. The method of claim
# Generating Prompt 607 ... Prompt: 14. An integrated circuit comprising:
# Generating Prompt 608 ... Prompt: 1. An organic light-emitting display
# Generating Prompt 609 ... Prompt: 9. The organic light-emitting device
# Generating Prompt 610 ... Prompt: 4. The electrical circuit of
# Generating Prompt 611 ... Prompt: 2. The organic light-emitting device
# Generating Prompt 612 ... Prompt: 4. The polishing agent according
# Generating Prompt 613 ... Prompt: 10. The method of claim
# Generating Prompt 614 ... Prompt: 16. The pixel of claim
# Generating Prompt 615 ... Prompt: 18. The microelectronic structure of
# Generating Prompt 616 ... Prompt: 15. The manufacturing method according
# Generating Prompt 617 ... Prompt: 9. A pixel assembly according
# Generating Prompt 618 ... Prompt: 19. A stacked three-dimensional integrated
# Generating Prompt 619 ... Prompt: 8. The semiconductor device of
# Generating Prompt 620 ... Prompt: 30. The method according to

# %%
fake_data = pd.read_csv("Models/Experiments/Claims/10epochs/fake_patent_claims.csv")
# fake_data = pd.read_csv("./Models/Experiments/Abstracts/fake_patent_abstracts_3epochs.csv")
fake_data = fake_data.loc[:, ~fake_data.columns.str.contains('^Unnamed')]
fake_data.head()
# Out:
#                                               Claims  Label
# 0  4. The acoustic resonator structure of claim 1...      1
# 1  16. The method according to claim 1, wherein t...      1
# 2  9. The method of claim 8, further comprising: ...      1
# 3  6. The stacked CMOS image sensor of claim 1, w...      1
# 4  1. A display device comprising: a base substra...      1

# %%
len(fake_data)
# Out:
# 8420

# %%
frames = [real_data, fake_data]
full_data = pd.concat(frames)


full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data
# Out:
#                                                   Claims  Label
# 0      3.  The device of claim 1, further comprising:...      0
# 1      8. The heater cleaning method according to cla...      1
# 2      13.  The method of claim 12, wherein the provi...      0
# 3      26. The pixel of claim 28, wherein said CTIA c...      1
# 4      10. An image sensor, comprising: a plurality o...      1
# ...                                                  ...    ...
# 16835  9.  The method of manufacturing a plurality of...      0
# 16836  2. The polishing agent according to claim 6, w...      1
# 16837  2.  The semiconductor die of claim 1, wherein ...      0
# 16838  5. The integrated circuit according to claim 6...      1
# 16839  6. The organic light emitting diode as claimed...      1
#
# [16840 rows x 2 columns]

# %%
len(full_data['Claims'][0])
# Out:
# 137

# %%
# path: "Models/Experiments/Claims"
full_data.to_csv("./Models/Experiments/Claims/10epochs/real_fake_claims.csv")

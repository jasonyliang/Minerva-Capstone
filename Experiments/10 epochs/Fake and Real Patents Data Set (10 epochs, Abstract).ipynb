# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# import from library
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import torch
# from fake_claims_generator import generate, grab_random_prompts

# %%
#!pip3 install git+https://github.com/huggingface/transformers@v3.1.0 # there were errors in the later versions, this version allows us to do our job for now
# !pip3 install transformers==3.3.1
# Out:
# Collecting transformers==3.3.1
#   Downloading https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 13.3MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (1.19.5)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 50.4MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (20.9)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (0.8)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 60.7MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.3.1) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 59.4MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.3.1) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.3.1) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.3.1) (1.0.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=698e3f82af066b4737bd952dc23ab9928c258118cd8c9aae11e4852919ef703e
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc2 transformers-3.3.1

# %%
# import necessary GPT-2 model architecture and tokenizer
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# %cd drive/My\ Drive/School\ Work/Fourth\ Year/Capstone\ Everything
# Out:
# /content/drive/My Drive/School Work/Fourth Year/Capstone Everything

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts

OUTPUT_DIR = "./Models/Experiments/Abstracts/10epochs" # the model for abstract is stored here
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    '''
    This is the main generation code using our model
    '''
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ## Load Real Data and Label Them

# %%
data = pd.read_csv("./Models/Data/H04L.csv")
real_data = pd.DataFrame({"Abstract": data["abstract"]})
real_data["Label"] = 0
real_data = real_data[real_data['Abstract'].notnull()]

# %%
real_data # shows some of the real patent claims
# Out:
#                                                Abstract  Label
# 0     An organic light emitting diode display includ...      0
# 1     Provided is an electric element cooling module...      0
# 2     An organic light emitting diode display includ...      0
# 3     Provided is an electric element cooling module...      0
# 4     An organic light emitting diode display includ...      0
# ...                                                 ...    ...
# 8942  A method including patterning a continuous fin...      0
# 8943  A method including patterning a continuous fin...      0
# 8944  A method including patterning a continuous fin...      0
# 8945  A method including patterning a continuous fin...      0
# 8946  A method including patterning a continuous fin...      0
#
# [8947 rows x 2 columns]

# %% [markdown]
# ## Generate Fake Data and Label Them

# %%
# How many fake claims do you want to generate
# num_fake_claims = len(real_data)
# prompts = grab_random_prompts(data, num_fake_claims, first_words=5)
# fake_claims = []
# for i, prompt in enumerate(prompts):
#     print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
#     generated_text = generate(prompt, n=8)
#     fake_claims.append(generated_text)

# %%
# write in chunks, and write to csv
'''
This code block is responsible for generating fake patent abstracts
I first deine the file paths where we will save the fake patent data
Then, I generate the fake patent prompts by sampling from the real abstracts
I save the prompts into a csv file.
Since I am running the generation on Colab and I'm generating thousands of fake patent abstracts,
there is a high frequency of interuption, I therefore need to save the prompts (to be accessed later),
and save the patent abstracts for every 100 that are generated.
The last_interupted variable stores where the generation was last interupted.
'''
import os.path
fake_data_file = "./Models/Experiments/Abstracts/10epochs/fake_patent_abstracts.csv"
prompt_file = "./Models/Experiments/Abstracts/10epochs/prompts.csv"
num_fake_claims = len(real_data)
if os.path.exists(prompt_file):
  prompts = pd.read_csv(prompt_file)
  prompts = prompts['Prompts'].tolist()
else:
  prompts = grab_random_prompts(data, num_fake_claims, first_words=5, column='abstract')
  # save prompts
  prompt_df = pd.DataFrame({"Prompts": prompts})
  prompt_df.to_csv(prompt_file)
fake_abstracts = []
last_interupted = 5400
for i, prompt in enumerate(prompts[last_interupted:]): # modify last_interupted if we got disconnected
    if i % 100 == 0 and i != 0: # for every 100 abstracts
      df = pd.DataFrame({"Abstract": fake_abstracts, "Label": 1})
      if os.path.exists(fake_data_file): # this means this csv is already created
        df.to_csv(fake_data_file, mode='a', header=False)
      else:
        df.to_csv(fake_data_file)
      fake_abstracts = []
    print(f"Generating Prompt {i+1} ... Prompt: {prompt}")
    generated_text = generate(prompt, n=8)
    fake_abstracts.append(generated_text)
# last batch (that doesn't go over 100)
df = pd.DataFrame({"Claims": fake_abstracts, "Label": 1})
df.to_csv(fake_data_file, mode='a', header=False)
# Out:
# Generating Prompt 1 ... Prompt: A solar cell includes a
# Generating Prompt 2 ... Prompt: Disclosed herein is an organic
# Generating Prompt 3 ... Prompt: A solid-state image pickup device
# Generating Prompt 4 ... Prompt: A substrate support assembly for
# Generating Prompt 5 ... Prompt: An organic light emitting display
# Generating Prompt 6 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 7 ... Prompt: We describe a method for
# Generating Prompt 8 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 9 ... Prompt: A method of manufacturing a
# Generating Prompt 10 ... Prompt: A semiconductor device includes a
# Generating Prompt 11 ... Prompt: A chip accommodation tray for
# Generating Prompt 12 ... Prompt: A method of manufacturing a
# Generating Prompt 13 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 14 ... Prompt: A group III-N nanowire is
# Generating Prompt 15 ... Prompt: A three-dimensional memory device including
# Generating Prompt 16 ... Prompt: A semiconductor device has a
# Generating Prompt 17 ... Prompt: A package for housing an
# Generating Prompt 18 ... Prompt: A semiconductor device according to
# Generating Prompt 19 ... Prompt: We describe a method for
# Generating Prompt 20 ... Prompt: The present disclosure discloses a
# Generating Prompt 21 ... Prompt: In accordance with an embodiment,
# Generating Prompt 22 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 23 ... Prompt: A microelectronic structure includes a
# Generating Prompt 24 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 25 ... Prompt: A device includes a substrate
# Generating Prompt 26 ... Prompt: A thermally conductive article including
# Generating Prompt 27 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 28 ... Prompt: An application specific integrated circuit
# Generating Prompt 29 ... Prompt: The invention relates to an
# Generating Prompt 30 ... Prompt: An organic light-emitting display including
# Generating Prompt 31 ... Prompt: The present disclosure describes additives
# Generating Prompt 32 ... Prompt: Systems and methods for detecting
# Generating Prompt 33 ... Prompt: Structures and formation methods of
# Generating Prompt 34 ... Prompt: The present invention relates to
# Generating Prompt 35 ... Prompt: A method of fabricating a
# Generating Prompt 36 ... Prompt: According to one embodiment, a
# Generating Prompt 37 ... Prompt: A substrate processing apparatus includes
# Generating Prompt 38 ... Prompt: A display apparatus includes a
# Generating Prompt 39 ... Prompt: A reheating collection device for
# Generating Prompt 40 ... Prompt: A solar cell includes a
# Generating Prompt 41 ... Prompt: To provide a coating fluid
# Generating Prompt 42 ... Prompt: The disclosure provides a package
# Generating Prompt 43 ... Prompt: Use of transition metal complexes
# Generating Prompt 44 ... Prompt: Various embodiments of the present
# Generating Prompt 45 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 46 ... Prompt: A display unit includes a
# Generating Prompt 47 ... Prompt: The present disclosure relates to
# Generating Prompt 48 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 49 ... Prompt: A light emitting diode (LED)
# Generating Prompt 50 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 51 ... Prompt: A display apparatus includes a
# Generating Prompt 53 ... Prompt: A light-emitting element having high
# Generating Prompt 54 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 55 ... Prompt: The present invention discloses a
# Generating Prompt 56 ... Prompt: A method for transporting a
# Generating Prompt 57 ... Prompt: A method for transporting a
# Generating Prompt 58 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 59 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 60 ... Prompt: A memory device includes first
# Generating Prompt 61 ... Prompt: The present invention provides an
# Generating Prompt 62 ... Prompt: Provided are a pickup sensor
# Generating Prompt 63 ... Prompt: CMOS circuits may formed using
# Generating Prompt 64 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 65 ... Prompt: An emitter for an LED-based
# Generating Prompt 66 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 67 ... Prompt: An organic light emitting display
# Generating Prompt 68 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 69 ... Prompt: A heat sink assembly for
# Generating Prompt 70 ... Prompt: A semiconductor device includes a
# Generating Prompt 71 ... Prompt: An organic EL display device
# Generating Prompt 72 ... Prompt: A method of manufacturing a
# Generating Prompt 73 ... Prompt: A reheating collection device for
# Generating Prompt 74 ... Prompt: Disclosed is a light emitting
# Generating Prompt 75 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 76 ... Prompt: An embodiment includes a memory
# Generating Prompt 77 ... Prompt: An organic light-emitting display including
# Generating Prompt 78 ... Prompt: The present specification relates to
# Generating Prompt 79 ... Prompt: An arc detector includes a
# Generating Prompt 80 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 81 ... Prompt: Embodiments are directed to a
# Generating Prompt 82 ... Prompt: Semiconductor devices may include a
# Generating Prompt 83 ... Prompt: Provided are a pickup sensor
# Generating Prompt 84 ... Prompt: A light emitting diode (LED)
# Generating Prompt 85 ... Prompt: Embodiments of this invention relate
# Generating Prompt 86 ... Prompt: Provided are a compound represented
# Generating Prompt 87 ... Prompt: A display device includes: a
# Generating Prompt 88 ... Prompt: An imaging element includes a
# Generating Prompt 89 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 90 ... Prompt: The present invention relates to
# Generating Prompt 91 ... Prompt: A first III-V material based
# Generating Prompt 92 ... Prompt: An organic EL display device
# Generating Prompt 93 ... Prompt: A method is presented for
# Generating Prompt 94 ... Prompt: A method for pre-aligning a
# Generating Prompt 95 ... Prompt: We describe a method for
# Generating Prompt 96 ... Prompt: A data reading error is
# Generating Prompt 97 ... Prompt: A microelectronic structure includes a
# Generating Prompt 98 ... Prompt: A first III-V material based
# Generating Prompt 99 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 100 ... Prompt: Disclosed is an infrared light
# Generating Prompt 101 ... Prompt: The present specification relates to
# Generating Prompt 102 ... Prompt: The present disclosure describes additives
# Generating Prompt 103 ... Prompt: Provided is an electric element
# Generating Prompt 104 ... Prompt: The present disclosure relates to
# Generating Prompt 105 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 106 ... Prompt: According to one embodiment, a
# Generating Prompt 107 ... Prompt: A display device includes a
# Generating Prompt 108 ... Prompt: Disclosed are a display substrate,
# Generating Prompt 109 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 110 ... Prompt: A light emitting device and
# Generating Prompt 111 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 112 ... Prompt: Some embodiments include an integrated
# Generating Prompt 113 ... Prompt: The various embodiments described herein
# Generating Prompt 114 ... Prompt: An enclosure for a radiographic
# Generating Prompt 115 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 116 ... Prompt: A display device includes: a
# Generating Prompt 117 ... Prompt: An application specific integrated circuit
# Generating Prompt 118 ... Prompt: An integrated circuit device includes
# Generating Prompt 119 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 120 ... Prompt: A method is provided for
# Generating Prompt 121 ... Prompt: A display apparatus includes: a
# Generating Prompt 122 ... Prompt: A memory device includes first
# Generating Prompt 123 ... Prompt: A display device is described.
# Generating Prompt 124 ... Prompt: Various embodiments of the present
# Generating Prompt 125 ... Prompt: A display apparatus includes a
# Generating Prompt 126 ... Prompt: The present invention relates to
# Generating Prompt 127 ... Prompt: To provide a light-emitting element
# Generating Prompt 128 ... Prompt: Solar cells having a plurality
# Generating Prompt 129 ... Prompt: A semiconductor device includes a
# Generating Prompt 130 ... Prompt: A substrate support assembly for
# Generating Prompt 131 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 132 ... Prompt: A system for surface patterning
# Generating Prompt 133 ... Prompt: According to an aspect, a
# Generating Prompt 134 ... Prompt: To reduce influence occurring between
# Generating Prompt 135 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 136 ... Prompt: A method of packaging CSP
# Generating Prompt 137 ... Prompt: Provided are a compound represented
# Generating Prompt 138 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 139 ... Prompt: The present invention relates to
# Generating Prompt 140 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 141 ... Prompt: An emitter for an LED-based
# Generating Prompt 142 ... Prompt: Disclosed herein are switching or
# Generating Prompt 143 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 144 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 145 ... Prompt: The disclosed technology generally relates
# Generating Prompt 146 ... Prompt: An application specific integrated circuit
# Generating Prompt 147 ... Prompt: A method of manufacturing a
# Generating Prompt 148 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 149 ... Prompt: A change in electrical characteristics
# Generating Prompt 150 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 151 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 152 ... Prompt: A substrate support assembly for
# Generating Prompt 153 ... Prompt: Systems and methods for growing
# Generating Prompt 154 ... Prompt: An upper surface of a
# Generating Prompt 155 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 156 ... Prompt: A driving control method is
# Generating Prompt 157 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 158 ... Prompt: An organic light emitting diode
# Generating Prompt 159 ... Prompt: An unmanned autonomous vehicle is
# Generating Prompt 160 ... Prompt: Provided are a compound represented
# Generating Prompt 161 ... Prompt: Solar cells having a plurality
# Generating Prompt 162 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 163 ... Prompt: The present disclosure provides an
# Generating Prompt 164 ... Prompt: The present disclosure discloses a
# Generating Prompt 165 ... Prompt: Provided are a display panel,
# Generating Prompt 166 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 167 ... Prompt: Discussed is a method of
# Generating Prompt 168 ... Prompt: A flexible display device includes:
# Generating Prompt 169 ... Prompt: There is provided a barrier
# Generating Prompt 170 ... Prompt: A package for housing an
# Generating Prompt 171 ... Prompt: A method of manufacturing a
# Generating Prompt 172 ... Prompt: The present disclosure discloses a
# Generating Prompt 173 ... Prompt: An imaging element includes: an
# Generating Prompt 174 ... Prompt: A display apparatus includes: a
# Generating Prompt 175 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 176 ... Prompt: An integrated circuit device includes
# Generating Prompt 177 ... Prompt: A light emitting diode package
# Generating Prompt 178 ... Prompt: An application specific integrated circuit
# Generating Prompt 179 ... Prompt: The present disclosure describes additives
# Generating Prompt 180 ... Prompt: An image detector comprises a
# Generating Prompt 181 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 182 ... Prompt: A manufacturing method of an
# Generating Prompt 183 ... Prompt: Embodiments of a method and
# Generating Prompt 184 ... Prompt: A method of fabricating a
# Generating Prompt 185 ... Prompt: According to one embodiment, a
# Generating Prompt 186 ... Prompt: A flexible display substrate includes
# Generating Prompt 187 ... Prompt: Discussed is a method of
# Generating Prompt 188 ... Prompt: An imaging element includes a
# Generating Prompt 189 ... Prompt: The disclosure provides a package
# Generating Prompt 190 ... Prompt: An integrated circuit device includes:
# Generating Prompt 191 ... Prompt: The various embodiments described herein
# Generating Prompt 192 ... Prompt: An organic light emitting diode
# Generating Prompt 193 ... Prompt: A solid-state image pickup device
# Generating Prompt 194 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 195 ... Prompt: Disclosed is an infrared light
# Generating Prompt 196 ... Prompt: A first III-V material based
# Generating Prompt 197 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 198 ... Prompt: An organic light emitting diode
# Generating Prompt 199 ... Prompt: An organic light emitting display
# Generating Prompt 200 ... Prompt: An embodiment includes a memory
# Generating Prompt 201 ... Prompt: To provide a light-emitting element
# Generating Prompt 202 ... Prompt: The present disclosure relates to
# Generating Prompt 203 ... Prompt: An application specific integrated circuit
# Generating Prompt 204 ... Prompt: Provided are a display panel,
# Generating Prompt 205 ... Prompt: A substrate support assembly for
# Generating Prompt 206 ... Prompt: An integrated circuit device includes:
# Generating Prompt 207 ... Prompt: A method of manufacturing a
# Generating Prompt 208 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 209 ... Prompt: An organic EL display device
# Generating Prompt 210 ... Prompt: An image detector comprises a
# Generating Prompt 211 ... Prompt: A display device includes a
# Generating Prompt 212 ... Prompt: An organic light emitting diode
# Generating Prompt 213 ... Prompt: The present specification relates to
# Generating Prompt 214 ... Prompt: Structures and formation methods of
# Generating Prompt 215 ... Prompt: An application specific integrated circuit
# Generating Prompt 216 ... Prompt: A light-emitting element having high
# Generating Prompt 217 ... Prompt: A flexible display substrate includes
# Generating Prompt 218 ... Prompt: A circuit carrier structure includes
# Generating Prompt 219 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 220 ... Prompt: A method is provided for
# Generating Prompt 221 ... Prompt: The present application discloses a
# Generating Prompt 222 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 223 ... Prompt: An object of the present
# Generating Prompt 224 ... Prompt: A heat-pipe membrane module belongs
# Generating Prompt 225 ... Prompt: A light emitting diode package
# Generating Prompt 226 ... Prompt: According to one embodiment, a
# Generating Prompt 227 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 228 ... Prompt: An organic light-emitting diode may
# Generating Prompt 229 ... Prompt: A display apparatus includes: a
# Generating Prompt 230 ... Prompt: A display apparatus includes a
# Generating Prompt 231 ... Prompt: An organic light-emitting device having
# Generating Prompt 232 ... Prompt: An organic light-emitting device including
# Generating Prompt 233 ... Prompt: A microelectronic structure includes a
# Generating Prompt 234 ... Prompt: An organic EL display device
# Generating Prompt 235 ... Prompt: The bluff body attaches to
# Generating Prompt 236 ... Prompt: A device including oxide spacer
# Generating Prompt 237 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 238 ... Prompt: According to one embodiment, a
# Generating Prompt 239 ... Prompt: A semiconductor light emitting device
# Generating Prompt 240 ... Prompt: The embodiments of the present
# Generating Prompt 241 ... Prompt: A display device is described.
# Generating Prompt 242 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 243 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 244 ... Prompt: Various embodiments of the present
# Generating Prompt 245 ... Prompt: According to example embodiments, a
# Generating Prompt 246 ... Prompt: A display device is described.
# Generating Prompt 247 ... Prompt: The present disclosure provides an
# Generating Prompt 248 ... Prompt: The invention relates to an
# Generating Prompt 249 ... Prompt: A display device including a
# Generating Prompt 250 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 251 ... Prompt: A semiconductor device of an
# Generating Prompt 252 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 253 ... Prompt: An enclosure for a radiographic
# Generating Prompt 254 ... Prompt: A circuit substrate and a
# Generating Prompt 255 ... Prompt: Systems and methods for growing
# Generating Prompt 256 ... Prompt: A method for manufacturing a
# Generating Prompt 257 ... Prompt: An organic light emitting display
# Generating Prompt 258 ... Prompt: A three-dimensional memory device including
# Generating Prompt 259 ... Prompt: A substrate carrier stack includes
# Generating Prompt 260 ... Prompt: A display apparatus includes a
# Generating Prompt 261 ... Prompt: A circuit substrate and a
# Generating Prompt 262 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 263 ... Prompt: A method of manufacturing a
# Generating Prompt 264 ... Prompt: An application specific integrated circuit
# Generating Prompt 265 ... Prompt: A group III-N nanowire is
# Generating Prompt 266 ... Prompt: A display unit includes a
# Generating Prompt 267 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 268 ... Prompt: An imaging element includes: an
# Generating Prompt 269 ... Prompt: The present disclosure provides an
# Generating Prompt 270 ... Prompt: Disclosed is an infrared light
# Generating Prompt 271 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 272 ... Prompt: A hermetic capsule including a
# Generating Prompt 273 ... Prompt: The disclosed apparatus may include
# Generating Prompt 274 ... Prompt: Disclosed are a method for
# Generating Prompt 275 ... Prompt: The embodiments of the present
# Generating Prompt 276 ... Prompt: The embodiments of the present
# Generating Prompt 277 ... Prompt: According to one embodiment, a
# Generating Prompt 278 ... Prompt: A microelectronic structure includes a
# Generating Prompt 279 ... Prompt: A light emitting diode (LED)
# Generating Prompt 280 ... Prompt: A display device includes a
# Generating Prompt 281 ... Prompt: According to one embodiment, a
# Generating Prompt 282 ... Prompt: An organic light emitting device
# Generating Prompt 283 ... Prompt: The present specification relates to
# Generating Prompt 284 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 285 ... Prompt: A display device includes: a
# Generating Prompt 286 ... Prompt: A method for manufacturing a
# Generating Prompt 287 ... Prompt: An OLED device and a
# Generating Prompt 288 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 289 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 290 ... Prompt: The invention relates to an
# Generating Prompt 291 ... Prompt: A flexible display panel has
# Generating Prompt 292 ... Prompt: Structures and formation methods of
# Generating Prompt 293 ... Prompt: A microfluidic system includes a
# Generating Prompt 294 ... Prompt: An imaging element includes a
# Generating Prompt 295 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 296 ... Prompt: A TFT substrate includes a
# Generating Prompt 297 ... Prompt: An image sensor pixel may
# Generating Prompt 298 ... Prompt: A light emitting diode (LED)
# Generating Prompt 299 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 300 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 301 ... Prompt: A vehicle skin, such as
# Generating Prompt 302 ... Prompt: A method for depositing a
# Generating Prompt 303 ... Prompt: A method is presented for
# Generating Prompt 304 ... Prompt: Provided is a semiconductor device
# Generating Prompt 305 ... Prompt: The various embodiments described herein
# Generating Prompt 306 ... Prompt: A display apparatus includes a
# Generating Prompt 307 ... Prompt: A semiconductor structure includes an
# Generating Prompt 308 ... Prompt: An anisotropic conductive film includes,
# Generating Prompt 309 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 310 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 311 ... Prompt: According to example embodiments, a
# Generating Prompt 312 ... Prompt: A light-emitting element having high
# Generating Prompt 313 ... Prompt: A semiconductor package includes a
# Generating Prompt 314 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 315 ... Prompt: Photodetectors and methods for dual
# Generating Prompt 316 ... Prompt: A circuit substrate and a
# Generating Prompt 317 ... Prompt: A display apparatus includes: a
# Generating Prompt 318 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 319 ... Prompt: An analog-to-digital converter includes a
# Generating Prompt 320 ... Prompt: A data reading error is
# Generating Prompt 321 ... Prompt: Disclosed is an infrared light
# Generating Prompt 322 ... Prompt: An organic light-emitting diode may
# Generating Prompt 323 ... Prompt: A method of forming a
# Generating Prompt 324 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 325 ... Prompt: A semiconductor device includes a
# Generating Prompt 326 ... Prompt: A method for depositing a
# Generating Prompt 327 ... Prompt: An integrated circuit device includes:
# Generating Prompt 328 ... Prompt: A display unit includes a
# Generating Prompt 329 ... Prompt: A display device includes: a
# Generating Prompt 330 ... Prompt: An embodiment includes a memory
# Generating Prompt 331 ... Prompt: Embodiments of a method and
# Generating Prompt 332 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 333 ... Prompt: In case of forming electrodes
# Generating Prompt 334 ... Prompt: The present invention relates to
# Generating Prompt 335 ... Prompt: A method of manufacturing a
# Generating Prompt 336 ... Prompt: A substrate support assembly for
# Generating Prompt 337 ... Prompt: A photoelectric conversion element and
# Generating Prompt 338 ... Prompt: A random number generator capable
# Generating Prompt 339 ... Prompt: An imaging system may include
# Generating Prompt 340 ... Prompt: According to one embodiment, a
# Generating Prompt 341 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 342 ... Prompt: A semiconductor device includes an
# Generating Prompt 343 ... Prompt: The present application discloses a
# Generating Prompt 344 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 345 ... Prompt: The present disclosure provides a
# Generating Prompt 346 ... Prompt: In a method of manufacturing
# Generating Prompt 347 ... Prompt: An organic light-emitting diode may
# Generating Prompt 348 ... Prompt: An electronic apparatus that is
# Generating Prompt 349 ... Prompt: Embodiments of this invention relate
# Generating Prompt 350 ... Prompt: Disclosed is a pattern forming
# Generating Prompt 351 ... Prompt: A method of manufacturing a
# Generating Prompt 352 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 353 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 354 ... Prompt: A method is presented for
# Generating Prompt 355 ... Prompt: A high output and high
# Generating Prompt 356 ... Prompt: Embodiments of this invention relate
# Generating Prompt 357 ... Prompt: A group III nitride semiconductor
# Generating Prompt 358 ... Prompt: According to example embodiments, a
# Generating Prompt 359 ... Prompt: The disclosure provides a package
# Generating Prompt 360 ... Prompt: A data reading error is
# Generating Prompt 361 ... Prompt: A method of manufacturing a
# Generating Prompt 362 ... Prompt: An embodiment includes a memory
# Generating Prompt 363 ... Prompt: An organic light emitting display
# Generating Prompt 364 ... Prompt: The object of the present
# Generating Prompt 365 ... Prompt: A vehicle skin, such as
# Generating Prompt 366 ... Prompt: Described herein are polishing compositions
# Generating Prompt 367 ... Prompt: A group III-N nanowire is
# Generating Prompt 368 ... Prompt: A method for pre-aligning a
# Generating Prompt 369 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 370 ... Prompt: A method of packaging CSP
# Generating Prompt 371 ... Prompt: A display apparatus includes a
# Generating Prompt 372 ... Prompt: A semiconductor structure includes a
# Generating Prompt 373 ... Prompt: An image sensor may include
# Generating Prompt 374 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 375 ... Prompt: Disclosed are a method for
# Generating Prompt 376 ... Prompt: The present invention relates to
# Generating Prompt 377 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 378 ... Prompt: The embodiments of the present
# Generating Prompt 379 ... Prompt: An integrated circuit device includes
# Generating Prompt 380 ... Prompt: A display apparatus includes a
# Generating Prompt 381 ... Prompt: In one embodiment, a surface
# Generating Prompt 382 ... Prompt: A method of manufacturing a
# Generating Prompt 383 ... Prompt: The present disclosure relates to
# Generating Prompt 384 ... Prompt: Systems and methods that may
# Generating Prompt 385 ... Prompt: A semiconductor device of an
# Generating Prompt 386 ... Prompt: The disclosure provides a package
# Generating Prompt 387 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 388 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 389 ... Prompt: A method of forming a
# Generating Prompt 390 ... Prompt: One aspect of the present
# Generating Prompt 391 ... Prompt: An image sensor may include
# Generating Prompt 392 ... Prompt: An organic light-emitting device having
# Generating Prompt 393 ... Prompt: A light emitting diode is
# Generating Prompt 394 ... Prompt: Provided are a compound represented
# Generating Prompt 395 ... Prompt: An assembly used in a
# Generating Prompt 396 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 397 ... Prompt: A display device includes a
# Generating Prompt 398 ... Prompt: A substrate carrier stack includes
# Generating Prompt 399 ... Prompt: CMOS circuits may formed using
# Generating Prompt 400 ... Prompt: One aspect of the present
# Generating Prompt 401 ... Prompt: An imaging system may include
# Generating Prompt 402 ... Prompt: An organic light emitting diode
# Generating Prompt 403 ... Prompt: An embodiment includes a memory
# Generating Prompt 404 ... Prompt: A method of manufacturing a
# Generating Prompt 405 ... Prompt: The present disclosure provides a
# Generating Prompt 406 ... Prompt: An organic light emitting diode
# Generating Prompt 407 ... Prompt: To provide a light-emitting element
# Generating Prompt 408 ... Prompt: The present invention relates to
# Generating Prompt 409 ... Prompt: An organic light emitting display
# Generating Prompt 410 ... Prompt: An imaging element includes: an
# Generating Prompt 411 ... Prompt: An object of the invention
# Generating Prompt 412 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 413 ... Prompt: Disclosed herein are switching or
# Generating Prompt 414 ... Prompt: The present invention discloses a
# Generating Prompt 415 ... Prompt: An imaging element includes: an
# Generating Prompt 416 ... Prompt: An organic EL display device
# Generating Prompt 417 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 418 ... Prompt: Verifying a semiconductor product is
# Generating Prompt 419 ... Prompt: An organic light emitting diode
# Generating Prompt 420 ... Prompt: Methods, systems, and apparatus for
# Generating Prompt 421 ... Prompt: Disclosed herein are switching or
# Generating Prompt 422 ... Prompt: A device includes a substrate
# Generating Prompt 423 ... Prompt: A display device includes a
# Generating Prompt 424 ... Prompt: A circuit substrate and a
# Generating Prompt 425 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 426 ... Prompt: An object of the present
# Generating Prompt 427 ... Prompt: We describe a method for
# Generating Prompt 428 ... Prompt: A display apparatus includes a
# Generating Prompt 429 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 430 ... Prompt: An application specific integrated circuit
# Generating Prompt 431 ... Prompt: A method of manufacturing a
# Generating Prompt 432 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 433 ... Prompt: Disclosed examples provide processes for
# Generating Prompt 434 ... Prompt: A photoelectric conversion device includes
# Generating Prompt 435 ... Prompt: An upper surface of a
# Generating Prompt 436 ... Prompt: A light emitting diode package
# Generating Prompt 437 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 438 ... Prompt: The embodiments of the present
# Generating Prompt 439 ... Prompt: The present invention relates to
# Generating Prompt 440 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 441 ... Prompt: Methods and devices for forming
# Generating Prompt 442 ... Prompt: We describe a method for
# Generating Prompt 443 ... Prompt: The embodiments of the present
# Generating Prompt 444 ... Prompt: A method of manufacturing a
# Generating Prompt 445 ... Prompt: A display panel and a
# Generating Prompt 446 ... Prompt: A light emitting diode (LED)
# Generating Prompt 447 ... Prompt: A light emitting diode package
# Generating Prompt 448 ... Prompt: A transistor device comprising an
# Generating Prompt 449 ... Prompt: Some embodiments include an integrated
# Generating Prompt 450 ... Prompt: A pressure sensor includes a
# Generating Prompt 451 ... Prompt: A semiconductor memory device includes
# Generating Prompt 452 ... Prompt: Docking platforms formed in one
# Generating Prompt 453 ... Prompt: A phase-change memory element is
# Generating Prompt 454 ... Prompt: A control device includes a
# Generating Prompt 455 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 456 ... Prompt: One aspect of the present
# Generating Prompt 457 ... Prompt: A random number generator capable
# Generating Prompt 458 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 459 ... Prompt: A light-emitting element having high
# Generating Prompt 460 ... Prompt: The present disclosure relates to
# Generating Prompt 461 ... Prompt: A semiconductor memory device includes
# Generating Prompt 462 ... Prompt: The present disclosure relates to
# Generating Prompt 463 ... Prompt: One aspect of the present
# Generating Prompt 464 ... Prompt: An organic light emitting diode
# Generating Prompt 465 ... Prompt: A hermetic capsule including a
# Generating Prompt 466 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 467 ... Prompt: An embodiment includes a memory
# Generating Prompt 468 ... Prompt: A wafer level package that
# Generating Prompt 469 ... Prompt: A method is provided for
# Generating Prompt 470 ... Prompt: An organic light-emitting display apparatus
# Generating Prompt 471 ... Prompt: An organic light emitting diode
# Generating Prompt 472 ... Prompt: An object of the invention
# Generating Prompt 473 ... Prompt: An enclosure for a radiographic
# Generating Prompt 474 ... Prompt: Systems and methods for detecting
# Generating Prompt 475 ... Prompt: A semiconductor structure is provided
# Generating Prompt 476 ... Prompt: The present specification relates to
# Generating Prompt 477 ... Prompt: The present disclosure provides an
# Generating Prompt 478 ... Prompt: A method for transporting a
# Generating Prompt 479 ... Prompt: The present invention relates to
# Generating Prompt 480 ... Prompt: An assembly used in a
# Generating Prompt 481 ... Prompt: Systems and methods for detecting
# Generating Prompt 482 ... Prompt: An image processing apparatus includes
# Generating Prompt 483 ... Prompt: A method of manufacturing a
# Generating Prompt 484 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 485 ... Prompt: A semiconductor device according to
# Generating Prompt 486 ... Prompt: The present disclosure relates to
# Generating Prompt 487 ... Prompt: According to one embodiment, a
# Generating Prompt 488 ... Prompt: A method of manufacturing a
# Generating Prompt 489 ... Prompt: An organic light-emitting device having
# Generating Prompt 490 ... Prompt: The present disclosure relates to
# Generating Prompt 491 ... Prompt: A wafer level package that
# Generating Prompt 492 ... Prompt: The present disclosure provides a
# Generating Prompt 493 ... Prompt: The present invention(s) is directed
# Generating Prompt 494 ... Prompt: A driving control method is
# Generating Prompt 495 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 496 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 497 ... Prompt: A method of manufacturing a
# Generating Prompt 498 ... Prompt: An organic light emitting device
# Generating Prompt 499 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 500 ... Prompt: A method is provided for
# Generating Prompt 501 ... Prompt: A light emitting device and
# Generating Prompt 502 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 503 ... Prompt: A method of forming a
# Generating Prompt 504 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 505 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 506 ... Prompt: According to one embodiment, a
# Generating Prompt 507 ... Prompt: A wavelength conversion element comprising
# Generating Prompt 508 ... Prompt: A flexible display device includes:
# Generating Prompt 509 ... Prompt: A structure containing a vertical
# Generating Prompt 510 ... Prompt: An electronic apparatus includes a
# Generating Prompt 511 ... Prompt: Embodiments are directed to a
# Generating Prompt 512 ... Prompt: A device includes a substrate
# Generating Prompt 513 ... Prompt: A flexible display panel has
# Generating Prompt 514 ... Prompt: Low temperature epitaxial silicon deposition
# Generating Prompt 515 ... Prompt: A wafer level package that
# Generating Prompt 516 ... Prompt: According to example embodiments, a
# Generating Prompt 517 ... Prompt: Discussed is a method of
# Generating Prompt 518 ... Prompt: A light emitting diode (LED)
# Generating Prompt 519 ... Prompt: The various embodiments described herein
# Generating Prompt 520 ... Prompt: An emitter for an LED-based
# Generating Prompt 521 ... Prompt: According to one embodiment, a
# Generating Prompt 522 ... Prompt: Vacuum annealing-based techniques for forming
# Generating Prompt 523 ... Prompt: An organic light-emitting diode may
# Generating Prompt 524 ... Prompt: According to example embodiments, a
# Generating Prompt 525 ... Prompt: An OLED device and a
# Generating Prompt 526 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 527 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 528 ... Prompt: A display panel comprises a
# Generating Prompt 529 ... Prompt: A system for surface patterning
# Generating Prompt 530 ... Prompt: A semiconductor device includes a
# Generating Prompt 531 ... Prompt: A display device includes first
# Generating Prompt 532 ... Prompt: A composition comprising a first
# Generating Prompt 533 ... Prompt: A semiconductor device of an
# Generating Prompt 534 ... Prompt: The present disclosure relates to
# Generating Prompt 535 ... Prompt: A circuit substrate and a
# Generating Prompt 536 ... Prompt: The present invention relates to
# Generating Prompt 537 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 538 ... Prompt: The present invention relates to
# Generating Prompt 539 ... Prompt: The present invention discloses a
# Generating Prompt 540 ... Prompt: According to an embodiment of
# Generating Prompt 541 ... Prompt: Various embodiments of the present
# Generating Prompt 542 ... Prompt: A semiconductor device includes a
# Generating Prompt 543 ... Prompt: The SCR-based ESD device has
# Generating Prompt 544 ... Prompt: The present invention(s) is directed
# Generating Prompt 545 ... Prompt: An image sensor may include
# Generating Prompt 546 ... Prompt: A flexible substrate including a
# Generating Prompt 547 ... Prompt: An organic EL display device
# Generating Prompt 548 ... Prompt: Systems and methods for growing
# Generating Prompt 549 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 550 ... Prompt: An organic EL display device
# Generating Prompt 551 ... Prompt: A method is provided for
# Generating Prompt 552 ... Prompt: Provided is a portable, thermoelectrically
# Generating Prompt 553 ... Prompt: CMOS circuits may formed using
# Generating Prompt 554 ... Prompt: The disclosed technology generally relates
# Generating Prompt 555 ... Prompt: According to an embodiment of
# Generating Prompt 556 ... Prompt: An example integrated circuit (IC)
# Generating Prompt 557 ... Prompt: A deposition system and method
# Generating Prompt 558 ... Prompt: An organic electroluminescence device including:
# Generating Prompt 559 ... Prompt: According to one embodiment, a
# Generating Prompt 560 ... Prompt: Docking platforms formed in one
# Generating Prompt 561 ... Prompt: A semiconductor structure includes a
# Generating Prompt 562 ... Prompt: Provided are a compound of
# Generating Prompt 563 ... Prompt: An organic light emitting display
# Generating Prompt 564 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 565 ... Prompt: An image sensor pixel may
# Generating Prompt 566 ... Prompt: It is an object of
# Generating Prompt 567 ... Prompt: A package structure includes a
# Generating Prompt 568 ... Prompt: A photoelectric conversion element and
# Generating Prompt 569 ... Prompt: The various embodiments described herein
# Generating Prompt 570 ... Prompt: According to one example, a
# Generating Prompt 571 ... Prompt: A display device includes a
# Generating Prompt 572 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 573 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 574 ... Prompt: The present disclosure provides an
# Generating Prompt 575 ... Prompt: Various embodiments of the present
# Generating Prompt 576 ... Prompt: An OLED device and a
# Generating Prompt 577 ... Prompt: An organic metal complex as
# Generating Prompt 578 ... Prompt: The present disclosure relates to
# Generating Prompt 579 ... Prompt: Provided are a display panel,
# Generating Prompt 580 ... Prompt: An image sensor may include
# Generating Prompt 581 ... Prompt: A light emitting diode package
# Generating Prompt 582 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 583 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 584 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 585 ... Prompt: A vehicle skin, such as
# Generating Prompt 586 ... Prompt: Discussed is a method of
# Generating Prompt 587 ... Prompt: Systems and methods that may
# Generating Prompt 588 ... Prompt: A composition comprising a first
# Generating Prompt 589 ... Prompt: A display device includes first
# Generating Prompt 590 ... Prompt: A light emitting diode package
# Generating Prompt 591 ... Prompt: An organic light emitting diode
# Generating Prompt 592 ... Prompt: A flexible display substrate includes
# Generating Prompt 593 ... Prompt: An apparatus comprising: a module;
# Generating Prompt 594 ... Prompt: A method is presented for
# Generating Prompt 595 ... Prompt: A method for manufacturing a
# Generating Prompt 596 ... Prompt: An imaging element includes: an
# Generating Prompt 597 ... Prompt: To provide a coating fluid
# Generating Prompt 598 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 599 ... Prompt: An object of the present
# Generating Prompt 600 ... Prompt: A display apparatus includes: a
# Generating Prompt 601 ... Prompt: A flexible display substrate includes
# Generating Prompt 602 ... Prompt: Systems and methods for growing
# Generating Prompt 603 ... Prompt: A display device, which includes
# Generating Prompt 604 ... Prompt: A pixel array in an
# Generating Prompt 605 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 606 ... Prompt: A heat sink assembly for
# Generating Prompt 607 ... Prompt: An organic light emitting diode
# Generating Prompt 608 ... Prompt: An electronic apparatus includes a
# Generating Prompt 609 ... Prompt: A flexible display panel has
# Generating Prompt 610 ... Prompt: To provide a light-emitting element
# Generating Prompt 611 ... Prompt: A heat sink assembly for
# Generating Prompt 612 ... Prompt: The present disclosure relates to
# Generating Prompt 613 ... Prompt: A display device including a
# Generating Prompt 614 ... Prompt: A method of fabricating a
# Generating Prompt 615 ... Prompt: Docking platforms formed in one
# Generating Prompt 616 ... Prompt: A semiconductor memory device includes
# Generating Prompt 617 ... Prompt: Disclosed herein is an organic
# Generating Prompt 618 ... Prompt: An application specific integrated circuit
# Generating Prompt 619 ... Prompt: A phase-change memory element is
# Generating Prompt 620 ... Prompt: An organic light emitting diode
# Generating Prompt 621 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 622 ... Prompt: The present disclosure relates to
# Generating Prompt 623 ... Prompt: A reheating collection device for
# Generating Prompt 624 ... Prompt: A method for pre-aligning a
# Generating Prompt 625 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 626 ... Prompt: The various embodiments described herein
# Generating Prompt 627 ... Prompt: A microfluidic system includes a
# Generating Prompt 628 ... Prompt: The disclosed technology generally relates
# Generating Prompt 629 ... Prompt: The present invention discloses a
# Generating Prompt 630 ... Prompt: An image sensor includes a
# Generating Prompt 631 ... Prompt: A novel and useful controlled
# Generating Prompt 632 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 633 ... Prompt: To provide a light-emitting element
# Generating Prompt 634 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 635 ... Prompt: A semiconductor device includes a
# Generating Prompt 636 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 637 ... Prompt: The present application discloses a
# Generating Prompt 638 ... Prompt: The present disclosure provides a
# Generating Prompt 639 ... Prompt: An organic metal complex as
# Generating Prompt 640 ... Prompt: An integrated circuit device includes:
# Generating Prompt 641 ... Prompt: A method of fabricating a
# Generating Prompt 642 ... Prompt: A light emitting diode (LED)
# Generating Prompt 643 ... Prompt: One aspect of the present
# Generating Prompt 644 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 645 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 646 ... Prompt: An object of the present
# Generating Prompt 647 ... Prompt: An embodiment includes a memory
# Generating Prompt 648 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 649 ... Prompt: According to one embodiment, a
# Generating Prompt 650 ... Prompt: Embodiments of this invention relate
# Generating Prompt 651 ... Prompt: A system for surface patterning
# Generating Prompt 652 ... Prompt: Disclosed is a light emitting
# Generating Prompt 653 ... Prompt: An application specific integrated circuit
# Generating Prompt 654 ... Prompt: A control device includes a
# Generating Prompt 655 ... Prompt: An image sensor pixel may
# Generating Prompt 656 ... Prompt: A bipolar complementary metal oxide
# Generating Prompt 657 ... Prompt: An object of the present
# Generating Prompt 658 ... Prompt: An anisotropic conductive film includes,
# Generating Prompt 659 ... Prompt: An analog-to-digital converter is provided.
# Generating Prompt 660 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 661 ... Prompt: An organic light emitting diode
# Generating Prompt 662 ... Prompt: An application specific integrated circuit
# Generating Prompt 663 ... Prompt: A semiconductor device and a
# Generating Prompt 664 ... Prompt: A method of fabricating a
# Generating Prompt 665 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 666 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 667 ... Prompt: A light-emitting element having high
# Generating Prompt 668 ... Prompt: A display apparatus includes a
# Generating Prompt 669 ... Prompt: Provided are a display panel,
# Generating Prompt 670 ... Prompt: An organic light-emitting display including
# Generating Prompt 671 ... Prompt: Disclosed is an infrared light
# Generating Prompt 672 ... Prompt: Disclosed are a method for
# Generating Prompt 673 ... Prompt: A light emitting diode package
# Generating Prompt 674 ... Prompt: A light emitting diode is
# Generating Prompt 675 ... Prompt: The present disclosure provides a
# Generating Prompt 676 ... Prompt: Systems and methods for growing
# Generating Prompt 677 ... Prompt: An integrated circuit device includes
# Generating Prompt 678 ... Prompt: One aspect of the present
# Generating Prompt 679 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 680 ... Prompt: One aspect of the present
# Generating Prompt 681 ... Prompt: An arc detector includes a
# Generating Prompt 682 ... Prompt: A method of manufacturing a
# Generating Prompt 683 ... Prompt: An organic light-emitting display including
# Generating Prompt 684 ... Prompt: Envelope-tracking control techniques are disclosed
# Generating Prompt 685 ... Prompt: A data reading error is
# Generating Prompt 686 ... Prompt: A deposition system and method
# Generating Prompt 687 ... Prompt: The present invention relates to
# Generating Prompt 688 ... Prompt: An organic light emitting diode
# Generating Prompt 689 ... Prompt: The present invention relates to
# Generating Prompt 690 ... Prompt: The present invention(s) is directed
# Generating Prompt 691 ... Prompt: A piezoelectric linear actuator comprising
# Generating Prompt 692 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 693 ... Prompt: A driving control method is
# Generating Prompt 694 ... Prompt: Provided is a light-emitting device
# Generating Prompt 695 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 696 ... Prompt: An electronic apparatus includes a
# Generating Prompt 697 ... Prompt: A semiconductor package assembly includes
# Generating Prompt 698 ... Prompt: Provided are a display apparatus,
# Generating Prompt 699 ... Prompt: According to one embodiment, a
# Generating Prompt 700 ... Prompt: A stacked complementary metal oxide
# Generating Prompt 701 ... Prompt: A data reading error is
# Generating Prompt 702 ... Prompt: An organic light emitting diode
# Generating Prompt 703 ... Prompt: Discussed is a method of
# Generating Prompt 704 ... Prompt: A support structure for a
# Generating Prompt 705 ... Prompt: A group III-N nanowire is
# Generating Prompt 706 ... Prompt: A light-emitting element having high
# Generating Prompt 707 ... Prompt: The invention relates to an
# Generating Prompt 708 ... Prompt: A substrate treating apparatus includes
# Generating Prompt 709 ... Prompt: Structures and formation methods of
# Generating Prompt 710 ... Prompt: A display device includes first
# Generating Prompt 711 ... Prompt: A Doherty amplifier includes a
# Generating Prompt 712 ... Prompt: Provided are a display panel,
# Generating Prompt 713 ... Prompt: Systems and methods for detecting
# Generating Prompt 714 ... Prompt: An optoelectronic arrangement having a
# Generating Prompt 715 ... Prompt: The present invention relates to
# ...
# Generating Prompt 3315 ... Prompt: The invention relates to an
# Generating Prompt 3316 ... Prompt: Discussed is a method of
# Generating Prompt 3317 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 3318 ... Prompt: In one embodiment, a solar
# Generating Prompt 3319 ... Prompt: Provided are a display panel,
# Generating Prompt 3320 ... Prompt: A semiconductor device is provided.
# Generating Prompt 3321 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 3322 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 3323 ... Prompt: An imaging system using ultraviolet
# Generating Prompt 3324 ... Prompt: An image sensor may include
# Generating Prompt 3325 ... Prompt: An organic light emitting device
# Generating Prompt 3326 ... Prompt: The present disclosure provides a
# Generating Prompt 3327 ... Prompt: An object of the present
# Generating Prompt 3328 ... Prompt: A semiconductor device and a
# Generating Prompt 3329 ... Prompt: Provided are a compound of
# Generating Prompt 3330 ... Prompt: An organic electroluminescent device, a
# Generating Prompt 3331 ... Prompt: A semiconductor device includes a
# Generating Prompt 3332 ... Prompt: A vibration-type actuator is downsized
# Generating Prompt 3333 ... Prompt: An emitter for an LED-based
# Generating Prompt 3334 ... Prompt: The various embodiments described herein
# Generating Prompt 3335 ... Prompt: A light-emitting element having high
# Generating Prompt 3336 ... Prompt: Provided are a compound represented
# Generating Prompt 3337 ... Prompt: A group III-N nanowire is
# Generating Prompt 3338 ... Prompt: A semiconductor device has a
# Generating Prompt 3339 ... Prompt: The present disclosure relates to
# Generating Prompt 3340 ... Prompt: The present invention relates to
# Generating Prompt 3341 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3342 ... Prompt: A backplate of a display
# Generating Prompt 3343 ... Prompt: Solar cells having a plurality
# Generating Prompt 3344 ... Prompt: A display device is described.
# Generating Prompt 3345 ... Prompt: The present specification relates to
# Generating Prompt 3346 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 3347 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 3348 ... Prompt: A digitally controlled oscillator (DCO)
# Generating Prompt 3349 ... Prompt: The disclosure provides a package
# Generating Prompt 3350 ... Prompt: According to example embodiments, a
# Generating Prompt 3351 ... Prompt: A substrate support assembly for
# Generating Prompt 3352 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 3353 ... Prompt: A device includes a substrate
# Generating Prompt 3354 ... Prompt: An organic light emitting display
# Generating Prompt 3355 ... Prompt: A method of fabricating a
# Generating Prompt 3356 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 3357 ... Prompt: According to one embodiment, a
# Generating Prompt 3358 ... Prompt: An imaging element includes a
# Generating Prompt 3359 ... Prompt: A display apparatus includes a
# Generating Prompt 3360 ... Prompt: The present disclosure provides an
# Generating Prompt 3361 ... Prompt: The disclosure provides a package
# Generating Prompt 3362 ... Prompt: A method for manufacturing a
# Generating Prompt 3363 ... Prompt: A method for manufacturing a
# Generating Prompt 3364 ... Prompt: A MEMS IR sensor, with
# Generating Prompt 3365 ... Prompt: A display device includes a
# Generating Prompt 3366 ... Prompt: A display apparatus includes a
# Generating Prompt 3367 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3368 ... Prompt: A flexible substrate including a
# Generating Prompt 3369 ... Prompt: The various embodiments described herein
# Generating Prompt 3370 ... Prompt: A manufacturing method of an
# Generating Prompt 3371 ... Prompt: There is provided a barrier
# Generating Prompt 3372 ... Prompt: An organic light-emitting display including
# Generating Prompt 3373 ... Prompt: A group III-N nanowire is
# Generating Prompt 3374 ... Prompt: A heat sink assembly for
# Generating Prompt 3375 ... Prompt: A memory device includes first
# Generating Prompt 3376 ... Prompt: In one embodiment, a surface
# Generating Prompt 3377 ... Prompt: A method of manufacturing a
# Generating Prompt 3378 ... Prompt: Methods/structures of joining package structures
# Generating Prompt 3379 ... Prompt: A heat sink assembly for
# Generating Prompt 3380 ... Prompt: The present invention relates to
# Generating Prompt 3381 ... Prompt: A phase-change memory element is
# Generating Prompt 3382 ... Prompt: The present disclosure relates to
# Generating Prompt 3383 ... Prompt: A flexible display panel has
# Generating Prompt 3384 ... Prompt: To provide a coating fluid
# Generating Prompt 3385 ... Prompt: A random number generator capable
# Generating Prompt 3386 ... Prompt: The present invention relates to
# Generating Prompt 3387 ... Prompt: A substrate processing apparatus includes
# Generating Prompt 3388 ... Prompt: An organic light emitting diode
# Generating Prompt 3389 ... Prompt: An imaging system may include
# Generating Prompt 3390 ... Prompt: To reduce influence occurring between
# Generating Prompt 3391 ... Prompt: A semiconductor package includes a
# Generating Prompt 3392 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 3393 ... Prompt: A microelectronic structure includes a
# Generating Prompt 3394 ... Prompt: A thermally conductive article including
# Generating Prompt 3395 ... Prompt: An organic light emitting diode
# Generating Prompt 3396 ... Prompt: A display apparatus includes a
# Generating Prompt 3397 ... Prompt: A microelectronic structure includes a
# Generating Prompt 3398 ... Prompt: An image sensor pixel may
# Generating Prompt 3399 ... Prompt: A flexible display panel, a
# Generating Prompt 3400 ... Prompt: A method of manufacturing a
# Generating Prompt 3401 ... Prompt: A microfluidic system includes a
# Generating Prompt 3402 ... Prompt: A TFT substrate includes a
# Generating Prompt 3403 ... Prompt: A light-emitting element that includes
# Generating Prompt 3404 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 3405 ... Prompt: The bluff body attaches to
# Generating Prompt 3406 ... Prompt: A manufacturing method of an
# Generating Prompt 3407 ... Prompt: The disclosed technology generally relates
# Generating Prompt 3408 ... Prompt: A memory device includes first
# Generating Prompt 3409 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 3410 ... Prompt: A semiconductor device includes a
# Generating Prompt 3411 ... Prompt: Various embodiments of the present
# Generating Prompt 3412 ... Prompt: Multiple tier structures are stacked
# Generating Prompt 3413 ... Prompt: The present invention(s) is directed
# Generating Prompt 3414 ... Prompt: An assembly used in a
# Generating Prompt 3415 ... Prompt: A display unit includes a
# Generating Prompt 3416 ... Prompt: The present invention relates to
# Generating Prompt 3417 ... Prompt: The disclosure provides a package
# Generating Prompt 3418 ... Prompt: An organic light emitting diode
# Generating Prompt 3419 ... Prompt: A light-emitting element that includes
# Generating Prompt 3420 ... Prompt: A solar cell includes a
# Generating Prompt 3421 ... Prompt: A display apparatus includes a
# Generating Prompt 3422 ... Prompt: According to one embodiment, a
# Generating Prompt 3423 ... Prompt: Variable-resistance material memories include a
# Generating Prompt 3424 ... Prompt: A solid-state image pickup device
# Generating Prompt 3425 ... Prompt: A back-illuminated energy ray detecting
# Generating Prompt 3426 ... Prompt: The present disclosure provides a
# Generating Prompt 3427 ... Prompt: A flexible display panel, a
# Generating Prompt 3428 ... Prompt: Aspects disclosed herein include circuits
# Generating Prompt 3429 ... Prompt: An object of the present
# Generating Prompt 3430 ... Prompt: The invention relates to an
# Generating Prompt 3431 ... Prompt: An application specific integrated circuit
# Generating Prompt 3432 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 3433 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 3434 ... Prompt: A package for housing an
# Generating Prompt 3435 ... Prompt: The present specification relates to
# Generating Prompt 3436 ... Prompt: An organic light-emitting diode may
# Generating Prompt 3437 ... Prompt: A display device includes a
# Generating Prompt 3438 ... Prompt: A hermetic capsule including a
# Generating Prompt 3439 ... Prompt: An organic metal complex as
# Generating Prompt 3440 ... Prompt: A photoelectric conversion element and
# Generating Prompt 3441 ... Prompt: The disclosure provides a package
# Generating Prompt 3442 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 3443 ... Prompt: A light-emitting element having high
# Generating Prompt 3444 ... Prompt: A novel and useful controlled
# Generating Prompt 3445 ... Prompt: An encapsulation structure, a manufacturing
# Generating Prompt 3446 ... Prompt: A method of manufacturing a
# Generating Prompt 3447 ... Prompt: A data reading error is
# Generating Prompt 3448 ... Prompt: In accordance with an embodiment,
# Generating Prompt 3449 ... Prompt: A random number generator capable
# Generating Prompt 3450 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 3451 ... Prompt: A method for manufacturing a
# Generating Prompt 3452 ... Prompt: A method of forming a
# Generating Prompt 3453 ... Prompt: Structures and formation methods of
# Generating Prompt 3454 ... Prompt: A method is presented for
# Generating Prompt 3455 ... Prompt: A manufacturing method of an
# Generating Prompt 3456 ... Prompt: A stacked-die oscillator package includes
# Generating Prompt 3457 ... Prompt: A HDR CTIA pixel which
# Generating Prompt 3458 ... Prompt: To provide a light-emitting element
# Generating Prompt 3459 ... Prompt: A display panel comprises a
# Generating Prompt 3460 ... Prompt: A dual-gate, self-aligned lateral double-diffused
# Generating Prompt 3461 ... Prompt: An application specific integrated circuit
# Generating Prompt 3462 ... Prompt: A flexible substrate including a
# Generating Prompt 3463 ... Prompt: A semiconductor structure is provided
# Generating Prompt 3464 ... Prompt: The present disclosure relates to
# Generating Prompt 3465 ... Prompt: Discussed is a method of
# Generating Prompt 3466 ... Prompt: Disclosed is an infrared light
# Generating Prompt 3467 ... Prompt: A novel and useful controlled
# Generating Prompt 3468 ... Prompt: To provide a light-emitting element
# Generating Prompt 3469 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 3470 ... Prompt: A light-emitting element that includes
# Generating Prompt 3471 ... Prompt: A method for fabricating semiconductor
# Generating Prompt 3472 ... Prompt: Various embodiments of the present
# Generating Prompt 3473 ... Prompt: A method of forming a
# Generating Prompt 3474 ... Prompt: A method for transporting a
# Generating Prompt 3475 ... Prompt: Semiconductor devices and methods of
# Generating Prompt 3476 ... Prompt: The present invention(s) is directed
# Generating Prompt 3477 ... Prompt: Disclosed is an image sensor.
# Generating Prompt 3478 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 3479 ... Prompt: A method of manufacturing a
# Generating Prompt 3480 ... Prompt: An electronic component mounting board
# Generating Prompt 3481 ... Prompt: An organic light emitting diode
# Generating Prompt 3482 ... Prompt: A semiconductor device includes a
# Generating Prompt 3483 ... Prompt: Disclosed is an infrared light
# Generating Prompt 3484 ... Prompt: A dynamic vision sensor (DVS)
# Generating Prompt 3485 ... Prompt: An ultraviolet light-emitting device including
# Generating Prompt 3486 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 3487 ... Prompt: A solid-state image pickup device
# Generating Prompt 3488 ... Prompt: Embodiments of the present disclosure
# Generating Prompt 3489 ... Prompt: An imaging element includes: an
# Generating Prompt 3490 ... Prompt: The present disclosure discloses a
# Generating Prompt 3491 ... Prompt: A phase-change memory element is
# Generating Prompt 3492 ... Prompt: Capacitor arrays and methods of
# Generating Prompt 3493 ... Prompt: A random number generator capable
# Generating Prompt 3494 ... Prompt: An organic EL display device
# Generating Prompt 3495 ... Prompt: The present disclosure describes additives
# Generating Prompt 3496 ... Prompt: An organic light-emitting display including
# Generating Prompt 3497 ... Prompt: An electronic apparatus includes a
# Generating Prompt 3498 ... Prompt: One aspect of the present
# Generating Prompt 3499 ... Prompt: A display device is described.
# Generating Prompt 3500 ... Prompt: A device includes a substrate
# Generating Prompt 3501 ... Prompt: The present specification relates to
# Generating Prompt 3502 ... Prompt: Disclosed herein are switching or
# Generating Prompt 3503 ... Prompt: To provide a coating fluid
# Generating Prompt 3504 ... Prompt: A semiconductor package includes a
# Generating Prompt 3505 ... Prompt: An embodiment includes a memory
# Generating Prompt 3506 ... Prompt: The present application relates to
# Generating Prompt 3507 ... Prompt: According to one embodiment, a
# Generating Prompt 3508 ... Prompt: Electronic devices are disclosed including
# Generating Prompt 3509 ... Prompt: A stacked semiconductor device assembly
# Generating Prompt 3510 ... Prompt: According to an embodiment of
# Generating Prompt 3511 ... Prompt: A method for fabricating caterpillar
# Generating Prompt 3512 ... Prompt: To provide a light-emitting element
# Generating Prompt 3513 ... Prompt: A microfluidic system includes a
# Generating Prompt 3514 ... Prompt: According to one embodiment, a
# Generating Prompt 3515 ... Prompt: Methods/structures of joining package structures
# Generating Prompt 3516 ... Prompt: An organic light emitting diode
# Generating Prompt 3517 ... Prompt: Methods of forming germanium channel
# Generating Prompt 3518 ... Prompt: An image sensor includes a
# Generating Prompt 3519 ... Prompt: A light-emitting element that includes
# Generating Prompt 3520 ... Prompt: A microelectronic structure includes a
# Generating Prompt 3521 ... Prompt: A method is provided for
# Generating Prompt 3522 ... Prompt: The present disclosure describes additives
# Generating Prompt 3523 ... Prompt: Techniques regarding protecting a dielectric
# Generating Prompt 3524 ... Prompt: A method of fabricating a
# Generating Prompt 3525 ... Prompt: An electronic apparatus that is
# Generating Prompt 3526 ... Prompt: An image sensor includes a
# Generating Prompt 3527 ... Prompt: Disclosed is a light emitting
# Generating Prompt 3528 ... Prompt: A phase-change memory element is
# Generating Prompt 3529 ... Prompt: An object of the invention
# Generating Prompt 3530 ... Prompt: An organic light-emitting device includes:
# Generating Prompt 3531 ... Prompt: Provided is an electric element
# Generating Prompt 3532 ... Prompt: One aspect of the present
# Generating Prompt 3533 ... Prompt: There is provided a barrier
# Generating Prompt 3534 ... Prompt: A magnetoresistance effect element has
# Generating Prompt 3535 ... Prompt: Provided are a display panel,
# Generating Prompt 3536 ... Prompt: Stacked semiconductor die assemblies with
# Generating Prompt 3537 ... Prompt: A semiconductor device has a
# Generating Prompt 3538 ... Prompt: A phase-change memory element is
# Generating Prompt 3539 ... Prompt: A change in electrical characteristics
# Generating Prompt 3540 ... Prompt: The invention relates to an
# Generating Prompt 3541 ... Prompt: A semiconductor device includes a
# Generating Prompt 3542 ... Prompt: Protective dielectrics are discussed generally
# Generating Prompt 3543 ... Prompt: A semiconductor device includes a
# Generating Prompt 3544 ... Prompt: An organic light emitting device
# Generating Prompt 3545 ... Prompt: The present invention relates to
# Generating Prompt 3546 ... Prompt: Quantum dot polymer composites for
# Generating Prompt 3547 ... Prompt: An electronic device and manufacturing

# %%
fake_data = pd.read_csv("./Models/Experiments/Abstracts/10epochs/fake_patent_abstracts.csv")
fake_data = fake_data.loc[:, ~fake_data.columns.str.contains('^Unnamed')]
fake_data
# Out:
#                                                Abstract  Label
# 0     An organic light-emitting display including a ...      1
# 1     A method for transporting a cassette pod for c...      1
# 2     A semiconductor device includes a first word l...      1
# 3     Systems and methods that may be implemented to...      1
# 4     A structure containing a vertical light emitti...      1
# ...                                                 ...    ...
# 8942  A semiconductor device includes a first word l...      1
# 8943  An organic light emitting device including: a ...      1
# 8944  The present invention relates to compounds of ...      1
# 8945  Quantum dot polymer composites for on-chip lig...      1
# 8946  An electronic device and manufacturing method ...      1
#
# [8947 rows x 2 columns]

# %%
len(fake_data)
# Out:
# 8947

# %%
fake_prompts = pd.read_csv("./Models/Experiments/Abstracts/10epochs/prompts.csv")

# %%
fake_data['Abstract'][0]
# Out:
# 'An organic light-emitting display including a substrate, an insulating      layer on the substrate, the substrate and the insulating layer having an      opening therethrough penetrating, a pixel array on the insulating layer,      the pixel array including a plurality of pixels that surround the      opening, a first pixel adjacent to the opening from among the plurality      of pixels includes a pixel electrode layer, an intermediate layer on the      pixel electrode layer, and an opposite electrode layer on the      intermediate layer, and a stepped portion on the substrate and adjacent      to the opening, the stepped portion having an under-cut step, wherein the      intermediate layer including an organic emission layer, and wherein at      least one of the intermediate layer and the opposite electrode layer      extends toward the opening and is disconnected by the stepped portion. <EOS>\n<BOS> An organic light emitting diode and an organic light emitting display      panel, the organic light emitting diode including an anode disposed on a      base layer; a first'

# %%
fake_prompts['Prompts'][0]
# Out:
# 'An organic light-emitting display including'

# %%
frames = [real_data, fake_data]
full_data = pd.concat(frames)


full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data
# Out:
#                                                 Abstract  Label
# 0      An integrated circuit device includes: a first...      1
# 1      A hermetic capsule including a semiconductor/m...      0
# 2      An organic EL display device 1 includes a flex...      1
# 3      The present disclosure provides a package stru...      1
# 4      A digitally controlled oscillator (DCO) may in...      0
# ...                                                  ...    ...
# 17889  An organic electroluminescent device, a method...      1
# 17890  The object of the present invention is to make...      0
# 17891  Disclosed examples provide processes for fabri...      0
# 17892  An analog-to-digital converter includes a comp...      1
# 17893  A piezoelectric linear actuator comprising a l...      0
#
# [17894 rows x 2 columns]

# %%
# Out:
# 'Embodiments of the present disclosure include methods and      configurations for an image sensor capable of simultaneous integration of      electrons and holes. According to one example, the image sensor can process      signals emitted from holes split into mutually different sub-lenses that are      indistinguishable at multiple wavelengths. <EOS>\n<BOS> A semiconductor device is provided. The semiconductor device includes a      carrier. The carrier includes a first region. The first region includes      holes. The carrier further includes an oxygen exchange layer (OEL) between      the first region and the OEL. The oxygen exchange layer includes a first portion      of a trench that extends in a first direction crossing the horizontal      direction, and a second portion that is in a second direction crossing the      horizontal direction and extending in a third direction crossing the      horizontal direction. A distance between an edge of the first region and an edge      of the second region in a first direction direction that is not      overlapping the first direction is equal to or greater than'

# %%
full_data.to_csv("./Models/Experiments/Abstracts/10epochs/real_fake_abstracts.csv")

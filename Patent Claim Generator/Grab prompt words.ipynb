# %%
# I will try to grab prompt words from existing patent claims and generate claims from there, 
# these generated text will be used for text classification
import pandas as pd
import re
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch
import numpy as np

# %%
data = pd.read_csv("../H01L.csv")
data.head()
# Out:
#    uid                                                url  \
# 0    1  http://patft.uspto.gov//netacgi/nph-Parser?Sec...
# 1    2  http://patft.uspto.gov//netacgi/nph-Parser?Sec...
# 2    3  http://patft.uspto.gov//netacgi/nph-Parser?Sec...
# 3    4  http://patft.uspto.gov//netacgi/nph-Parser?Sec...
# 4    5  http://patft.uspto.gov//netacgi/nph-Parser?Sec...
#
#                                               claims  \
# 0  1.  An organic light emitting diode display co...
# 1  1.  An electric element cooling module compris...
# 2  2.  The organic light emitting diode display o...
# 3  2.  The electric element cooling module of cla...
# 4  3.  The organic light emitting diode display o...
#
#                                             abstract  \
# 0  An organic light emitting diode display includ...
# 1  Provided is an electric element cooling module...
# 2  An organic light emitting diode display includ...
# 3  Provided is an electric element cooling module...
# 4  An organic light emitting diode display includ...
#
#                                          description  \
# 0    This application claims priority to Korean P...
# 1   CROSS-REFERENCE TO RELATED APPLICATIONS  This...
# 2    This application claims priority to Korean P...
# 3   CROSS-REFERENCE TO RELATED APPLICATIONS  This...
# 4    This application claims priority to Korean P...
#
#               collection_time                  write_date
# 0  2020-03-03 05:37:01.550764  2020-03-02 18:37:01.547157
# 1  2020-03-03 05:37:01.550849  2020-03-02 18:37:01.547352
# 2  2020-03-03 05:37:01.603471  2020-03-02 18:37:01.548018
# 3  2020-03-03 05:37:01.604237  2020-03-02 18:37:01.548179
# 4  2020-03-03 05:37:01.607406  2020-03-02 18:37:01.548057

# %%
def grab_random_prompts(data, numprompts, first_words=5, column='claims'):
    '''
    Inputs:
    numprompts int: Number of prompts we would want
    first_words int: How many first words would we want
    '''
    num_data = len(data)
    prompts = []
    while len(prompts) < numprompts:
        row = np.random.randint(0, num_data-1)
        try:
            words = data[column][row].split()
            firsts = " ".join(words[:first_words])
            prompts.append(firsts)
        except:
            #print("No claims")
            pass
    
#     for indx in rows:
#         words = data[column][indx].split()
#         firsts = " ".join(words[:first_words])
#         prompts.append(firsts)
    return prompts

# %%
grab_random_prompts(data, 20, first_words=5)
# Out:
# ['5. The light emitting device',
#  '20. The process according to',
#  '8. The process according to',
#  '7. The method of claim',
#  '22. A light emitting device',
#  '10. The apparatus of claim',
#  '5. The pressure sensor of',
#  '14. The method of claim',
#  '9. The method of manufacturing',
#  '14. The method of claim',
#  '11. A display device, comprising',
#  '19. The method of claim',
#  '11. The photoelectric conversion element',
#  '7. The magnetic structure according',
#  '5. The integrated circuit device',
#  '14. The display device according',
#  '19. The carbon nanotube nanostructure',
#  '15. The method of claim',
#  '12. An electronic device comprising',
#  '2. The system of claim']

# %%
OUTPUT_DIR = "./models"
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'

tokenizer = GPT2Tokenizer.from_pretrained(OUTPUT_DIR)
model = GPT2LMHeadModel.from_pretrained(OUTPUT_DIR)
model = model.to(device)
def generate(input_str, length=250, n=5):
    cur_ids = torch.tensor(tokenizer.encode(input_str)).unsqueeze(0).long().to(device)
    model.eval()
    with torch.no_grad():
        for i in range(length):
            outputs = model(cur_ids[:, -1024:], labels=cur_ids[:, -1024:])
            loss, logits = outputs[:2]
            softmax_logits = torch.softmax(logits[0,-1], dim=0)
            next_token_id = choose_from_top(softmax_logits.to('cpu').numpy(), n=n)
            cur_ids = torch.cat([cur_ids, torch.ones((1,1)).long().to(device) * next_token_id], dim=1)
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

def choose_from_top(probs, n=5):
    ind = np.argpartition(probs, -n)[-n:]
    top_prob = probs[ind]
    top_prob = top_prob / np.sum(top_prob) # Normalize
    choice = np.random.choice(n, 1, p = top_prob)
    token_id = ind[choice][0]
    return int(token_id)

# %%
# generate text for randomly retrieved prompt words
prompts = grab_random_prompts(data, 12, first_words=5)
for prompt in prompts:
    generated_text = generate(prompt, n=8)
    print(f"Prompt: {prompt}")
    print(generated_text)
# Out:
# Prompt: 14. The light-emitting device defined
# 14. The light-emitting device defined in claim 1, wherein the first light-emitting layer has a first width and a second width;  a first portion of the first portion is electrically connected to the second portion of the light-emitting layer;  and a second portion is electrically connected to the first portion of the light-emitting layer, wherein the first portion is electrically connected with the first portion of the second portion and the second portion is electrically connected with the second portion of the light-emitting layer. <EOS>
# <BOS> 7.  An electronic device, comprising: a substrate;  and a gate stack comprising an interlayer substrate having a first gate electrode having a first width, and a second gate electrode having a second width;  wherein the substrate is formed of a first material and a second material;  each gate stack comprises a first conductive layer disposed between the first portion of the gate electrode and the second portion of the gate electrode, a second conductive layer disposed in a first direction, and a third conductive layer disposed in a second direction, and wherein a first portion of the second portion of the gate electrode and the first portion of the second portion of the second portion of the second portion of the
# Prompt: 9. The display panel of
# 9. The display panel of claim 1 further comprising the first display unit comprising: a first display unit comprising: a first conductive layer disposed over and including a portion of the conductive layer extending along a first side of the first display unit, and a first portion disposed between the first display unit and the first conductive layer, wherein the first portion is in contact with a portion of a surface of the first conductive layer, and the first portion covers a portion of the first surface of the first conductive layer;  a second display unit comprising: a second conductive layer disposed over the second display unit, and including a portion of the second conductive layer extending along a second side of the second display unit, and a second portion disposed between the second display unit and the second conductive layer, wherein the second portion is in contact with a portion of a surface of the second conductive layer, and the second portion covers a portion of the second surface of the second conductive layer. <EOS>
# <BOS> 4.  The organic light emitting diode of claim 1, wherein: the organic light emitting diode portion comprises a first organic layer disposed at a lower surface of the third electrode region, and a second organic layer disposed at a upper surface
# Prompt: 9. The image display device
# 9. The image display device according to claim 1, wherein each of the light source units and the light emitting element are coupled to a corresponding electrode, the corresponding electrode includes a first pixel region, a second pixel region, a third pixel region and a fourth pixel region, and the first pixel region and the second pixel region are each independently connected to the pixel region through the light emitting element. <EOS>
# <BOS> 9.  The display device of claim 1, wherein the second dielectric layer has an inner diameter greater than the outer diameter. <EOS>
# <BOS> 1.  A light emitting device of claim 1 comprising, among a semiconductor device and a display device, a first portion that is electrically coupled to a first portion of the second dielectric layer, the first portion comprising a plurality of first portions, and a plurality of second portions, wherein the first portion further comprises the first dielectric material, the second portion comprises the second dielectric material and the second dielectric material, the plurality of first portions and the plurality of second portions are connected to each other and to the semiconductor device, the plurality of first portions and second portions are electrically coupled to the first portion of the second die
# Prompt: 7. The process of claim
# 7. The process of claim 4, wherein the first and second photosensitive film layers comprise an interlayer film and a second photoensitive film layer comprising a first material layer and a second material layer, and wherein an interlayer insulating film and an interlayer insulator film are in contact with one another, and are formed on the first material layer and the second material layer, respectively. <EOS>
# <BOS> 2.  The method of claim 1, wherein forming the first metal layer comprises: forming a plurality of first metal layers, the plurality of first metal layers having one surface and one end surface, a first metal material layer having an outer surface and an inner surface, a first material layer having an outer surface, and a first oxide layer having an inner surface;  etching a first metal layer to expose a second metal layer;  etching a second metal layer to expose a third metal layer, and etching at least one second metal layer, wherein a width of the first metal layer between the outer surface and the second metal layer is greater than a length of the first metal layer between the outer surface and the second metal layer;  etching at least one second metal layer to expose a third metal layer, and etching at least one
# Prompt: 3. The encapsulation structure according
# 3. The encapsulation structure according to claim 1, wherein the plurality of electrodes include a plurality of plurality of metal lines, wherein the plurality of metal lines are formed in a plurality of layers, wherein each metal line is made in a single layer in a region of the plurality of metal lines, and wherein the plurality of metallic lines are formed in a region of at least one of the plurality of metal lines. <EOS>
# <BOS> 3.  The semiconductor device of claim 3, wherein the conductive film further comprises a layer selected from the group consisting of a layer containing a first compound, a layer containing a second compound, and a layer containing a third compound. <EOS>
# <BOS> 8.  The method of claim 1 wherein forming the plurality of light emitting diode layers comprises: depositing the plurality of light emitting diode layers on a substrate;  forming a plurality of plurality of plurality of plurality of light emitting diode layers on a plurality of substrate;  forming a plurality of plurality of light emitting diode layers on a plurality of plurality of plurality of substrate-mountable structures;  forming an interlayer layer extending from the plurality of light emitting diode layers and the plurality of plurality of light emitting diode layers
# Prompt: 19. The device according to
# 19. The device according to claim 10, wherein the substrate includes two or more organic layers on top of each other, wherein the substrate is arranged between the organic layers, and wherein the organic layer is disposed between one of the substrate and the neighboring organic layer. <EOS>
# <BOS> 6.  The method of claim 1, wherein the second electrode includes a second dielectric material, and the second dielectric material is selected from a group consisting of an oxide semiconductor, a silica semiconductor, a silicon dioxide semiconductor, a silicon nitride semiconductor, a silicon oxide semiconductor, a silicon nitride semiconductor, and a silicon nitride semiconductor. <EOS>
# <BOS> 6.  The method as claimed in claim 3, further comprising: forming a second hole injection layer on the conductive layer to expose the first hole injection surface and forming an electrode on the second hole injection surface, wherein forming a first hole injection material in the second hole injection layer exposes the first hole injection material in the second hole injection layer, and forming an electrode on the hole injection material exposes the hole injection material in the first hole injection layer. <EOS>
# <BOS> 4.  The semiconductor device
# Prompt: 5. The drive circuit of
# 5. The drive circuit of claim 1 further comprises an output transistor that receives data from the input transistor, and outputs the data into a memory. <EOS>
# <BOS> 5.  The organic light-emitting display of claim 4, wherein the first and second semiconductor layers are arranged in a second direction, the third semiconductor layer in the second direction and the fourth semiconductor layer in the third direction. <EOS>
# <BOS> 4.  The semiconductor device of claim 2, further comprising a third electrode that is disposed between the first electrode and the second electrode. <EOS>
# <BOS> 1.  A light-emitting element comprising: a first electrode disposed between the light absorption layer and the first electrode;  a second electrode disposed between the light absorption layer and the second electrode, wherein: the first electrode and the second electrode are adjacent to each other;  and the first electrode has an area adjacent to an upper surface of the first electrode;  a portion of the surface of the second electrode is electrically connected to a portion of the surface of the second electrode, and the portion of the surface of the first electrode is electrically connected to the lower surface of the first electrode. <E
# Prompt: 1. A multi-junction solar cell,
# 1. A multi-junction solar cell, comprising: a first conductive metal layer and a second conductive metal layer disposed between the first conductive layer and the second conductive metal layer;  a first conductive material layer disposed between the first conductive material layer and the second conductive material layer, the first conductive material layer being in contact with the first semiconductor die, the second conductive material layer including a first conductive layer and a second conductive material layer and comprising a first and a second insulating layer on each of the second conductive material layer and the first insulating material layer, the first conductive material layer including a first insulating material layer and a second insulating material layer;  a plurality of semiconductor layers, each having a first insulating film on one side of the first semiconductor film and an intermediate film on the other side of the first semiconductor film;  a plurality of first conductive layers on one side of the first semiconductor film and an intermediate film on the other side of the first semiconductor film, the first first insulating film including a first insulating film and a second insulating film, the first intermediate film including a first insulating film and a second insulating film, the first intermediate film including a second
# Prompt: 13. The organic light-emitting display
# 13. The organic light-emitting display device according to claim 1, wherein the organic light-emitting device is disposed above a first surface of an organic light-emitting device disposed under a substrate, and at least a second surface of the organic light-emitting device. <EOS>
# <BOS> 7.  The light-emitting display of claim 1, wherein the organic layer comprises at least one of silicon dioxide and a phosphorescent material. <EOS>
# <BOS> 8.  The method of the solar cell according to claim 7, wherein, the first semiconductor material layer comprises at least one of silicon dioxide and a phosphorescent material. <EOS>
# <BOS> 1.  The organic light emitting diode according to claim 8, wherein said first semiconductor material layer comprises a second semiconductor material layer disposed in a first direction and a second direction, wherein at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said at least one of said first insulating layer and a second insulating layer disposed
# Prompt: 16. A pixel array included
# 16. A pixel array included in the package comprising a plurality of first, second, third, and fourth photosensitive pixels, each of the first, second, third, and fourth photosensitive photosensitive pixels comprises a pixel array of a first pixel type, a pixel array of a second pixel type, and a second pixel type, wherein the pixel array comprises at least one pixel type having at least one photoensitive pixel in the first pixel type having a first color, a pixel array of a second pixel type, and a third pixel type in the second pixel type having a second color, wherein the pixel array includes a first source electrode, a second source electrode, a third source electrode, a fourth source electrode, and a third source electrode;  a first insulator disposed in a first portion of the first pixel type;  a first insulator disposed in a second portion of the first pixel type;  a first insulator disposed in the first portion of the first pixel type, wherein the first insulator is electrically bonded to the first source electrode;  and a first insulator disposed on a first portion of the first pixel type and wherein the first insulator is electrically bonded to the second source electrode, and wherein the first insulator and the second insulator are electr
# Prompt: 12. The formulation of claim
# 12. The formulation of claim 1 is a compound comprising an anhydrous compound having at least one hydrophilic ring formed on the base of the compound in contact with a surface of the resin. <EOS>
# <BOS> 6.  The method of claim 1 wherein the second metal layer comprises one of a silicon nitride or a silicon oxide. <EOS>
# <BOS> 5.  The method according to claim 1, wherein a first electrode is formed on the second metal layer. <EOS>
# <BOS> 3.  The method according to claim 1, wherein: the first conductive layer comprises a first conductive layer and an insulating layer on the first conductive layer, the second conductive layer comprises a second conductive layer and an insulating layer on the second conductive layer, and each of the first and second conductive layers is arranged so that the first and second conductive layers of each first and second conducting layer are formed on opposite surfaces of one another. <EOS>
# <BOS> 8.  The image sensor according to claim 1, wherein each of the first and second pixels includes at least one first pixel and a pixel selected from the array of first and second image processing
# Prompt: 2. The pixel circuit according
# 2. The pixel circuit according to claim 1, wherein the organic layer is formed from an organic solvent. <EOS>
# <BOS> 4.  The display device according to claim 2, wherein the display device comprises: one or more display layers;  one or more pixel regions arranged in the display layer;  and one or more light emitting elements arranged between the plurality of display layers. <EOS>
# <BOS> 5.  The organic light emitting device of claim 1, further comprising a hole injection region, the hole injection region being located between the first layer and the third layer. <EOS>
# <BOS> 3.  The method of claim 1, wherein forming the organic compound comprises: depositing the organic compound on a substrate, including a first substrate;  and depositing a second substrate on the organic compound substrate to form the organic compound. <EOS>
# <BOS> 3.  The light emitting element according to claim 2, further comprising a hole injection region. <EOS>
# <BOS> 6.  The display device according to claim 1, further comprising a second opening and a second opening having a first opening, wherein an uppermost edge of the second opening extends into the first
